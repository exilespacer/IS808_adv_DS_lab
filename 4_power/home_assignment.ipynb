# %% [markdown]
# ## DAO Power Analysis

# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from gql import gql, Client
from gql.transport.aiohttp import AIOHTTPTransport

from etherscan import Etherscan

import json
import time
import os
import random
import math

import scipy.stats as st


print(pd.__version__)
print(np.__version__)
print(requests.__version__)
print(plt.matplotlib.__version__)
# Out:
# 1.3.4
# 1.21.2
# 2.26.0
# 3.5.0

# %% [markdown]
# Import authentication key.

# %%
# https://martin-thoma.com/configuration-files-in-python/

import json

with open("../3_api/.private/keys.json") as keys_file:
    KEYS = json.load(keys_file)

# Note: don't print the key, or if you do, delete the cell's output
# (cell outputs are saved and can be sent to Github).

# %% [markdown]
# #### Define functions to call different APIs

# %%
## DEEPDAO

def deepdao(query, params=None, post=False):

    ENDPOINT = 'https://api.deepdao.io/v0.1/'

    headers={
        'x-api-key': KEYS['DEEPDAO'],
        'accept': 'application/json'
    }

    if post:
        response = requests.post(ENDPOINT + query,
                                headers=headers,
                                json=params)
    else:
        response = requests.get(ENDPOINT + query,
                                headers=headers,
                                params=params)

    print(response)
    return response.json()

## ETHERSCAN
############

def etherscan(params={}):

    ENDPOINT = 'https://api.etherscan.io/api'

    params['apikey'] = KEYS['ETHERSCAN']

    response = requests.get(ENDPOINT,
                            headers={
                                'accept': 'application/json',
                                "User-Agent": ""
                            },
                            params=params)

    print(response)
    return response.json()


eth = Etherscan(KEYS['ETHERSCAN'])

## SNAPSHOT
###########

SNAPSHOT_ENDPOINT = "https://hub.snapshot.org/graphql"

snapshot = Client(
    transport=AIOHTTPTransport(url=SNAPSHOT_ENDPOINT)
)


def snapshot_rest(query, params=None):

    response = requests.post(SNAPSHOT_ENDPOINT,
                            headers={                      
                                'accept': 'application/json'
                            },
                            params={
                                'query': query
                            })

    print(response)
    return response.json()['data']

## THE GRAPH
############

## Endpoints depends on subgraph of interest.

# %% [markdown]
# ## Load DAOs.
#
# Saved in previous lecture.

# %%
## All Daos according to Deepdao
daos_deepdao = pd.read_json("../3_api/deepdao/data/daos_deepdao.json")
daos_deepdao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2275 entries, 0 to 2274
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   organizationId   2275 non-null   object
#  1   name             2275 non-null   object
#  2   description      2275 non-null   object
#  3   logo             1466 non-null   object
#  4   members          2275 non-null   int64
#  5   activeMembers    2275 non-null   int64
#  6   proposals        2275 non-null   int64
#  7   votes            2275 non-null   int64
#  8   governance       2268 non-null   object
#  9   categories       358 non-null    object
#  10  socialResources  2246 non-null   object
#  11  updatedAt        2275 non-null   object
#  12  tokens           239 non-null    object
# dtypes: int64(4), object(9)
# memory usage: 231.2+ KB

# %%
# ## Warning: it throws an error.

# ## All Daos according to Snapshot
# daos_snapshot = pd.read_json("../3_api/snapshot/data/daos_snapshot.json")
# daos_snapshot.info()

# %% [markdown]
# Workaround.

# %%
with open("../3_api/snapshot/data/daos_snapshot.json") as file:
    daos_snapshot = json.load(file)

daos_snapshot = pd.DataFrame(daos_snapshot)
daos_snapshot.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10956 entries, 0 to 10955
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          10956 non-null  object
#  1   name        10956 non-null  object
#  2   about       10956 non-null  object
#  3   network     10956 non-null  object
#  4   symbol      10956 non-null  object
#  5   strategies  10956 non-null  object
#  6   admins      10956 non-null  object
#  7   members     10956 non-null  object
#  8   filters     10956 non-null  object
#  9   plugins     10956 non-null  object
# dtypes: object(10)
# memory usage: 856.1+ KB

# %% [markdown]
# ### Updated Utility Functions.

# %% [markdown]
# #### Load JSON files into Pandas.
#
# Pandas throws an error if JSON contains too large ints, so we load JSON separately and then feed the Pandas.

# %%
def pd_read_json(file):
    ## Prevents Value too big Error.
    with open(file) as f:
        df = json.load(f)
    df = pd.DataFrame(df)
    return df

# %% [markdown]
# ### Keep GQL queries separated.
#
# GQL queries can be quite cumbersome, so it's better to write them into a separate file and then load them in here.

# %%
def get_query(filename, do_gql=False):
    with open("gql_queries/" + filename.replace(".gql", "") + ".gql") as f:
        query = f.read()
        if do_gql: query = gql(query)
    return query
    
## Alias gq.
gq = get_query

# %% [markdown]
# #### Enhanced API Wrapper
#
# With this wrapper we want to:
# - Save data as we download it in order to avoid data loss in case of an error (remote or local).
# - Save the data periodically and in small chuncks, which is usually easier to load back.
# - Catch errors as much as possible, to terminate gracefully the execution.
# - Execute both GQL and simple rest requests for any type of query.

# %%
async def gql_all(query, field, first=1000, skip=None, initial_list=None, 
                  counter = True, limit=None, save=None, save_interval=10, clear_on_save = False, append=True, rest=False, data_dir="data", save_counter = 1, vars=None):

    ## The returned value and the varible used to accumulate results.
    out = []

    ## Utility function to save intermediate and final results.
    def save_json():

        # Pandas has problem load pure json saves.
        # Hence we create a pandas Dataframe and save it.
        # nonlocal append
        # flag = "a" if append else "w"
        # with open("data/" + save, flag) as f:
        #     json.dump(out, f)
        #     print("Saved.")

        nonlocal out
        df = pd.DataFrame(out)

        if clear_on_save:
            
            nonlocal save_counter
            
            sv = str(save_counter)
            sv = sv.zfill(5)
            save_counter += 1

            filename = save.replace('.json', '_' + sv + '.json')
            
            out = []
            out_str = "Saved and cleared."
        else:
            filename = save
            out_str = "Saved."
        
        df.to_json(data_dir + "/" + filename, orient="records")
        print(out_str)

        
    ## Load initial list.
    ## If no skip is provided, then skip is set to the length of
    ## the initial list, otherwise we use the user-specified value
    if initial_list:
        out = initial_list
        if skip is None:
            skip = len(out)
    elif skip is None:
        skip = 0

    ## Make a GQL query object, if necessary.
    if not rest and type(query) == str:
        query = gql(query)
        

    my_counter = 0
    fetch = True
    try:
        while fetch:
            
            my_counter += 1
            if limit and my_counter > limit:
                print('**Limit reached: ', limit)
                fetch = False
                continue

            if rest:

                # Building query manually.
                q = query.replace("($first: Int!, $skip: Int!)", "")
                q = q.replace("$first", str(first))
                q = q.replace("$skip", str(skip))
                # print(q)

                ## Optional additional variables.
                if vars:
                    for v in vars:
                        q = q.replace("$" + v, str(vars[v]))

                res = snapshot_rest(q)
                
            else:
                
                _vars = {"first": first, "skip": skip}
                
                ## Optional additional variables.
                if vars:
                    _vars ={**_vars, ** vars}

                res = await snapshot.execute_async(query, variable_values=_vars)
            
            if not res[field]:
                print('**I am done fetching!**')
                fetch = False
            else:
                out.extend(res[field])
                skip += first
                if counter: print(my_counter, len(out))

                if save and my_counter % save_interval == 0:
                    save_json()

        if save and my_counter % save_interval != 0:
            save_json()

    except Exception as e:
        print(str(e))
        print("**An error occurred, exiting early.**")
        if save: save_json()
    
    return out

# %% [markdown]
# As we split data from the API in multiple smaller files, we want to have a quick method to load them back into one place.

# %%
def pd_read_dir(dir, blacklist=None, whitelist=None, ext=('.json')):
    dir_df = pd.DataFrame()
    

    for file in os.listdir(dir):
        if blacklist and file in blacklist:
            continue
        if whitelist and file not in whitelist:
            continue

        if file.endswith(ext):
            tmp_df = pd_read_json(dir + '/' + file)
            dir_df = pd.concat([dir_df, tmp_df])
    
    return dir_df

# %% [markdown]
# ## Spaces

# %% [markdown]
# We did not fetch all the useful information in the previous lecture. Let's do it again.

# %% [markdown]
# **Exercise: use the functions above to load all spaces**
#
# Important! Try with GQL and with REST.
#
# Remember to save the file.
#
# Try different values of `first`.

# %%
## Your code here.
from re import S


q = get_query(filename="snapshot_spaces")
res = await gql_all(
    query = q, 
    field = "spaces",
    save = "snapshot_spaces.json"
)
res

# q = get_query(filename="snapshot_followers_of_space")
# res = await gql_all(
#     query=q, 
#     field="follows",
#     vars = {
#         "space": "yam.eth"
#     }    
# )
# Out:
# 1 1000
# 2 2000
# 3 3000
# 4 4000
# 5 5000
# 6 6000
# 7 7000
# 8 8000
# 9 9000
# 10 10000
# Saved.
# 11 11000
# 12 11195
# **I am done fetching!**
# Saved.
# [{'id': 'bonustrack.eth',
#   'name': 'Hi',
#   'private': True,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'TICKET',
#   'skin': 'aragon',
#   'domain': 'vote.balancer.finance',
#   'strategies': [{'name': 'ticket',
#     'params': {'symbol': 'TICKET'},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x24A12Fa313F57aF541d447c594072A992c605DCf',
#    '0x8BBE4Ac64246d600BC2889ef5d83809D138F03DF',
#    '0xeF8305E140ac520225DAf050e2f71d5fBcC543e7',
#    '0x107174D70b33523E83711EA4C3F4229cdB8A7Cb1',
#    '0x0b21Dbc34A953a35dFA629ad31e1cEE3dE0433Fb',
#    '0x40FDAa1bff3BB87bC70955Be6657edBFdBeb122e',
#    '0xcc6A949DB9b26a7173648d50Cf7C55e800E6585B',
#    '0xC1C8ac723Fd9Db3db6E947dF42aaEdd28058A31D'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {'safeSnap': {'address': '0xeF8305E140ac520225DAf050e2f71d5fBcC543e7'}},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 0,
#   'proposalsCount': 2,
#   'parent': None,
#   'children': []},
#  {'id': 'fabien.eth',
#   'name': 'Fabien',
#   'private': False,
#   'about': 'This is nothing more than a test space.',
#   'avatar': 'ipfs://QmcbtSnE5TpCjuQrKN4sxEh1Qv6B4RoKLx4aVgjtf8y3M5',
#   'terms': None,
#   'location': None,
#   'website': 'https://snapshot.org/#/fabien.eth',
#   'twitter': 'bonustrack87',
#   'github': 'bonustrack',
#   'email': None,
#   'network': '1',
#   'symbol': 'POINT',
#   'skin': 'eth',
#   'domain': None,
#   'strategies': [{'name': 'ticket',
#     'params': {'value': 100, 'symbol': 'POINT'},
#     'network': '1'}],
#   'admins': ['0xeF8305E140ac520225DAf050e2f71d5fBcC543e7',
#    '0x4C7909d6F029b3a5798143C843F4f8e5341a3473'],
#   'members': ['0xeF8305E140ac520225DAf050e2f71d5fBcC543e7'],
#   'filters': {'minScore': 1, 'onlyMembers': False},
#   'plugins': {'safeSnap': {'safes': [{'network': '4',
#       'realityAddress': '0xF8Ca72b0d427F0b3e8984133C8A6860153b4f2D8'}]}},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': 14,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': 'shutter'},
#   'categories': ['social', 'creator'],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [{'name': 'Fabien',
#     'address': '0xeF8305E140ac520225DAf050e2f71d5fBcC543e7',
#     'network': '1'}],
#   'followersCount': 1009,
#   'proposalsCount': 323,
#   'parent': None,
#   'children': []},
#  {'id': 'ichi.eth',
#   'name': 'ichi.farm',
#   'private': False,
#   'about': '',
#   'avatar': 'ipfs://QmZWdd7iWxB61KGn2i5MGEHQeakFTWyPnKTL9A4x26b3Fz',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'ICHIPOWAH',
#   'skin': 'synthetix',
#   'domain': 'https://www.ichi.farm/',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'ICHIPOWAH',
#      'address': '0x873902a3c0731EcC1F2075435FE035ACCeEd5459',
#      'decimals': 9},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x873902a3c0731EcC1F2075435FE035ACCeEd5459'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 60,
#   'proposalsCount': 56,
#   'parent': None,
#   'children': []},
#  {'id': 'loyalfinance.eth',
#   'name': 'loyal.finance',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'rLYL',
#   'skin': 'eth',
#   'domain': 'loyal.finance',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'RLYL',
#      'address': '0x0C9BbF4364F90db22B1B21b45177069a078842Aa',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 0,
#   'proposalsCount': 2,
#   'parent': None,
#   'children': []},
#  {'id': 'damflux.eth',
#   'name': 'FLUX',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'FLUX',
#   'skin': 'coin',
#   'domain': 'https://datamine.finance',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'FLUX',
#      'address': '0x469eDA64aEd3A3Ad6f868c44564291aA415cB1d9',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 6,
#   'proposalsCount': 2,
#   'parent': None,
#   'children': []},
#  {'id': 'ufode.eth',
#   'name': 'UFO Finance',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'UFO',
#   'skin': 'cover',
#   'domain': 'https://ufode.finance',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 2,
#   'proposalsCount': 4,
#   'parent': None,
#   'children': []},
#  {'id': 'boringvote.eth',
#   'name': 'BoringDAO',
#   'private': False,
#   'about': '',
#   'avatar': 'ipfs://QmRoRjQAVGAbhBdzzD5ngH7q5Ff6cwwpfGKrt9HqpQahWW',
#   'terms': None,
#   'location': None,
#   'website': 'https://www.boringdao.com/',
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'BoringDAO VS',
#   'skin': 'eth',
#   'domain': 'vote.boringdao.org',
#   'strategies': [{'name': 'contract-call',
#     'params': {'symbol': 'BoringDAO VS',
#      'address': '0xdd018AD3D79bF8aA7C2E9726b566f7aeeF693618',
#      'decimals': 18,
#      'methodABI': {'name': 'balanceOf',
#       'type': 'function',
#       'inputs': [{'name': '_voter',
#         'type': 'address',
#         'internalType': 'address'}],
#       'outputs': [{'name': '', 'type': 'uint256', 'internalType': 'uint256'}],
#       'stateMutability': 'view'}},
#     'network': '1'}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 73,
#   'proposalsCount': 41,
#   'parent': None,
#   'children': []},
#  {'id': 'relayernetwork.eth',
#   'name': 'Relayer Network',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'RLR',
#   'skin': 'synthetix',
#   'domain': 'vote.relay3r.network',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'RLR',
#      'address': '0x0e3ef895c59e7db27214ab5bbf56347ce115a3f4',
#      'decimals': 18},
#     'network': '1'},
#    {'name': 'erc20-balance-of-delegation',
#     'params': {'symbol': 'RLR',
#      'address': '0x0e3ef895c59e7db27214ab5bbf56347ce115a3f4',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 1,
#   'proposalsCount': 10,
#   'parent': None,
#   'children': []},
#  {'id': 'prophetfinance.eth',
#   'name': 'prophet.finance',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'PROPHET',
#   'skin': 'aave',
#   'domain': 'https://prophet.finance',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'PROPHET',
#      'address': '0x8d5db0c1f0681071cb38a382ae6704588d9da587',
#      'decimals': 9},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0xcA670BC7D254C2a4b050Dbb05aD8f3db57Fd43Cd',
#    '0xe2f071Fa6a421c6Bd7DF3635cC001c569182B950'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 1,
#   'proposalsCount': 12,
#   'parent': None,
#   'children': []},
#  {'id': 'liddao.eth',
#   'name': 'Lid Dao',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'Lid Dao',
#   'skin': None,
#   'domain': 'liddao.eth',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'LID-vr',
#      'address': '0xb271e47E8AbD99df2f6275793eF838B0Ee0866c9',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x4735581201F4cAD63CCa0716AB4ac7D6d9CFB0ed'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 1,
#   'proposalsCount': 14,
#   'parent': None,
#   'children': []},
#  {'id': 'idlefinance.eth',
#   'name': 'Idle DAO',
#   'private': False,
#   'about': 'Idle DAO off-chain polls for IDLE holders',
#   'avatar': 'ipfs://QmdcEPNYDZgf1uE3evtbVXmKBckbueod31NmKmEumRjPXx',
#   'terms': None,
#   'location': None,
#   'website': 'https://idle.finance',
#   'twitter': 'idlefinance',
#   'github': 'Idle-Finance',
#   'email': None,
#   'network': '1',
#   'symbol': 'IDLE',
#   'skin': 'status',
#   'domain': 'signal.idle.finance',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'IDLE',
#      'address': '0x875773784Af8135eA0ef43b5a374AaD105c5D39e',
#      'decimals': 18},
#     'network': '1'},
#    {'name': 'erc20-balance-of',
#     'params': {'start': 11737307,
#      'symbol': 'LockedIDLE',
#      'address': '0xF241a0151841AE2E6ea750D50C5794b5EDC31D99',
#      'decimals': 18},
#     'network': '1'},
#    {'name': 'uniswap',
#     'params': {'symbol': 'IDLE',
#      'address': '0x875773784Af8135eA0ef43b5a374AaD105c5D39e',
#      'decimals': 18},
#     'network': '1'},
#    {'name': 'sushiswap',
#     'params': {'symbol': 'IDLE',
#      'address': '0x875773784Af8135eA0ef43b5a374AaD105c5D39e',
#      'decimals': 18},
#     'network': '1'},
#    {'name': 'erc20-balance-of-delegation',
#     'params': {'symbol': 'IDLE',
#      'address': '0x875773784Af8135eA0ef43b5a374AaD105c5D39e',
#      'decimals': 18,
#      'delegationSpace': 'idlefinance.eth'},
#     'network': '1'}],
#   'admins': ['0xe4E69ef860D3018B61A25134D60678be8628f780',
#    '0xb373F5f09d9875b94661776201165D01a7AE7bF7'],
#   'members': ['0xf27d7e8E96e891D77F42E1d88dA872A1cFaFe91a',
#    '0x4AF7cfbDbeF5ba845476652b79c0157D923E8207',
#    '0x2fa92128ecE3901395448bf62Dd5Ff6a35871540',
#    '0xe09E513301ba3717cBF50d9e67F85fAC249bb74d',
#    '0xeA173648F959790baea225cE3E75dF8A53a6BDE5',
#    '0xb373F5f09d9875b94661776201165D01a7AE7bF7',
#    '0x30723bb508E84706297EeF689C20096907023897',
#    '0xbD2D55b7F1693C4Fb337a89aCB12f657D5acFc82',
#    '0xDeBa9cd00120Ea0BE15955Cc3FA4b2d3E66Aa65d',
#    '0xfdA462548Ce04282f4B6D6619823a7C64Fdc0185'],
#   'filters': {'minScore': 100, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': ['protocol'],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [{'name': 'Idle DAO - Ecosystem Fund',
#     'address': '0xb0aA1f98523Ec15932dd5fAAC5d86e57115571C7',
#     'network': '1'},
#    {'name': 'Idle DAO - Long Term Fund',
#     'address': '0x107A369bc066c77FF061c7d2420618a6ce31B925',
#     'network': '1'},
#    {'name': 'Idle DAO - Fee Treasury',
#     'address': '0x69a62C24F16d4914a48919613e8eE330641Bcb94',
#     'network': '1'},
#    {'name': 'Idle DAO - Fee Collector',
#     'address': '0xBecC659Bfc6EDcA552fa1A67451cC6b38a0108E4',
#     'network': '1'}],
#   'followersCount': 22,
#   'proposalsCount': 85,
#   'parent': None,
#   'children': [{'id': 'staking.idlefinance.eth'}]},
#  {'id': 'scradclub.eth',
#   'name': 'SCRAD Club',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'SMT',
#   'skin': 'fries',
#   'domain': None,
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'SMT',
#      'address': '0xa6c5651f3f7f81bea6097a1a694bf819adbd1cfd',
#      'decimals': 0},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x58E603d9824976F7a3940C6B408F0Ffa523a216C'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 1,
#   'proposalsCount': 8,
#   'parent': None,
#   'children': []},
#  {'id': 'pub-finance.eth',
#   'name': 'pub-finance',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'PINT',
#   'skin': 'fries',
#   'domain': 'pub.finance',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'PINT',
#      'address': '0xFECBa472B2540C5a2d3700b2C9E06F0aa7dC6462',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 50000, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 4,
#   'proposalsCount': 14,
#   'parent': None,
#   'children': []},
#  {'id': 'saffronfinance.eth',
#   'name': 'saffron.finance',
#   'private': False,
#   'about': 'Welcome to Saffron, a peer-to-peer collateralization and risk exchange protocol. SFI holders decide which proposals are implemented on-chain',
#   'avatar': 'ipfs://QmQnW9UNCMfgL8droNC3VUXTPgamCuJ3ic8DuoJPXey2cT',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': 'saffronfinance_',
#   'github': 'saffron-finance',
#   'email': None,
#   'network': '1',
#   'symbol': 'SFI',
#   'skin': 'hubdao',
#   'domain': 'vote.saffron.finance',
#   'strategies': [{'name': 'saffron-finance',
#     'params': {'symbol': 'SFIV1',
#      'contracts': [{'label': 'SFI',
#        'tokenAddress': '0xb753428af26e81097e7fd17f40c88aaa3e04902c',
#        'votingScheme': 'oneToOne'},
#       {'label': 'TEAM_HODL_TOKEN',
#        'tokenAddress': '0x4e5ee20900898054e998fd1862742c28c651bf5d',
#        'votingScheme': 'oneToOne'}],
#      'dexLpTypes': [{'name': 'uniswap',
#        'lpToken': '0xC76225124F3CaAb07f609b1D147a31de43926cd6'},
#       {'name': 'sushiswap',
#        'lpToken': '0x23a9292830Fc80dB7f563eDb28D2fe6fB47f8624'}],
#      'votingSchemes': [{'name': 'oneToOne',
#        'type': 'DirectBoostScheme',
#        'multiplier': 1},
#       {'name': 'staking', 'type': 'DirectBoostScheme', 'multiplier': 1.1},
#       {'name': 'uniswap', 'type': 'LPReservePairScheme', 'multiplier': 1.1},
#       {'name': 'sushiswap',
#        'type': 'LPReservePairScheme',
#        'multiplier': 1.1}]},
#     'network': '1'},
#    {'name': 'saffron-finance-v2',
#     'params': {'symbol': 'SAFF_STAK_V2',
#      'decimals': 18,
#      'multiplier': 1.1,
#      'stakingPool': '0x4eB4C5911e931667fE1647428F38401aB1661763',
#      'singleAssets': ['0xb753428af26E81097e7fD17f40c88aaA3E04902c']},
#     'network': '1'}],
#   'admins': ['0x9CfEC36a7b09c469DDf0D1558Eb92F7A88ED796b'],
#   'members': ['0x9CfEC36a7b09c469DDf0D1558Eb92F7A88ED796b',
#    '0xD90B866039E8820c2Cd082840fceeD81Cef691F8',
#    '0x44b6eaEA64a0f0a8828B32a9B9E103CD5eBfBBEb'],
#   'filters': {'minScore': 0.1, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 25,
#   'proposalsCount': 9,
#   'parent': None,
#   'children': []},
#  {'id': 'sovi.eth',
#   'name': 'sovi.finance',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'SOVI',
#   'skin': 'y3d',
#   'domain': 'https://sovi.finance',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x560C2B75c7B4e077C71D66aE4E18b688D099963f',
#    '0x02e8e50913F7Fc1a22F48C1e7012cdc80B03d25a'],
#   'filters': {'minScore': 1, 'onlyMembers': True},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 2,
#   'proposalsCount': 0,
#   'parent': None,
#   'children': []},
#  {'id': 'monportefeuille.eth',
#   'name': 'Monportefeuille',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'CIRCL',
#   'skin': 'raid-guild',
#   'domain': 'monportefeuille.eth',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'CIRCL',
#      'address': '0x63a2ccd492e316eefab5b3326db3c7b0a94c3726',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0xa921789802E13243C6827D37526Ce632eF4A138b'],
#   'filters': {'minScore': 250, 'onlyMembers': True},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 1,
#   'proposalsCount': 1,
#   'parent': None,
#   'children': []},
#  {'id': 'flowcommunity.eth',
#   'name': 'Flow Protocol',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'FLOW',
#   'skin': None,
#   'domain': 'https://flowprotocol.io',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'FLOW',
#      'address': '0xC6e64729931f60D2c8Bc70A27D66D9E0c28D1BF9',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 51, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 1,
#   'proposalsCount': 0,
#   'parent': None,
#   'children': []},
#  {'id': 'tradersquare.eth',
#   'name': 'Trader Square',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'TRS',
#   'skin': 'qian',
#   'domain': '',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'TRS',
#      'address': '0x1Ef4d930097D30689B16945Aa8286C62Ce7f75dF',
#      'decimals': 4},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0xf4945a878d7B464cAA4d383B3988a652661897d2',
#    '0xe2d088Ee9872dFd340A6B3fb5d0fD6B245CBe34a',
#    '0x890F598d391f4bA5A2d903301eC78B7E12C935FC'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 1,
#   'proposalsCount': 4,
#   'parent': None,
#   'children': []},
#  {'id': 'xionetwork.eth',
#   'name': '(old) Blockzero Labs',
#   'private': True,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'XIO',
#   'skin': 'balancer',
#   'domain': '',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'XIO',
#      'address': '0x0f7F961648aE6Db43C75663aC7E5414Eb79b5704',
#      'decimals': 18},
#     'network': '1'},
#    {'name': 'uniswap',
#     'params': {'symbol': 'XIO',
#      'address': '0x0f7F961648aE6Db43C75663aC7E5414Eb79b5704',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x11231f7Dc863F36A6516Eb4EF052f195000e0000',
#    '0xA0018Abd370A8B5CA89452f0711B653786F6264E',
#    '0xb0faa146515792276465F084f7c23E52F3B40839',
#    '0xA8A68CDe3aF5a932BE6a29a7E4975D1975f3E3AC',
#    '0x4BF4e3a59add035c479CDE89d98103Cb65DCa941',
#    '0xE73C98667C82bb76E58c0d9B065B6A0C9ea2d088'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 0,
#   'proposalsCount': 31,
#   'parent': None,
#   'children': []},
#  {'id': 'minkfinance.eth',
#   'name': 'Mink Finance',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'MINK',
#   'skin': None,
#   'domain': 'https://gov.mink.finance',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'MINK',
#      'address': '0x1D47F2A94d5a6d59D2A37eF47CA7f71b661654c8',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x9650F4feDd1e6ce63621479A4bf5F4d743E6F958'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 0,
#   'proposalsCount': 1,
#   'parent': None,
#   'children': []},
#  {'id': 'mutualdao.eth',
#   'name': 'MutualDAO',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'MDS',
#   'skin': 'eth',
#   'domain': 'https://www.mutualdao.org',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'MDS',
#      'address': '0x66186008C1050627F979d464eABb258860563dbE',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x00f57c080d7746b607708699bc9c3af289a0b56a'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 0,
#   'proposalsCount': 1,
#   'parent': None,
#   'children': []},
#  {'id': 'esd.eth',
#   'name': 'Empty Set',
#   'private': False,
#   'about': 'A decentralized, censorship resistant, stablecoin built for DeFi',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': 'emptysetdollar',
#   'github': 'emptysetsquad',
#   'email': None,
#   'network': '1',
#   'symbol': 'ESS',
#   'skin': 'eth',
#   'domain': 'fund.emptyset.finance',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'ESS',
#      'address': '0x24aE124c4CC33D6791F8E8B63520ed7107ac8b3e',
#      'decimals': 18},
#     'network': '1'},
#    {'name': 'delegation',
#     'params': {'symbol': 'ESS (delegated)',
#      'strategies': [{'name': 'erc20-balance-of',
#        'params': {'address': '0x24aE124c4CC33D6791F8E8B63520ed7107ac8b3e',
#         'decimals': 18}}]},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0xB0B2b405c9D09d129E9F9b18c9DD218c532f2b2A',
#    '0x0FeBbB3f91fae9BDC2f86B82c1b61a1dF6c6a5e8',
#    '0x264297e93B09430a81a31368F243EDe8500A5E6d',
#    '0x7ed9F10b5299b44D28F2AEBf8D057919698cB94A',
#    '0xC85170886A7F34e1365E2aA04486ae8F1106F783',
#    '0xDbFcA4a2807F4EF3efdDc10F3EaDc84714D8c333',
#    '0x37Ed74A0dA66c0392C4c5901c3b3B97675871FE1'],
#   'filters': {'minScore': 100000, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 72,
#   'proposalsCount': 20,
#   'parent': None,
#   'children': []},
#  {'id': 'vote.southchain.eth',
#   'name': 'SouthChain Digital Asset Network',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'SCT',
#   'skin': 'mettalex',
#   'domain': 'vote.southchain.eth',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'SCT',
#      'address': '0x98f2e50eECA2352b60E1Dad37f93Dc9113a07BE9',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x51A33a5bBa82f8EBd0fE2192A25CA2E60B9Dc32f',
#    '0x54c787bA416570B72B5Da1457a7bE0932261f9b2',
#    '0x6Bc5d7C5cb2371A1923499F7a38717261Dadb559',
#    '0x2C9754cc6E982530c7fC41CA1edA622d780Cf49d'],
#   'filters': {'minScore': 10000, 'onlyMembers': True},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 1,
#   'proposalsCount': 1,
#   'parent': None,
#   'children': []},
#  {'id': 'flushlol.eth',
#   'name': 'FLUSH',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'PAPER',
#   'skin': 'flush',
#   'domain': 'gov.flush.lol',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'PAPER',
#      'address': '0xdDce093888C8Dc636677Cd29BC6C68D35cFDAC33',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0xcd9B0611bAD3c052215968bA5CBD7A0A51549BA6'],
#   'filters': {'minScore': 10, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 0,
#   'proposalsCount': 1,
#   'parent': None,
#   'children': []},
#  {'id': 'xethfinance.eth',
#   'name': 'xETH Finance',
#   'private': True,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'xETH-G',
#   'skin': 'griffin',
#   'domain': None,
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'xETH-G',
#      'address': '0x3863ea7577fc91bfbaeae6a6a3e403524afcf787',
#      'decimals': 18},
#     'network': '1'},
#    {'name': 'staked-uniswap',
#     'params': {'symbol': 'xETH-G',
#      'decimals': 18,
#      'tokenAddress': '0x3863EA7577fc91bFBaEAE6A6a3E403524aFcf787',
#      'stakingAddress': '0x022e6461e01af241a81b2e6a661111efa852e976',
#      'uniswapAddress': '0x6ff249432df165f209782995dc27c9c53bd11ee1'},
#     'network': '1'},
#    {'name': 'contract-call',
#     'params': {'symbol': 'xETH-G',
#      'address': '0x304D4F1abB117aaB97C6AC34b97fE14348A3Be10',
#      'decimals': 18,
#      'methodABI': {'name': 'balanceOf',
#       'type': 'function',
#       'inputs': [{'name': 'voter',
#         'type': 'address',
#         'internalType': 'address'}],
#       'outputs': [{'name': '', 'type': 'uint256', 'internalType': 'uint256'}],
#       'stateMutability': 'view'}},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x95df7d90fc5822Ef1140Fb9aB37A9fF2a94356A2'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 0,
#   'proposalsCount': 0,
#   'parent': None,
#   'children': []},
#  {'id': 'dodobird.eth',
#   'name': 'DODO',
#   'private': False,
#   'about': 'DODO is a decentralized exchange platform powered by the Proactive Market Maker (PMM) algorithm.',
#   'avatar': 'ipfs://QmPVpmxBYthxp2uTrbFV4sKr59X1LG1m4FDSZB1rfihnqH',
#   'terms': None,
#   'location': None,
#   'website': 'https://dodoex.io/',
#   'twitter': 'BreederDodo',
#   'github': 'DODOEX',
#   'email': None,
#   'network': '1',
#   'symbol': 'DODO',
#   'skin': 'eth',
#   'domain': None,
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DODO',
#      'address': '0x43Dfc4159D86F3A37A5A4B3D4580b888ad7d4DDd',
#      'decimals': 18},
#     'network': '1'},
#    {'name': 'erc20-balance-of-coeff',
#     'params': {'coeff': 100,
#      'symbol': 'vDODO',
#      'address': '0xc4436fBAE6eBa5d95bf7d53Ae515F8A707Bd402A',
#      'decimals': 18},
#     'network': '1'},
#    {'name': 'multichain',
#     'params': {'symbol': 'BSC DODO',
#      'strategies': [{'name': 'erc20-balance-of',
#        'params': {'address': '0x67ee3Cb086F8a16f34beE3ca72FAD36F7Db929e2',
#         'decimals': 18},
#        'network': '56'}]},
#     'network': '1'},
#    {'name': 'multichain',
#     'params': {'symbol': 'Arbitrum DODO',
#      'strategies': [{'name': 'erc20-balance-of',
#        'params': {'address': '0x69Eb4FA4a2fbd498C257C57Ea8b7655a2559A581',
#         'decimals': 18},
#        'network': '42161'}]},
#     'network': '1'},
#    {'name': 'multichain',
#     'params': {'symbol': 'Polygon DODO',
#      'strategies': [{'name': 'erc20-balance-of',
#        'params': {'address': '0xe4bf2864ebec7b7fdf6eeca9bacae7cdfdaffe78',
#         'decimals': 18},
#        'network': '137'}]},
#     'network': '1'}],
#   'admins': ['0xd088dBF014335d679fac2b7c6359018f8ed952BB',
#    '0x0fBC222aDF84bEE9169022b28ebc3D32b5C60756',
#    '0xC1068213b81c7A18E88063e998519d5EBB01efE2'],
#   'members': ['0xd088dBF014335d679fac2b7c6359018f8ed952BB'],
#   'filters': {'minScore': 100000, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': 5000000,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': ['protocol'],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 1984,
#   'proposalsCount': 16,
#   'parent': None,
#   'children': []},
#  {'id': 'archerdao.eth',
#   'name': 'Archer DAO',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'ARCH',
#   'skin': 'balancer',
#   'domain': 'gov.archerdao.io',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'AVP',
#      'address': '0x000100bB517E0c003200502A822083000a3B005d',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x8d775aeA4533253327FE70be28F6a56166ddD951',
#    '0x848Df9eFee9Fe8b473Ad456CFd46364461B5BC75',
#    '0x4530B100BF6400268E22fE64d7548fFaafA8dC39'],
#   'filters': {'minScore': 20000, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 23,
#   'proposalsCount': 4,
#   'parent': None,
#   'children': []},
#  {'id': 'bbra.eth',
#   'name': 'BooBanker Research Association',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'BBRA',
#   'skin': 'eth',
#   'domain': 'vote.bbra.io',
#   'strategies': [{'name': 'contract-call',
#     'params': {'symbol': 'BBRA',
#      'address': '0x19e5680201231B5Ef3038063Ff801C1b50770Ee5',
#      'decimals': 18,
#      'methodABI': {'name': 'balanceOf',
#       'type': 'function',
#       'inputs': [{'name': '_user',
#         'type': 'address',
#         'internalType': 'address'}],
#       'outputs': [{'name': '', 'type': 'uint256', 'internalType': 'uint256'}],
#       'stateMutability': 'view'}},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x02480f3Fc4c53885f6b5d2eC723025C8ce0DE264',
#    '0xD5b790E299c7a46407c16E2Ec94B893046aB478E'],
#   'filters': {'minScore': 1, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 1,
#   'proposalsCount': 6,
#   'parent': None,
#   'children': []},
#  {'id': 'truegov.eth',
#   'name': 'TrueFi-Test',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'TRU',
#   'skin': None,
#   'domain': 'app.truefi.io',
#   'strategies': [{'name': 'contract-call',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0xf6E2Da7D82ee49f76CE652bc0BeB546Cbe0Ea521'],
#   'filters': {'minScore': 1500, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 2,
#   'proposalsCount': 0,
#   'parent': None,
#   'children': []},
#  {'id': 'keep2r.eth',
#   'name': 'Keep2r',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'KP2R',
#   'skin': 'synthetix',
#   'domain': 'gov.kp2r.network',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'KP2R',
#      'address': '0x9BdE098Be22658d057C3F1F185e3Fd4653E2fbD1',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x69ba033E6622e76f10C733A38aB8a9A6a6C1Ce4B',
#    '0x5E47b8155E4D66d5A88437D471e80daEb4Df9498',
#    '0xB2b4076a36b8993094cBfdb72512820B8BeDb6Ce',
#    '0xb058daD825A8E84cB453949bEFc4f7e77CaAa65E'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 1,
#   'proposalsCount': 2,
#   'parent': None,
#   'children': []},
#  {'id': 'meter-eth.eth',
#   'name': 'Meter Ethereum eMTRG',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'eMTRG',
#   'skin': None,
#   'domain': 'eMTRG.meter.io',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'eMTRG',
#      'address': '0xBd2949F67DcdC549c6Ebe98696449Fa79D988A9F',
#      'decimals': 18},
#     'network': '1'},
#    {'name': 'uniswap',
#     'params': {'symbol': 'eMTRG LPT',
#      'address': '0xBd2949F67DcdC549c6Ebe98696449Fa79D988A9F',
#      'decimals': 18},
#     'network': '1'},
#    {'name': 'balancer',
#     'params': {'symbol': 'eMTRG BPT',
#      'address': '0xBd2949F67DcdC549c6Ebe98696449Fa79D988A9F',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x0aB5ddA6f096E127AF74d4b64A101ac6C43FA128',
#    '0x78e6f3af2bf71afa209c6e81b161c6a41d2da79d',
#    '0xa755Cff7308Ac068c55EB141fbFDE822ee6FFcdd',
#    '0xf6B5FD8e2CAC43987DE603ce7942E09e2DC8A2C9'],
#   'filters': {'minScore': 100, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 5,
#   'proposalsCount': 2,
#   'parent': None,
#   'children': []},
#  {'id': 'meter-mainnet.eth',
#   'name': 'Meter Governance MTRG',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': 'Meter_IO',
#   'github': 'meterio',
#   'email': None,
#   'network': '82',
#   'symbol': 'MTRG',
#   'skin': None,
#   'domain': 'MTRG.meter.io',
#   'strategies': [{'name': 'contract-call',
#     'params': {'symbol': 'MTRG',
#      'address': '0x5729cb3716a315d0bde3b5e489163bf8b9659436',
#      'decimals': 18,
#      'methodABI': {'name': 'balanceOfBoundMtrg',
#       'type': 'function',
#       'inputs': [{'name': 'account',
#         'type': 'address',
#         'internalType': 'address'}],
#       'outputs': [{'name': '', 'type': 'uint256', 'internalType': 'uint256'}],
#       'stateMutability': 'view'}},
#     'network': '82'},
#    {'name': 'erc20-balance-of',
#     'params': {'symbol': 'MTRG',
#      'address': '0x228ebBeE999c6a7ad74A6130E81b12f9Fe237Ba3',
#      'decimals': 18},
#     'network': '82'}],
#   'admins': [],
#   'members': ['0x0aB5ddA6f096E127AF74d4b64A101ac6C43FA128',
#    '0x78e6f3af2bf71afa209c6e81b161c6a41d2da79d',
#    '0xa755Cff7308Ac068c55EB141fbFDE822ee6FFcdd',
#    '0xf6B5FD8e2CAC43987DE603ce7942E09e2DC8A2C9',
#    '0x0F8684F6dC76617D6831B4546381eb6CFB1C559F'],
#   'filters': {'minScore': 100, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 43,
#   'proposalsCount': 17,
#   'parent': None,
#   'children': []},
#  {'id': 'communitytoken.eth',
#   'name': 'Community Token',
#   'private': True,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'COM',
#   'skin': 'eth',
#   'domain': None,
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'COM',
#      'address': '0x1b4052d98fb1888c2bf3b8d3b930e0aff8a910df',
#      'decimals': 18},
#     'network': '1'},
#    {'name': 'contract-call',
#     'params': {'symbol': 'COM',
#      'address': '0xbB687EC3e1EfD71c58164147899DFEa54c9dAb6e',
#      'decimals': 18,
#      'methodABI': {'name': 'balanceOf',
#       'type': 'function',
#       'inputs': [{'name': 'voter',
#         'type': 'address',
#         'internalType': 'address'}],
#       'outputs': [{'name': '', 'type': 'uint256', 'internalType': 'uint256'}],
#       'stateMutability': 'view'}},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x95df7d90fc5822Ef1140Fb9aB37A9fF2a94356A2'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 0,
#   'proposalsCount': 0,
#   'parent': None,
#   'children': []},
#  {'id': 'ceproject.eth',
#   'name': 'CEProject',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'CEP',
#   'skin': None,
#   'domain': 'CEP',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'BDC',
#      'address': '0xa6e24154944bec5106ed416a6df1fb241ccb523b',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 0,
#   'proposalsCount': 1,
#   'parent': None,
#   'children': []},
#  {'id': 'dfking.eth',
#   'name': 'Defiking',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'DFK',
#   'skin': 'aave',
#   'domain': '',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 4,
#   'proposalsCount': 2,
#   'parent': None,
#   'children': []},
#  {'id': 'swarmnetwork.eth',
#   'name': 'Swarm Network',
#   'private': False,
#   'about': '',
#   'avatar': 'ipfs://QmRRdTZ4frqz69KfiK33rdGP4w6UECCD7ajNZvFSZnaM1r',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'SWM',
#   'skin': 'dforce',
#   'domain': 'https://snapshot.page/#/swarmnetwork.eth',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'SWM',
#      'address': '0x3505f494c3f0fed0b594e01fa41dd3967645ca39',
#      'decimals': 18},
#     'network': '1'},
#    {'name': 'masterchef-pool-balance',
#     'params': {'pid': '0',
#      'symbol': 'SWM',
#      'chefAddress': '0xE13c0Ec78D283eb8Cca72Edd018a9c13AD0E002a'},
#     'network': '1'},
#    {'name': 'masterchef-pool-balance',
#     'params': {'pid': '1',
#      'symbol': 'SWM',
#      'chefAddress': '0xE13c0Ec78D283eb8Cca72Edd018a9c13AD0E002a',
#      'uniPairAddress': '0xe0b1433e0174b47e8879ee387f1069a0dbf94137'},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x102D67E6d2BcdC5f66C079d4a383d3cefA5023b0',
#    '0xd56c6E89DA9F6cEab903878b98B1D91CfE1024D9'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 5,
#   'proposalsCount': 13,
#   'parent': None,
#   'children': []},
#  {'id': 'gokai.eth',
#   'name': 'Gokai',
#   'private': True,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'GKI',
#   'skin': 'gokai',
#   'domain': 'vote.gokai.org',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x71dFf12E24Db711b99a64a8A1d904cd256A49e58',
#    '0x41646Fb881Acd56bad144B343A3525B6907Bc86b'],
#   'filters': {'minScore': 10000, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 0,
#   'proposalsCount': 1,
#   'parent': None,
#   'children': []},
#  {'id': 'midas-defi.eth',
#   'name': 'Midas',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'MDS',
#   'skin': 'polyient-games-governance',
#   'domain': 'https://midas-defi.finance',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'MDS',
#      'address': '0x0290B327A8583bD6FA63c130B732a808864e55Fc',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': ['0x4150f70235FA3d017AA67b1eeaC377f46BD76953'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 0,
#   'proposalsCount': 2,
#   'parent': None,
#   'children': []},
#  {'id': 'btfinance.eth',
#   'name': 'BT.Finance',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'BT',
#   'skin': 'gene-finance',
#   'domain': 'vote.bt.finance',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'BT',
#      'address': '0x85E129b851d07D942e743f9444D637f57d3E3767',
#      'decimals': 9},
#     'network': '1'}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
# ...
#      'symbol': 'FLUX3days',
#      'address': '0x122E253B5D7544F09a67Ff72702f59a82baC868E',
#      'decimals': 18},
#     'network': '128'},
#    {'name': 'erc20-balance-of-coeff',
#     'params': {'coeff': 7,
#      'symbol': 'FLUX7days',
#      'address': '0x9198E353FE12786eA04152D51280D5BDB1A3DCe2',
#      'decimals': 18},
#     'network': '128'},
#    {'name': 'erc20-balance-of-coeff',
#     'params': {'coeff': 30,
#      'symbol': 'FLUX30days',
#      'address': '0xd0815947F6816Fc8565b9B68AfcA99E249C72ea6',
#      'decimals': 18},
#     'network': '128'}],
#   'admins': ['0xE7B6721fC8C9b313C2422200D2B05c9aB2F1A665',
#    '0x8A30b9440C13bCeFCEf04BAd5B98087Cc353Fc00',
#    '0x73AC875785523bf7D9C20D26393EC67607d2D923'],
#   'members': ['0xE7B6721fC8C9b313C2422200D2B05c9aB2F1A665',
#    '0x8A30b9440C13bCeFCEf04BAd5B98087Cc353Fc00',
#    '0x73AC875785523bf7D9C20D26393EC67607d2D923'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 8,
#   'proposalsCount': 3,
#   'parent': None,
#   'children': []},
#  {'id': 'flux-oec.eth',
#   'name': 'Flux-OEC DAO',
#   'private': False,
#   'about': '',
#   'avatar': 'ipfs://QmQThXm7cdmCq7feLW3Z47ZLYjjMGbhoZPUfdiwPrhKz8f',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': None,
#   'email': None,
#   'network': '66',
#   'symbol': 'FLUXK',
#   'skin': None,
#   'domain': 'https://flux.01.finance/',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'FLUXK',
#      'address': '0xd0C6821aba4FCC65e8f1542589e64BAe9dE11228',
#      'decimals': 18},
#     'network': '66'}],
#   'admins': ['0xE7B6721fC8C9b313C2422200D2B05c9aB2F1A665',
#    '0x8A30b9440C13bCeFCEf04BAd5B98087Cc353Fc00',
#    '0x73AC875785523bf7D9C20D26393EC67607d2D923'],
#   'members': ['0xE7B6721fC8C9b313C2422200D2B05c9aB2F1A665',
#    '0x8A30b9440C13bCeFCEf04BAd5B98087Cc353Fc00'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 14,
#   'proposalsCount': 0,
#   'parent': None,
#   'children': []},
#  {'id': 'unlock-protocol.eth',
#   'name': 'Unlock Protocol',
#   'private': False,
#   'about': 'Unlock is a protocol for memberships',
#   'avatar': 'ipfs://bafkreihlcpcef2zlgfgopzjstdp4e2mhqnms5om3iqattbbzvnt6vfjp3a',
#   'terms': None,
#   'location': None,
#   'website': 'https://unlock-protocol.com',
#   'twitter': 'unlockprotocol',
#   'github': 'unlock-protocol',
#   'email': None,
#   'network': '1',
#   'symbol': 'UDT',
#   'skin': 'eth',
#   'domain': 'vote.unlock-protocol.com',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'UDT',
#      'address': '0x90de74265a416e1393a450752175aed98fe11517',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': ['0x4Ce2DD8373ECe0d7baAA16E559A5817CC875b16a'],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 140,
#   'proposalsCount': 22,
#   'parent': None,
#   'children': []},
#  {'id': 'rcubedao.eth',
#   'name': 'RETRO DEFI ',
#   'private': False,
#   'about': "RETRO DEFI is a User-Governed Ecosystem | Yield Farming | Gaming | NFT's",
#   'avatar': 'https://ipfs.io/ipfs/QmfGopwH2MqpgbvYx5Ym8UsHDrAmGp6nEN8EPnXfDPqqfi?filename=retroflogo.png',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': 'retrodefi',
#   'github': 'retrodefi',
#   'email': None,
#   'network': '56',
#   'symbol': 'RCUBE',
#   'skin': 'benchmark',
#   'domain': None,
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'RCUBE',
#      'address': '0xa6e53f07bd410df069e20ced725bdc9135146fe9',
#      'decimals': 18},
#     'network': '56'},
#    {'name': 'contract-call',
#     'params': {'symbol': 'RCUBE',
#      'address': '0xa6e53f07bd410df069e20ced725bdc9135146fe9',
#      'decimals': 18},
#     'network': '56'}],
#   'admins': ['0xB5c8f28AB36Cee8481a720D2D9561832e790782C'],
#   'members': [],
#   'filters': {'minScore': 2500, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 1,
#   'proposalsCount': 0,
#   'parent': None,
#   'children': []},
#  {'id': 'metta.eth',
#   'name': 'Mettā Creative',
#   'private': False,
#   'about': 'To allow participation of MTTA token holders in the governance of Mettā Creative DAO ',
#   'avatar': 'https://gateway.pinata.cloud/ipfs/QmSHJbQPREbDqbbzS7X1hTsnM5JbkiKytygqSp4XhueqdW',
#   'terms': 'https://www.thebackyard.world/terms-and-conditions',
#   'location': None,
#   'website': None,
#   'twitter': 'mettamakers',
#   'github': 'mettamakers',
#   'email': None,
#   'network': '1',
#   'symbol': 'mtta',
#   'skin': 'eth',
#   'domain': 'https://mettacreative.world/token',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'MTTA',
#      'address': '0x0Df6b23127cfd1C931000cbB452a0D75A716c3cd',
#      'decimals': 2},
#     'network': '1'}],
#   'admins': ['0xD2f793D5f65449e6992e0c9c52A7334b62e5ec6c'],
#   'members': ['0x713A60bc9FB6D8527ACF956dc92b11f253b0512d',
#    '0xDE31A8E636E1222E736ff0Fe7e4e95aCb0018C6E',
#    '0xbD8C79740Bf625F5054E86a2CE4e73879382f923'],
#   'filters': {'minScore': 100, 'onlyMembers': True},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 0,
#   'proposalsCount': 1,
#   'parent': None,
#   'children': []},
#  {'id': 'icebrk.eth',
#   'name': 'Icebreak-R',
#   'private': False,
#   'about': 'ICEBRK token is the governance and utility token for the IceBreak-R Network, a social media driven NFT-marketplace and DeFi ecosystem.',
#   'avatar': 'https://icebreak-r.com/wp-content/uploads/2021/06/icebreakr-logo-social.png',
#   'terms': 'https://icebreak-r.com/disclaimer/',
#   'location': None,
#   'website': 'https://icebreak-r.com',
#   'twitter': 'ICEBRKofficial',
#   'github': None,
#   'email': None,
#   'network': '250',
#   'symbol': 'ICEBRK',
#   'skin': 'synthetix',
#   'domain': None,
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'ICEBRK',
#      'address': '0xc6E3f3083a15468350976369898381Eec5cfE10f',
#      'decimals': 9},
#     'network': '250'},
#    {'name': 'erc20-balance-of',
#     'params': {'symbol': 'ICEDOGE',
#      'address': '0xF007fb98c537aaf892dfb04e794dFEbbE9aDCfc6',
#      'decimals': 9},
#     'network': '250'}],
#   'admins': ['0x30bc20753b325C7F7B3e55daEB464C348C5e8096',
#    '0x721700d0DC44058B8Dc855840464489210Ca1457'],
#   'members': ['0x721700d0DC44058B8Dc855840464489210Ca1457',
#    '0x30bc20753b325C7F7B3e55daEB464C348C5e8096',
#    '0xBA189a4F264f5A434B5DCD49Df5aB150DD0e54Ae',
#    '0xa587a1694ec8b2e7dcb1cf3ed3ac3f8b4953f938',
#    '0x0bb354811980410fd515a5d5f0fbd484dbbc93d5',
#    '0xffdcab633846a6f90a1084a914f988f2c4e3e3da'],
#   'filters': {'minScore': 2000, 'onlyMembers': True},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': 259200,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': ['protocol'],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [{'name': 'ICEBRKDAO',
#     'address': '0x855bC77b8429D26b89f74fc8352f944a12F4729D',
#     'network': '250'}],
#   'followersCount': 12,
#   'proposalsCount': 21,
#   'parent': None,
#   'children': []},
#  {'id': 'marbleclash.eth',
#   'name': 'MarbleClash',
#   'private': False,
#   'about': 'The first game based on MarbleCards',
#   'avatar': 'https://www.marbleclash.cards/media/cache/MarbleClash/marble-clash-logo.svg',
#   'terms': 'https://www.marbleclash.cards/Terms-and-conditions',
#   'location': None,
#   'website': None,
#   'twitter': 'MarbleCardsInfo',
#   'github': None,
#   'email': None,
#   'network': '1',
#   'symbol': 'MBC',
#   'skin': None,
#   'domain': 'https://www.marbleclash.cards/',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'MBC',
#      'address': '0x8888889213DD4dA823EbDD1e235b09590633C150',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 0,
#   'proposalsCount': 3,
#   'parent': None,
#   'children': []},
#  {'id': 'apestreet.eth',
#   'name': 'Ape Street',
#   'private': False,
#   'about': 'Decentralizing the Financial World',
#   'avatar': 'ipfs://QmaZx3gvykaohoHhvjjosafGurDMYB67dT3gdGYn78oPjT',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': 'apestreet',
#   'github': 'ape-street',
#   'email': None,
#   'network': '1',
#   'symbol': 'APE',
#   'skin': 'barnbridge',
#   'domain': None,
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 11,
#   'proposalsCount': 11,
#   'parent': None,
#   'children': []},
#  {'id': 'frenchienetwork.eth',
#   'name': 'Frenchie Network',
#   'private': False,
#   'about': '',
#   'avatar': 'ipfs://QmQBF4iRRi5eieh9L6Garba7aEPptu8SGgwwet4NftfrcX',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': 'frenchietoken',
#   'github': None,
#   'email': None,
#   'network': '56',
#   'symbol': 'FREN',
#   'skin': 'fries',
#   'domain': 'vote.frenchie.so',
#   'strategies': [{'name': 'erc20-with-balance',
#     'params': {'symbol': 'FREN',
#      'address': '0x13958e1eb63dfb8540eaf6ed7dcbbc1a60fd52af',
#      'decimals': 18},
#     'network': '56'},
#    {'name': 'erc20-balance-of',
#     'params': {'symbol': 'FREN',
#      'address': '0x13958e1eb63dfb8540eaf6ed7dcbbc1a60fd52af',
#      'decimals': 18},
#     'network': '56'}],
#   'admins': ['0x6ED8CD17EE5453E17eb731a6B2004aF53eA1f26a'],
#   'members': ['0x6ED8CD17EE5453E17eb731a6B2004aF53eA1f26a'],
#   'filters': {'minScore': 1000000000, 'onlyMembers': False},
#   'plugins': {'quorum': {'total': 50000000000, 'strategy': 'static'}},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 2,
#   'proposalsCount': 1,
#   'parent': None,
#   'children': []},
#  {'id': 'mintlaab.eth',
#   'name': 'Mintlaab',
#   'private': False,
#   'about': '',
#   'avatar': '',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': None,
#   'github': 'mintlaab',
#   'email': None,
#   'network': '1',
#   'symbol': 'DAI',
#   'skin': None,
#   'domain': None,
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'ETH',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18},
#     'network': '1'}],
#   'admins': ['0x1700c12BC9F2D6963B71d3022301A8d326796865',
#    '0xD710B4cbF1A4E510F6c6e9245c5Cb65c4eB3Dc02'],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 0,
#   'proposalsCount': 0,
#   'parent': None,
#   'children': []},
#  {'id': 'longdrinkfinance.eth',
#   'name': 'Longdrink Finance',
#   'private': False,
#   'about': 'Longdrink Finance is the leading index protocol on BSC',
#   'avatar': 'ipfs://QmbBnYqchmSffBPe9jzx8NMxk5ULRCoQsURT4aKKE3BwUU',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': 'LongdrinkDefi',
#   'github': 'LongdrinkDefi',
#   'email': None,
#   'network': '56',
#   'symbol': 'LONG',
#   'skin': 'dfi',
#   'domain': 'vote.longdrink.finance',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'vLong',
#      'address': '0x6F49e0311419eDc6879F8d3d60E49f1eDb7A257E',
#      'decimals': 18},
#     'network': '56'}],
#   'admins': ['0x33756a0A837Ec2babee7244bb6D5793FD7306818',
#    '0xd9811FF259869e9bC23d77EEBAc7C3f01DB68D33'],
#   'members': ['0x33756a0A837Ec2babee7244bb6D5793FD7306818',
#    '0xd9811FF259869e9bC23d77EEBAc7C3f01DB68D33'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 0,
#   'proposalsCount': 4,
#   'parent': None,
#   'children': []},
#  {'id': 'chimpyswap.eth',
#   'name': 'ChimpySwap',
#   'private': False,
#   'about': 'ChimpySwap is a decentralized exchange on Binance Smart Chain',
#   'avatar': 'ipfs://QmTo3uV2nTGht4CeyKLn9D4uv3UrtCXHdujN418VNmfP4Z',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': 'ChimpySwap',
#   'github': 'chimpyswap',
#   'email': None,
#   'network': '56',
#   'symbol': 'CHIMPY',
#   'skin': 'eth',
#   'domain': 'voting.chimpyswap.com',
#   'strategies': [{'name': 'pancake',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18},
#     'network': '56'}],
#   'admins': ['0x4C9093bF32814BD705bA5A7FecF799ce74C0C85f'],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 9,
#   'proposalsCount': 0,
#   'parent': None,
#   'children': []},
#  {'id': 'ldt.eth',
#   'name': 'LENDOO',
#   'private': False,
#   'about': 'lendoo is a lend protocol. website: https://lendoo.finance',
#   'avatar': 'ipfs://QmTfopCwNghwRpqJ3TGQWp2LBuyGqwJNPxcW3TF7Cngmpv',
#   'terms': None,
#   'location': None,
#   'website': None,
#   'twitter': 'Lendoo_finance',
#   'github': 'Lendoo-lab',
#   'email': None,
#   'network': '70',
#   'symbol': 'GLDT',
#   'skin': None,
#   'domain': 'gov.lendoo.finance',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'GLDT',
#      'address': '0xB856F232f1Eb62bd9E301287631A168b9A5C68dE',
#      'decimals': 18},
#     'network': '70'}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {},
#   'voting': {'delay': None,
#    'period': None,
#    'type': None,
#    'quorum': None,
#    'blind': False,
#    'hideAbstain': False,
#    'privacy': ''},
#   'categories': [],
#   'validation': {'name': 'basic', 'params': {}, 'network': None},
#   'treasuries': [],
#   'followersCount': 8,
#   'proposalsCount': 8,
#   'parent': None,
#   'children': []},
#  ...]

# %% [markdown]
# **Exercise: verify that you can import the file containing the spaces that just saved**

# %%
spaces = pd_read_json("data/snapshot_spaces.json")

# %% [markdown]
# **Exercise: plot the relationship between followers and proposals across DAOs**
#
# Question: ...and votes?
# Bonus: jitter the dots, and try log scales.

# %%
spaces = pd.DataFrame(res)
spaces.info()
## Your code here.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11195 entries, 0 to 11194
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              11195 non-null  object
#  1   name            11195 non-null  object
#  2   private         11195 non-null  bool
#  3   about           11195 non-null  object
#  4   avatar          11195 non-null  object
#  5   terms           858 non-null    object
#  6   location        7 non-null      object
#  7   website         2337 non-null   object
#  8   twitter         4831 non-null   object
#  9   github          1876 non-null   object
#  10  email           1 non-null      object
#  11  network         11195 non-null  object
#  12  symbol          11195 non-null  object
#  13  skin            2987 non-null   object
#  14  domain          2375 non-null   object
#  15  strategies      11195 non-null  object
#  16  admins          11195 non-null  object
#  17  members         11195 non-null  object
#  18  filters         11195 non-null  object
#  19  plugins         11195 non-null  object
#  20  voting          11195 non-null  object
#  21  categories      11195 non-null  object
#  22  validation      11195 non-null  object
#  23  treasuries      11195 non-null  object
#  24  followersCount  11195 non-null  int64
#  25  proposalsCount  11195 non-null  int64
#  26  parent          109 non-null    object
#  27  children        11195 non-null  object
# dtypes: bool(1), int64(2), object(25)
# memory usage: 2.3+ MB

# %% [markdown]
# ### Checking last week home assignment.
#
# - Pick a small (<1k), medium (<10k), and large  DAO (10k+)
# - Get all members (if possible try different APIs)
# - Order them by wealth in ETH
# - Compute correlation ETH wealth and number of votes in the DAO

# %% [markdown]
# Let's see whether our cutpoints make sense.

# %%
def dao_size(x, T1=1000, T2=10000):
    if x < T1: return "small"
    if x < T2: return "medium"
    return "large"

spaces['size'] = spaces['followersCount'].apply(dao_size)

# %%
spaces['size'].value_counts()
# Out:
# small     11046
# medium      125
# large        24
# Name: size, dtype: int64

# %% [markdown]
# Most of the DAOs are rather small in size.

# %%
spaces['followersCount'].describe()
# Out:
# count     11195.000000
# mean        128.714873
# std        1919.442484
# min           0.000000
# 25%           1.000000
# 50%           3.000000
# 75%          11.000000
# max      102707.000000
# Name: followersCount, dtype: float64

# %%
spaces10 = spaces[spaces['followersCount'] >= 10]
spaces10.describe()
# Out:
#        followersCount  proposalsCount
# count     3030.000000     3030.000000
# mean       469.416172       15.963696
# std       3668.291515       65.501408
# min         10.000000        0.000000
# 25%         16.000000        2.000000
# 50%         31.500000        4.000000
# 75%         92.750000       11.000000
# max     102707.000000     2264.000000

# %%
sm = spaces10[spaces10['size'] == "small"].sample(1)
sm[['name', 'followersCount', 'website']]
# Out:
#              name  followersCount website
# 5432  Nuke Vaults              20    None

# %%
## id = hashflowdao.eth
DAO_ID = "hashflowdao.eth"
# DAO_ID = sm['id'].iloc[0]

# %%
query_followers = gq("snapshot_followers_of_space")
followers = await gql_all(query_followers, 
        field="follows", 
        vars={'space': DAO_ID }
    )
# Out:
# 1 974
# **I am done fetching!**

# %%
len(followers)
# Out:
# 949

# %%
followers = pd.DataFrame(followers)
followers.head()
# Out:
#                                      follower
# 0  0x6430F34e563C719a74cDf9bdD565bc569B1CDf51
# 1  0xE199ea2CdCcDD08d793c2d25AE5b974cb38fCA72
# 2  0xa944e92483DDC42e70358760d4A5276be8e82767
# 3  0x969FB247acDD7c8e1dA46620e7C70521D37d4f94
# 4  0x3238e4dbb25EFEFc5d00624F949bc40e719a6F27

# %%
print(sum(followers.duplicated()))
# Out:
# 0

# %% [markdown]
# Now we want to get the **wealth** in ETH of the followers.
#
# Etherscan's api is quite handy...
#
# **Exercise: finish the function below**

# %%
from etherscan import Etherscan
import json

with open("../3_api/.private/keys.json") as keys_file:
    KEYS = json.load(keys_file)

APIKEY = KEYS['ETHERSCAN']
eth = Etherscan(APIKEY)

# %%
def get_eth_wealth(addresses, K=20, limit=None):
    
    idx = 0
    counter = 0
    eth_wealth = []
    n_addresses = len(addresses)
    
    while (idx < n_addresses) and (limit is None or counter < limit):
        
        ## Your code here.
        my_addresses = addresses[idx: idx+K]
        res = eth.get_eth_balance_multiple(my_addresses)
        eth_wealth += res
        idx += K
        counter += 1
        print(counter, idx, len(eth_wealth))
    
    print('**Got all of them!')
    return eth_wealth

# %%
eth_wealth = get_eth_wealth(followers['follower'])
# Out:
# 1 20 20
# 2 40 40
# 3 60 60
# 4 80 80
# 5 100 100
# 6 120 120
# 7 140 140
# 8 160 160
# 9 180 180
# 10 200 200
# 11 220 220
# 12 240 240
# 13 260 260
# 14 280 280
# 15 300 300
# 16 320 320
# 17 340 340
# 18 360 360
# 19 380 380
# 20 400 400
# 21 420 420
# 22 440 440
# 23 460 460
# 24 480 480
# 25 500 500
# 26 520 520
# 27 540 540
# 28 560 560
# 29 580 580
# 30 600 600
# 31 620 620
# 32 640 640
# 33 660 660
# 34 680 680
# 35 700 700
# 36 720 720
# 37 740 740
# 38 760 760
# 39 780 780
# 40 800 800
# 41 820 820
# 42 840 840
# 43 860 860
# 44 880 880
# 45 900 900
# 46 920 920
# 47 940 940
# 48 960 960
# 49 980 974
# **Got all of them!

# %%
len(eth_wealth)
# Out:
# 974

# %%
sm_wealth = pd.DataFrame(eth_wealth)

# %%
sm_wealth.head()
# Out:
#                                       account             balance
# 0  0x6430F34e563C719a74cDf9bdD565bc569B1CDf51  158086424803534476
# 1  0xE199ea2CdCcDD08d793c2d25AE5b974cb38fCA72  143360324733880574
# 2  0xa944e92483DDC42e70358760d4A5276be8e82767    1606900959375449
# 3  0x969FB247acDD7c8e1dA46620e7C70521D37d4f94     678944184894282
# 4  0x3238e4dbb25EFEFc5d00624F949bc40e719a6F27  101023656105411008

# %% [markdown]
# Get the votes of the space.

# %%
query_votes = gq("snapshot_votes_of_space")
votes = await gql_all(query_votes, 
        field="votes",         
        vars={'space': DAO_ID }
    )
# Out:
# 1 1000
# 2 2000
# 3 2900
# **I am done fetching!**

# %%
votes = pd.DataFrame(votes)
votes.info()
votes.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2900 entries, 0 to 2899
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              2900 non-null   object
#  1   ipfs            2900 non-null   object
#  2   voter           2900 non-null   object
#  3   created         2900 non-null   int64
#  4   space           2900 non-null   object
#  5   proposal        2900 non-null   object
#  6   choice          2900 non-null   int64
#  7   metadata        2900 non-null   object
#  8   reason          2900 non-null   object
#  9   app             2900 non-null   object
#  10  vp              2900 non-null   int64
#  11  vp_by_strategy  2900 non-null   object
#  12  vp_state        2900 non-null   object
# dtypes: int64(3), object(10)
# memory usage: 294.7+ KB
#                                                   id  \
# 0  0xe59241a0c7caa7df80b59699db152e062ae0f979e6b1...
# 1  0xf7eb9e85f2be15b9c064489573fe97a0c11de2ab1292...
# 2  0x663cf2e839c1d483718887639d3fc6172f1bad207146...
# 3  0x97d7c5eab61e6f98063caefe67cb559b4d964ca4f73a...
# 4  0xf2c3ff59b8f86d850f204b2368b560dc5615dc63edee...
#
#                                              ipfs  \
# 0  Qmafz3CUF3DurMLwZWVcdzpvaXwSr3VdCnaPiQtnCUdDLX
# 1  QmWASPkMqKVSAjCLozkdt5Aa6FK77jGPdLZhh1fU9JqKRQ
# 2  QmUjkVGDiwf8rEwko2YWownhJpDN1xYnLVnqLUnDqhLKke
# 3  QmWLasNke1mKYvkmQgj7uk2vNCsthSKi6TuCwV5MUEtEK7
# 4  QmPkstby2HozH1DUxx6vM1ShYPQzEoKUFA7rBq5kwFoB6u
#
#                                         voter     created  \
# 0  0x1BaA7E3DDA9480f2fff7a62cFB92B56c0B35456E  1651420795
# 1  0x298d0f26472e364Ea84090C80B09b187098F84b8  1651420749
# 2  0x8Fffb08a892B348C3df82695F55F866D85BCD358  1651420689
# 3  0x31A95aDAa9435f6381Ab41b38C6C8150Bcb845E9  1651420640
# 4  0xf517C1A78d0769B7BEdF26217e4FcAe4C727D0a0  1651420188
#
#                        space  \
# 0  {'id': 'hashflowdao.eth'}
# 1  {'id': 'hashflowdao.eth'}
# 2  {'id': 'hashflowdao.eth'}
# 3  {'id': 'hashflowdao.eth'}
# 4  {'id': 'hashflowdao.eth'}
#
#                                             proposal  choice metadata reason  \
# 0  {'id': '0x886f9da80077ffeac2269b9d9a4bdc60f5ff...       1       {}
# 1  {'id': '0x886f9da80077ffeac2269b9d9a4bdc60f5ff...       1       {}
# 2  {'id': '0x886f9da80077ffeac2269b9d9a4bdc60f5ff...       1       {}
# 3  {'id': '0x886f9da80077ffeac2269b9d9a4bdc60f5ff...       1       {}
# 4  {'id': '0x886f9da80077ffeac2269b9d9a4bdc60f5ff...       1       {}
#
#   app  vp vp_by_strategy vp_state
# 0       1            [1]    final
# 1       1            [1]    final
# 2       1            [1]    final
# 3       1            [1]    final
# 4       1            [1]    final

# %% [markdown]
# **Exercise: Unnest proposal id.**

# %%
## Your code here.
votes["space"] = votes.space.map(lambda x: x['id'])
votes["proposal"] = votes.proposal.map(lambda x: x['id'])

# %%
votes.head()
# Out:
#                                                   id  \
# 0  0xe59241a0c7caa7df80b59699db152e062ae0f979e6b1...
# 1  0xf7eb9e85f2be15b9c064489573fe97a0c11de2ab1292...
# 2  0x663cf2e839c1d483718887639d3fc6172f1bad207146...
# 3  0x97d7c5eab61e6f98063caefe67cb559b4d964ca4f73a...
# 4  0xf2c3ff59b8f86d850f204b2368b560dc5615dc63edee...
#
#                                              ipfs  \
# 0  Qmafz3CUF3DurMLwZWVcdzpvaXwSr3VdCnaPiQtnCUdDLX
# 1  QmWASPkMqKVSAjCLozkdt5Aa6FK77jGPdLZhh1fU9JqKRQ
# 2  QmUjkVGDiwf8rEwko2YWownhJpDN1xYnLVnqLUnDqhLKke
# 3  QmWLasNke1mKYvkmQgj7uk2vNCsthSKi6TuCwV5MUEtEK7
# 4  QmPkstby2HozH1DUxx6vM1ShYPQzEoKUFA7rBq5kwFoB6u
#
#                                         voter     created            space  \
# 0  0x1BaA7E3DDA9480f2fff7a62cFB92B56c0B35456E  1651420795  hashflowdao.eth
# 1  0x298d0f26472e364Ea84090C80B09b187098F84b8  1651420749  hashflowdao.eth
# 2  0x8Fffb08a892B348C3df82695F55F866D85BCD358  1651420689  hashflowdao.eth
# 3  0x31A95aDAa9435f6381Ab41b38C6C8150Bcb845E9  1651420640  hashflowdao.eth
# 4  0xf517C1A78d0769B7BEdF26217e4FcAe4C727D0a0  1651420188  hashflowdao.eth
#
#                                             proposal  choice metadata reason  \
# 0  0x886f9da80077ffeac2269b9d9a4bdc60f5ff158e0f93...       1       {}
# 1  0x886f9da80077ffeac2269b9d9a4bdc60f5ff158e0f93...       1       {}
# 2  0x886f9da80077ffeac2269b9d9a4bdc60f5ff158e0f93...       1       {}
# 3  0x886f9da80077ffeac2269b9d9a4bdc60f5ff158e0f93...       1       {}
# 4  0x886f9da80077ffeac2269b9d9a4bdc60f5ff158e0f93...       1       {}
#
#   app  vp vp_by_strategy vp_state
# 0       1            [1]    final
# 1       1            [1]    final
# 2       1            [1]    final
# 3       1            [1]    final
# 4       1            [1]    final

# %%
votes['proposal'].value_counts()
# Out:
# 0x886f9da80077ffeac2269b9d9a4bdc60f5ff158e0f9312f96be0af081b1a5963    2900
# Name: proposal, dtype: int64

# %%
votes['voter'].value_counts()
# Out:
# 0x1BaA7E3DDA9480f2fff7a62cFB92B56c0B35456E    1
# 0xD42f7148D63e567126f3F436B745C3ADa2F2aFA6    1
# 0xCA241c81f27161C753fD11DDEd3B8738E3D1B62E    1
# 0xb6F00a713153Cbaf39FB0BfdE52AdD5795a43C80    1
# 0xF76bf0f87E42Ce159fbD9b730fA9c676dE43c716    1
#                                              ..
# 0x27670a5383D252fD7028ce7FE55A6a68127E8Ce1    1
# 0x5426e265e7681C29746009841dE3d369C840C556    1
# 0x5B15AAB04EC5E3058AB2921A8F2f94FD26ed581C    1
# 0x32388db1e4AF84ac25742c76C4731025DA0E8f3B    1
# 0xFf918a3Ff6CCc3722197B555a7a30de9A37906dB    1
# Name: voter, Length: 2900, dtype: int64

# %%
votes['choice'].value_counts()
# Out:
# 1    1630
# 2    1143
# 3     127
# Name: choice, dtype: int64

# %% [markdown]
# We have more votes than followers...\
# After inquirying with Snapshot staff on Discord, **it is possible to vote without following an organization.**\
# Let's get the wealth of all voters.

# %%
eth_wealth2 = get_eth_wealth(votes['voter'])
# Out:
# 1 20 20
# 2 40 40
# 3 60 60
# 4 80 80
# 5 100 100
# 6 120 120
# 7 140 140
# 8 160 160
# 9 180 180
# 10 200 200
# 11 220 220
# 12 240 240
# 13 260 260
# 14 280 280
# 15 300 300
# 16 320 320
# 17 340 340
# 18 360 360
# 19 380 380
# 20 400 400
# 21 420 420
# 22 440 440
# 23 460 460
# 24 480 480
# 25 500 500
# 26 520 520
# 27 540 540
# 28 560 560
# 29 580 580
# 30 600 600
# 31 620 620
# 32 640 640
# 33 660 660
# 34 680 680
# 35 700 700
# 36 720 720
# 37 740 740
# 38 760 760
# 39 780 780
# 40 800 800
# 41 820 820
# 42 840 840
# 43 860 860
# 44 880 880
# 45 900 900
# 46 920 920
# 47 940 940
# 48 960 960
# 49 980 980
# 50 1000 1000
# 51 1020 1020
# 52 1040 1040
# 53 1060 1060
# 54 1080 1080
# 55 1100 1100
# 56 1120 1120
# 57 1140 1140
# 58 1160 1160
# 59 1180 1180
# 60 1200 1200
# 61 1220 1220
# 62 1240 1240
# 63 1260 1260
# 64 1280 1280
# 65 1300 1300
# 66 1320 1320
# 67 1340 1340
# 68 1360 1360
# 69 1380 1380
# 70 1400 1400
# 71 1420 1420
# 72 1440 1440
# 73 1460 1460
# 74 1480 1480
# 75 1500 1500
# 76 1520 1520
# 77 1540 1540
# 78 1560 1560
# 79 1580 1580
# 80 1600 1600
# 81 1620 1620
# 82 1640 1640
# 83 1660 1660
# 84 1680 1680
# 85 1700 1700
# 86 1720 1720
# 87 1740 1740
# 88 1760 1760
# 89 1780 1780
# 90 1800 1800
# 91 1820 1820
# 92 1840 1840
# 93 1860 1860
# 94 1880 1880
# 95 1900 1900
# 96 1920 1920
# 97 1940 1940
# 98 1960 1960
# 99 1980 1980
# 100 2000 2000
# 101 2020 2020
# 102 2040 2040
# 103 2060 2060
# 104 2080 2080
# 105 2100 2100
# 106 2120 2120
# 107 2140 2140
# 108 2160 2160
# 109 2180 2180
# 110 2200 2200
# 111 2220 2220
# 112 2240 2240
# 113 2260 2260
# 114 2280 2280
# 115 2300 2300
# 116 2320 2320
# 117 2340 2340
# 118 2360 2360
# 119 2380 2380
# 120 2400 2400
# 121 2420 2420
# 122 2440 2440
# 123 2460 2460
# 124 2480 2480
# 125 2500 2500
# 126 2520 2520
# 127 2540 2540
# 128 2560 2560
# 129 2580 2580
# 130 2600 2600
# 131 2620 2620
# 132 2640 2640
# 133 2660 2660
# 134 2680 2680
# 135 2700 2700
# 136 2720 2720
# 137 2740 2740
# 138 2760 2760
# 139 2780 2780
# 140 2800 2800
# 141 2820 2820
# 142 2840 2840
# 143 2860 2860
# 144 2880 2880
# 145 2900 2900
# **Got all of them!

# %%
eth_wealth2
# Out:
# [{'account': '0x1BaA7E3DDA9480f2fff7a62cFB92B56c0B35456E',
#   'balance': '9227623336239750'},
#  {'account': '0x298d0f26472e364Ea84090C80B09b187098F84b8',
#   'balance': '1313058536808346'},
#  {'account': '0x8Fffb08a892B348C3df82695F55F866D85BCD358',
#   'balance': '4938400684681228'},
#  {'account': '0x31A95aDAa9435f6381Ab41b38C6C8150Bcb845E9',
#   'balance': '10346809650713943'},
#  {'account': '0xf517C1A78d0769B7BEdF26217e4FcAe4C727D0a0',
#   'balance': '8098745663244817'},
#  {'account': '0xCb6012f6E83e73AEb0f8fE650FAF1f64BcdA2709',
#   'balance': '6658581243856640'},
#  {'account': '0x4f6420E54191389555d33C0850E8eC66dcCBcD45',
#   'balance': '42246827870140413'},
#  {'account': '0xd2F7Bb62504FBe33e3038bf2fefAEaB42bad88B3',
#   'balance': '38044711527633304'},
#  {'account': '0xf938097bd64b0f9C969983B361a07EdFE9143552',
#   'balance': '111300005548672131'},
#  {'account': '0x68a78F3b7Ed88a22e5e158320e0d15B52eDFa312',
#   'balance': '28200984544995111'},
#  {'account': '0x8adFc6e6E6DA6Ed9aF7F094B3f3115ED72048395',
#   'balance': '89193638863415572'},
#  {'account': '0x45054fe2A75d6A87eBe9BA6A70F97B24AAa0aAF5',
#   'balance': '356505000000000'},
#  {'account': '0xD0246aA2e5Ab6859876EC143FD766e7e64744E58',
#   'balance': '356505000000000'},
#  {'account': '0x50A7F68482CC626a041A92B4020b58102009F4b9',
#   'balance': '51263783535184546'},
#  {'account': '0xDf3458AFBCF1Cc144DfA91DC534cF9d12CcBFD75',
#   'balance': '356633000000000'},
#  {'account': '0xAeC14EC7C4341AD6980534C9E91A7FbB9574d185',
#   'balance': '356585000000000'},
#  {'account': '0xC89ebC3aB47AbDFa150d6e880Dd44d8250C5a904',
#   'balance': '961158000000000'},
#  {'account': '0x81B95e0a9c274881bF34A1dEa0494011353882E7',
#   'balance': '356585000000000'},
#  {'account': '0x527ddEabA639E360c492C6CC4f9eBab8cb485CA7',
#   'balance': '356585000000000'},
#  {'account': '0xa1Bcd69B831fd130C4de549065Fb68e2469FC6fF',
#   'balance': '356585000000000'},
#  {'account': '0x7DEa927E7708BBb449c16b8C9D1b0771262eA997',
#   'balance': '356585000000000'},
#  {'account': '0xA377094F8EcfAe21D9eCb23De1662B491BFc9A9f',
#   'balance': '356585000000000'},
#  {'account': '0x26cDD75acD2346a88D3EfE5385D01689ff2D5670',
#   'balance': '356553000000000'},
#  {'account': '0xd54f254558415336d195D9418eF5fd9A0aDaAb5E',
#   'balance': '10350592789024851'},
#  {'account': '0xCfa9022b903e40bb1e35A6e50a821CBb08172d45',
#   'balance': '356585000000000'},
#  {'account': '0x6F69a118e4C79d8Dee8287a70864F107948da0C3',
#   'balance': '356633000000000'},
#  {'account': '0xD6B6edd45dA7F9D3477Ba1881f32453CFa81dCB7',
#   'balance': '39959702412000'},
#  {'account': '0xcee4f7EC63bbeaA366742389A7c587A3163d45C8',
#   'balance': '356585000000000'},
#  {'account': '0xF862192C8060Eb70154FeAf9CBEC45F9e3d4255a',
#   'balance': '356681000000000'},
#  {'account': '0x3E5fB0dF946B5e428a6f1934Cd627F0238CD7F8e',
#   'balance': '356585000000000'},
#  {'account': '0x99EB232f69aed0CB1149CDff4A16141D0f6345E7',
#   'balance': '356585000000000'},
#  {'account': '0x27fF1323531C5f7d01C24C4ba535Fcca9217Cf50',
#   'balance': '795678142250242'},
#  {'account': '0x27Ba99bE029A813Fb49D47E5989F56589b49a3a4',
#   'balance': '758981770012923'},
#  {'account': '0x19B5283e0672c4518d1638B86Dc998386A488ee3',
#   'balance': '51112350741596955'},
#  {'account': '0xBD129349ec13aD73c279047cf1ae66454373161b',
#   'balance': '1352525046467266'},
#  {'account': '0x271D8e39108990e89DE0aEf49275A194269b58c5',
#   'balance': '6559344297005588'},
#  {'account': '0xda3b46e7506Eb94A9A37475E214d5d75f5555309',
#   'balance': '249338632385269613'},
#  {'account': '0x1D1569E8ECb88C0cb35F8920649f1aa66173A8Bc',
#   'balance': '20676743097847704'},
#  {'account': '0xFff6C947cef2Bb33Dd3e6A79600e3D2c1cA6D7cc',
#   'balance': '529542800946628651'},
#  {'account': '0xabEc53AD5BaFc9088d7140dd517a924D43564Fe0',
#   'balance': '49282791075295473'},
#  {'account': '0x545A2B389C7196fd79c8777BFC4e82A5FFA3e042',
#   'balance': '473372061363494083'},
#  {'account': '0x9C24Fe1dCbFb393da6b384ec6FB1cE30502C0eFB',
#   'balance': '527513380490894083'},
#  {'account': '0x5cE63dB7A09deFded434C6a29D7556963f8A7a45',
#   'balance': '478347505666046083'},
#  {'account': '0xAacBDEd6b950F31106b359F124683cCc608e8722',
#   'balance': '509338194941006083'},
#  {'account': '0xe57AFD4fAeDaE0862D95AB713A053Df0136f6bA2',
#   'balance': '15605961220825439'},
#  {'account': '0x859DA71b23337171b863e02C503C3C61BBC74c6a',
#   'balance': '10788469891600259'},
#  {'account': '0x94a1f89ca35A03381E1A2C60ADB64246f21e3d26',
#   'balance': '2170806772370174'},
#  {'account': '0x8D81e62C916B572b5AF8f5F1433a2E4e9d39292D',
#   'balance': '45368176405837604'},
#  {'account': '0x6b89b3BaBC1de4A9C78f73c4d48C847C285CBAd2',
#   'balance': '482626418932406083'},
#  {'account': '0xf78504C4aE5e36cE67401dc7FEbD2D9700C096D8',
#   'balance': '5844502836233834'},
#  {'account': '0x5a5a209E5E0f26909659525fF68aFA71920D091E',
#   'balance': '732229352431875991'},
#  {'account': '0xB3Fd85542cff89eB0FCCc18F9483d1BC8b4fA21e',
#   'balance': '3456653530592203'},
#  {'account': '0xd9079f124D43c83ee00dedD9005E21ccF47607b5',
#   'balance': '813765502878822'},
#  {'account': '0x544FFb0219442A2D34d85Eb866e663Bf83d96E02',
#   'balance': '419392973202510083'},
#  {'account': '0xaaa2974bA80aE029d561C2234ba705C84900a01D',
#   'balance': '547302325674420695'},
#  {'account': '0xe4763E6DBcA5441D500574eeF9d392E55C4ee428',
#   'balance': '417719319736374083'},
#  {'account': '0xA5D31597FdA0b153122cf528205Ade8a5cDd1148',
#   'balance': '565878102214476294'},
#  {'account': '0x5Bc5a37613E681C35776366BF4Cb0AF9d2B2Fb8D',
#   'balance': '119019106494389981'},
#  {'account': '0xdF219bfC217221ab911c4333A846623CeC5c1009',
#   'balance': '586403276812114436'},
#  {'account': '0x9a02874faE953434885F8B8C29e0c4A534823508',
#   'balance': '121672078184542083'},
#  {'account': '0x4C538a90aCa4EEA1Cf2D8bc5aee75E662f522BA8',
#   'balance': '353884500677669800'},
#  {'account': '0x9908F7d28c5A959B27AB7BeFc469a56C594639AC',
#   'balance': '113346531723453910'},
#  {'account': '0x29c86b04c88e48dB1A6fB8BccBC607148f4eC060',
#   'balance': '29005139262165092'},
#  {'account': '0xE53093b3a50141514E75B488564d62B886B94D43',
#   'balance': '106074101276273139'},
#  {'account': '0x537db859e8Ff6c0619394A4B83DD08d5f6f1bf97',
#   'balance': '28528635054881380'},
#  {'account': '0xDA39DaCb749c6a936Af9cB2a7bd814bfBC8E524E',
#   'balance': '101934203620462694'},
#  {'account': '0xf82D123De909BBB2697E314465670e249b7aDbD3',
#   'balance': '28176423257223678'},
#  {'account': '0x31E19CAC09F0fC35138514aAeaecf07f48dA30af',
#   'balance': '375155088412270441'},
#  {'account': '0x74435DE5A8ab92Ce3a68645EDf1CCEd3b0b7CfEc',
#   'balance': '120317323766425000'},
#  {'account': '0x76A9b89b4bD79e016c31fcCB5884Dcf86cf57A49',
#   'balance': '112238262129245717'},
#  {'account': '0x06089BcEeE94A485c61b311Cb61934d5CF8a684e',
#   'balance': '305581634799790250'},
#  {'account': '0xc9dAB5744d0768aB9235549BD157aB4Ef01D57Fc',
#   'balance': '69354627308382570'},
#  {'account': '0x5855dEb8b81517a42d4412F0c4D612A67318B35d',
#   'balance': '334122620080079716'},
#  {'account': '0xD4B9715fda3Db5460273A51A6D3F94ad46fb98c9',
#   'balance': '326047718599284312'},
#  {'account': '0x0482d6bF3B83470ee4eE87C20a98d38249138e1B',
#   'balance': '95330337147096439'},
#  {'account': '0xcd2A9DfDB6EFE0d4A834e736Db10aC9bd2f31ae1',
#   'balance': '257367138019629809'},
#  {'account': '0x66F990ce451926c631Aa11A04A772ceB532d34E6',
#   'balance': '134022998014073720'},
#  {'account': '0x334c5B9f732174Caa4B7A67d2178b7E74a527003',
#   'balance': '9863950048269340'},
#  {'account': '0xa727C11EE000a8F0DF668939f5Af7A10ac4F253F',
#   'balance': '82853149352691227'},
#  {'account': '0xD0d64eA80e516939DC29144af2B5607bEf7C4f9C',
#   'balance': '2539595381680603'},
#  {'account': '0x4F459Dc2A1DAC3Cfb64DC5DCEbA6Ab02D8E1FC1c',
#   'balance': '2130251502260855'},
#  {'account': '0xbe2e8F6292D29c65F9BCd807bE387422857B4093',
#   'balance': '206572590286801941'},
#  {'account': '0x3c5de42f02DebBaA235f7a28E4B992362FfeE0B6',
#   'balance': '148618114336651203'},
#  {'account': '0x1a6D00C269Ad115a288C3114c4bE5D993A619Cdd',
#   'balance': '232775336913000'},
#  {'account': '0x7Fd10A2BC1c076f7AF26DaFeE744E1027A85dF32',
#   'balance': '24515493996547675'},
#  {'account': '0x1e8831fa8BFaD1380Eb09845D740d8F44b2782A7',
#   'balance': '61609415502095049'},
#  {'account': '0x7F3CFf0706d6B7425D39F5a18F0bc5d702bEABfC',
#   'balance': '24997396628856099'},
#  {'account': '0x911ADC4e2e84D172cD51b17eC813029f4B8050b9',
#   'balance': '18990016584000'},
#  {'account': '0xD32ef2f9A580f575B59E8cfC5F8d94A626606E20',
#   'balance': '124354081444102206'},
#  {'account': '0xb542d66eD67401B572FC34Ed1D0D0Dac3E181862',
#   'balance': '123956237282557786'},
#  {'account': '0xb200663fbEAE3C28D898453Fb4Fd9898cF0Bcbd8',
#   'balance': '113829037539874081'},
#  {'account': '0xFBb990Fb9C1854842afB7d2e3Bd2117F4b4275B2',
#   'balance': '55796268087000'},
#  {'account': '0x88baa8E1555A3CfeB125eF3da3d5E88E633F865D',
#   'balance': '228638824788551770'},
#  {'account': '0xB6bd1b9b3e6e3512BB354789289f6d8FBc0F65BC',
#   'balance': '117278749557156726'},
#  {'account': '0x97fe413d650D495338615150a8ed6F78A32C2e68',
#   'balance': '24281010211212208'},
#  {'account': '0x8822C248805EFBb56A89caF7033a733607118a05',
#   'balance': '31665779670432328'},
#  {'account': '0x698c3255DB5fD4cC99D5a3004a4704922d76444D',
#   'balance': '28735493179118524'},
#  {'account': '0xC7C4fE1b862e17bc9aD900873422115954f9893A',
#   'balance': '11666909118961698'},
#  {'account': '0x8e29d26155C6e7acb597495dfCf4A8831Ed57C41',
#   'balance': '16964900802693188'},
#  {'account': '0x3a647b4e245EE3Ec5dfe76fd97FF8f8f367B454B',
#   'balance': '3629868786076142'},
#  {'account': '0xADcF8eec47dBc624d41DC2486909f56884D12f7F',
#   'balance': '973209376417462848'},
#  {'account': '0x3570Ead6A101d2e0f4e0c2fcfA03b71a121c9089',
#   'balance': '388705389537128083'},
#  {'account': '0xD9c0DD9F990d56248A5C14B9915A63eA2713DCbf',
#   'balance': '27006145133861119'},
#  {'account': '0x32f6e0C3DD52f85C6F924E8225975155ed2aE71b',
#   'balance': '28543644841859924'},
#  {'account': '0x79d0Ab0482913E518E5EcF85E128386E6B83428C',
#   'balance': '54800478759849599'},
#  {'account': '0xc41947f2A4e64CED66A459faB4A40B2fA5587038',
#   'balance': '18280823954187646'},
#  {'account': '0x9bCeE92cbF09362fa1E3aC4E6E0a07046ac35510',
#   'balance': '24867947131402740'},
#  {'account': '0xa974890156A3649A23a6C0f2ebd77D6F7A7333d4',
#   'balance': '721744059330287853'},
#  {'account': '0x8a2899b62af3d98c275A69eE6A81E507b545E48E',
#   'balance': '25219090859035814'},
#  {'account': '0xb104c6Ebe6F99473B9Ad3C34b9237222E7641723',
#   'balance': '26867438333518394'},
#  {'account': '0x91971781AaD7FE82f513c4b72A8365133A94fEC8',
#   'balance': '27238562649457771'},
#  {'account': '0x89AaF4ECe6bB47472b7Bd532f3bAf490beEEE2C4',
#   'balance': '29869443138924166'},
#  {'account': '0x46c8b6FE35f04Ab7a5c4194BCEd33a1F682613c8',
#   'balance': '3117595652057520'},
#  {'account': '0x42C6c52b686E3845f9D5deE93dc213A3826214A9',
#   'balance': '88774233212154912'},
#  {'account': '0xdDbb4912066850f309a60A84cE28899249060846',
#   'balance': '25485262721992664'},
#  {'account': '0x410812f2f67370B1f8628759fec499f41643973F',
#   'balance': '5330084563083711'},
#  {'account': '0x751F6102A51047d148e510C20FF88c60eC9a9d9f',
#   'balance': '22019835345869719'},
#  {'account': '0xec53019377eBa590cCa9e057bB3B18AD76E59102',
#   'balance': '115074155052458746'},
#  {'account': '0xdfDA7181EB27A69d897E82cF96C5BcbdC3c059B0',
#   'balance': '3622366697382864'},
#  {'account': '0x6eA60f83dF21F9DA4a6b4DEa21249154e74DE210',
# ...
#  {'account': '0x363452F7EE7Ff0A1A2B6764a7a8607ed161F025c',
#   'balance': '3036902896800199'},
#  {'account': '0xaE6779A4e97F4503eA14e4f8bD120529388FE463',
#   'balance': '4988751733501099'},
#  {'account': '0x166830B7198c70C0a39cf004e1ED1513b1Ce55bd',
#   'balance': '12736623136662868'},
#  {'account': '0xA741B24C8aDCd1db26CD05714fFD870bD15Aa95B',
#   'balance': '835413214494521'},
#  {'account': '0x4B80e11D2410F2029aE73628603840dfFbF885Aa',
#   'balance': '98628735613896998'},
#  {'account': '0xD3eFd3BD60b5a95379e2f8644822B751E9b80882',
#   'balance': '30946896208441560'},
#  {'account': '0x635EA29535Fb8a18135b9854906Fd502456dB196',
#   'balance': '1421696475200575'},
#  {'account': '0x20388c24E7DAfa873Ee09b06F8673bb347a2A563',
#   'balance': '33135480330686205'},
#  {'account': '0x326107587c4a162047c6891D933e37C6aEc0E7AE',
#   'balance': '31808023276534264'},
#  {'account': '0xdF9c9D9399b3a77168079216af8C158c29Cce6e9',
#   'balance': '3382103840319053'},
#  {'account': '0x3f84020F8d26F80075d5eC97b434A70124164Ae7',
#   'balance': '58160069987256625'},
#  {'account': '0xa83021e1dA72AAd42ceCf683589D8A5C4ef347af',
#   'balance': '9708224092582264'},
#  {'account': '0x75cF6D3e76D550b615aEC7e3da8195e672259C73',
#   'balance': '1235123329942127'},
#  {'account': '0xecBB260F13427D93c0c9b70257ae90E078667aE4',
#   'balance': '1824077288796191'},
#  {'account': '0xFc77174fC6d70FDd3406aed7643363927e386e6e',
#   'balance': '781356840995745'},
#  {'account': '0x7170cae564388868115BDdE93b2fFD48CA6c8f29',
#   'balance': '15964425972790076'},
#  {'account': '0x97D7764F6C3f44CD962639Ef505523388F19B138',
#   'balance': '28949800618301672'},
#  {'account': '0x3ebAF00176a77a9EDe760dc43f798A9Ad2A87C8A',
#   'balance': '158763186266731'},
#  {'account': '0x9CFD69CbDfbC0602ea2d4BdF9e3Ca39f79809f95',
#   'balance': '22305345461507836'},
#  {'account': '0x89Ceb56D9F626639c99CAE72afE54412e89f1142',
#   'balance': '26842725605030264'},
#  {'account': '0x418f528E2CB2dD97E797CDfAf3e04E67e9aBE3aC',
#   'balance': '86463201801527860'},
#  {'account': '0xBf6B90EC3f6E2c6d07fF8135b6c5301950399f92',
#   'balance': '16409753704031196'},
#  {'account': '0x2E736Cbc6F8312a136c7F93e5Cd342e6EF4088Fd',
#   'balance': '15646864123915186'},
#  {'account': '0x92574727439ba321bC4216f2F8baA99662dD93aA',
#   'balance': '15676130990358396'},
#  {'account': '0xce68b1394ED29ECAA6974536244d1D2Aad4a2745',
#   'balance': '879174170368497837'},
#  {'account': '0xdC5801E226e1432449C5F68D53b34bA1c1729666',
#   'balance': '12000000000000000'},
#  {'account': '0xA82c1E9408B139F93f391e20da6cBd0302F2F525',
#   'balance': '97478183580215521'},
#  {'account': '0xFe14cc0327B72fCa3C47e9621b13ACf1dA12b0d4',
#   'balance': '12262305243512260'},
#  {'account': '0xd074A156C4f418745A7D9edFD8bEFE11D8dE14Fb',
#   'balance': '13079679311199188'},
#  {'account': '0xc58563c6A3d1889E9CF41c8cBA84c78C0B58DD97',
#   'balance': '3589095635892852'},
#  {'account': '0xBBF1E45aF35D6A99464B5D2d27d435CDE21dD7f8',
#   'balance': '34671494877422213'},
#  {'account': '0x71c4268EBA8e7A1E8783185aDd258531E2F350b0',
#   'balance': '21124219640828385'},
#  {'account': '0x6A6e0145fD7b209859DD85eCc0D79E9218199FC5',
#   'balance': '10150030992723582'},
#  {'account': '0xdB220DE2d36C5AbF72e1c88ffC29d0AeD06E495e',
#   'balance': '654166613994998'},
#  {'account': '0x6D7cEA482d280378B86DB9112Edd62919faE2c36',
#   'balance': '24770556459425466'},
#  {'account': '0x7D4bF9002C92E0F2a1a957A6838e6b631681834a',
#   'balance': '21161575931085145'},
#  {'account': '0xEb2c238f2b5ae3B30793Ca8179aE426B7Ec5D49c',
#   'balance': '27338473310600325'},
#  {'account': '0x922e6Fd79348C23d34813976db5CEC57292bDec0',
#   'balance': '48424576930734216'},
#  {'account': '0xAD2D23dcfF6cDBb8a15e71D9acEF313690933145',
#   'balance': '81927204633562304'},
#  {'account': '0x909f9ef8a242e2df9c65c2535f3521e9Bd5212EB',
#   'balance': '81583108533341773'},
#  {'account': '0x53599497864Fb436f7E843bC712E031B5828FddC',
#   'balance': '16337079690764194'},
#  {'account': '0xc6332d5e27e4C0b28B1D4AfCbB6Ed790211e3d9B',
#   'balance': '16472077030528427'},
#  {'account': '0x672C3b982325bE86E221fe5d0Eb5391ffA9CC8fC',
#   'balance': '149503709715837680'},
#  {'account': '0x0231941AbBC3DD9ceD1F3279DCF862ff5c233C4b',
#   'balance': '24555921463407205'},
#  {'account': '0xc7B060256672C77466Bd88714f435BFA8344ECb8',
#   'balance': '13186133513188532'},
#  {'account': '0x935640A15B2AD02862C925349B8287B134464cb2',
#   'balance': '44900811419508526'},
#  {'account': '0x539f0450EA804aA87C122731136187f9ACCB5bC5',
#   'balance': '19617022834166089'},
#  {'account': '0x25cAEAa2A14EbfCB33e5866b6F701316e8B2c677',
#   'balance': '21887289334040301'},
#  {'account': '0xd5Eb8F3f1eD7DDA719DAFA19B9C9C7f67513D779',
#   'balance': '9050042178892217'},
#  {'account': '0x9B733744344AD50CC726F8b48f3BddA34224370a',
#   'balance': '20874607417969472'},
#  {'account': '0xae786E1F9B0AB70a34ed1A3e87DB33ae3aF030f0',
#   'balance': '25247517371355939'},
#  {'account': '0xe588471D7Da6e9c48681eb6d4E4cd2c6aeC9cce8',
#   'balance': '15718654125204252'},
#  {'account': '0x8BC2118CB187feD5A2EecE06c5aF095088d1d78e',
#   'balance': '3965710730368294'},
#  {'account': '0x4a2Fb8B433F4FFD1a78E01FEc78aF6f985831726',
#   'balance': '21259217392864495'},
#  {'account': '0xfD8a8FF896CCd28efE1c4a3EF69B9c4fd3f1943d',
#   'balance': '6194482006850831'},
#  {'account': '0xB2bAA1B7527fe99A995Da3FD4FC4cd84F338Ace9',
#   'balance': '26713565338179692'},
#  {'account': '0x8362CB1C821b83ca0026099A4918668a4A52a504',
#   'balance': '91326341385884398'},
#  {'account': '0x429641573FEd33be1beC77Ef15b5F047e115C054',
#   'balance': '12265457218459344'},
#  {'account': '0xd6c2757516110F2d27402Ce7351c970b24c314e9',
#   'balance': '21568129473660097'},
#  {'account': '0xB4A8090BAcC5D62AE1c887674f9436fd829c2154',
#   'balance': '17387930033874767'},
#  {'account': '0x951ca62090E6670a939400498fF26CcDC4F91F6A',
#   'balance': '18544091384215374'},
#  {'account': '0x8F65257B183936a6f48e814bD01E08A74d6B2079',
#   'balance': '16803278000000000'},
#  {'account': '0x21b9448EDac62C358786CAb8c71399515F9505b8',
#   'balance': '31748614715478176'},
#  {'account': '0x426ECD71FBDfc437b8012Bae2616e63839C41237',
#   'balance': '12088542193580794'},
#  {'account': '0x40d88fB6a1C15CE0436Ff1d888E219130787caB7',
#   'balance': '11631613169532362'},
#  {'account': '0xD7199b369CAA47CE2B4C5305c3F6Fc15D09EAC5d',
#   'balance': '24128673796136129'},
#  {'account': '0x4506cA6a8Af3f450ef12C22B951BFDb5b2E72a87',
#   'balance': '11408439733594740'},
#  {'account': '0x1FFEa978E9df2D0430987eD4040EbACB0417C4a8',
#   'balance': '17683080992716150'},
#  {'account': '0x0730c0B89a18772abe0e1b2FadEffA4b2ebfFd9d',
#   'balance': '11148435461323363'},
#  {'account': '0xb39f58372396B93236cda0Be1fD9299f5FBc39DD',
#   'balance': '85626713017594460'},
#  {'account': '0xDA9C19470f0D68BA464EC22BF8FAC4E1986C4C26',
#   'balance': '1812184923227632'},
#  {'account': '0xba27305B9a0BB010A94C5E09a94c809116d52e7A',
#   'balance': '2337768377195773'},
#  {'account': '0x09c2bC4f430325B5370f858759950D486a3ac059',
#   'balance': '30165719821812906'},
#  {'account': '0xcb6382Ff625f34433DDEB18C22774315d92AB8eC',
#   'balance': '12739283234738732'},
#  {'account': '0xc2609e4d1E9d5aFf92EE0f882ffc661aCF67b85B',
#   'balance': '12289723227857293'},
#  {'account': '0xEcE94CA7C6d298c707b19e8a41029218f5E409aD',
#   'balance': '59674049640777038'},
#  {'account': '0x4190a81Ca69B1fac9392719776205061c962E839',
#   'balance': '14377772517713286'},
#  {'account': '0x2e39AFcD3cd5E9430000492BD9eC8571c600C963',
#   'balance': '76876315423453982'},
#  {'account': '0xea3129fd3bB6c9551Ee01CdF17E88B61488f6FC5',
#   'balance': '40061703865855801'},
#  {'account': '0xdE91757c408306cb8258B2e1cA77797fE6613A5D',
#   'balance': '13713582964523194'},
#  {'account': '0x039c7320956110b7E9E350D382a354D6aCe8d2C0',
#   'balance': '46494120643363849'},
#  {'account': '0xc296E9f9359c3bF69d2A1b614B1F99988D8d5b85',
#   'balance': '6372790881841652'},
#  {'account': '0xa8eAc5592228F1108fd4a488bD13D2201268cC3f',
#   'balance': '88422066239435549'},
#  {'account': '0xA2B4ca5f98951F71D311898FdfBd1130ee7EA435',
#   'balance': '35932584383539774'},
#  {'account': '0x5e94208bb2f02153e0D19dA707BddDf3828c5b1e',
#   'balance': '36924065230134464'},
#  {'account': '0x3C3d43Efab6e23D5D0f65F14CD5FBA47BC621e9c',
#   'balance': '89965742943137918'},
#  {'account': '0xf1Ccefd09A2c294a4f4dCc2f9707E861f4d84dE2',
#   'balance': '73916768971769621'},
#  {'account': '0x4dfd6788383EbF6bF27C86eDbCC2e7aAD75F5B8C',
#   'balance': '63126876191877631'},
#  {'account': '0x549af80C7c3d948708a6DF948330121ebFc023c3',
#   'balance': '14235048778624693'},
#  {'account': '0x516206D1C585ef7A8dB664CDA2390f72fa693912',
#   'balance': '22660236003885465'},
#  {'account': '0xC6e431fDe25CcBA2520491e29AD5B2e3134d7989',
#   'balance': '9967752545801727'},
#  {'account': '0x8F9e251b6eC993c9a9ea4712c40D19F1052e7873',
#   'balance': '89263068483214962'},
#  {'account': '0x0A030ED2B5B7Bc9fe8676e1BE40cc228e66b3B55',
#   'balance': '198083520604469605'},
#  {'account': '0xFd5BB6E088Cd1e561FE6779b517833dF934B85F8',
#   'balance': '14964193005181100'},
#  {'account': '0x55155065F66C978aC724F2973739A9495374155C',
#   'balance': '40322099514570461'},
#  {'account': '0x15d789D4Dd128CEA5D8E6b6f0adAbe910e5Fd100',
#   'balance': '138289385258760676'},
#  {'account': '0xAF4FBDCD730fC9eC4A94C4E184Be87f4a80e1AD5',
#   'balance': '215634038066679672'},
#  {'account': '0x1071a56413701b104f35fCD0a94822457e512114',
#   'balance': '119892695705824305'},
#  {'account': '0x76E93F920194f278591be7727608c02659fe99Db',
#   'balance': '202465047179423552'},
#  {'account': '0xbFb779A251dea0CC13F39b004FD3D8F303C397a2',
#   'balance': '17386991914861459'},
#  {'account': '0xa8c7d5818A255A1856b31177E5c96E1D61c83991',
#   'balance': '20480922673695894'},
#  {'account': '0x5d69a4fa13C0Be04f0b299Bc725909fD80dB7529',
#   'balance': '284818295748000'},
#  {'account': '0x1EA5C1ADd3c70Cf37455018FecFd0AD24b258F34',
#   'balance': '3267142667816345937'},
#  {'account': '0x3FE8b5E12b932fCda52596A1d6A5dD0acD1d9C75',
#   'balance': '438202419633362820'},
#  {'account': '0x1F2129FDC61Cac52B76499eb703cdba573Af4509',
#   'balance': '100000000000000000'},
#  {'account': '0x57b6951cAbaCD1CF30381E76445b5c48A18BC54D',
#   'balance': '156104930121000'},
#  {'account': '0x7aA6bE3Ebf32fB2A7f212548E5aF9fc0FF5c6c47',
#   'balance': '6210266634479952'},
#  {'account': '0x503F84693a76cfF67B313D0d56B0b66a67e45f6B',
#   'balance': '447500000000000000'},
#  {'account': '0x1fE7602cf87Bfb401D030c7bA4B6bdE3AD8af2F6',
#   'balance': '64749803703827039'},
#  {'account': '0x27670a5383D252fD7028ce7FE55A6a68127E8Ce1',
#   'balance': '10175804010804339'},
#  {'account': '0x5426e265e7681C29746009841dE3d369C840C556',
#   'balance': '253687148151369188'},
#  {'account': '0x5B15AAB04EC5E3058AB2921A8F2f94FD26ed581C',
#   'balance': '56603967676144370'},
#  {'account': '0x32388db1e4AF84ac25742c76C4731025DA0E8f3B',
#   'balance': '442621526941266199'},
#  {'account': '0x84Bc5e975da6cF8F3D5c22B5A13F70Fa623Fe879',
#   'balance': '26693553248141011'},
#  {'account': '0x04c2e657CB2b0D86D7129819808430d889Ed2660',
#   'balance': '5092804918904771'},
#  {'account': '0x2e558247eaAAd7Ca4c8a4D4baFc97cE1e607906b',
#   'balance': '869104497368754'},
#  {'account': '0x2655342165c183d4706DCC98A1AFe588fA48F7ae',
#   'balance': '443107459317269322'},
#  {'account': '0x9900fee54d1499ABf321A5e3E44dA35386B81dcf',
#   'balance': '334550966608766105'},
#  {'account': '0xF2E2806911a310bA9600eBc2DBD4978d31A0C65C',
#   'balance': '2811509134376883'},
#  {'account': '0x89768Ca7E116D7971519af950DbBdf6e80b9Ded1',
#   'balance': '9926540459346255'},
#  {'account': '0xCCed609d3dE07A746ECbEBFB02193E15F200faD2',
#   'balance': '277112017043107450'},
#  {'account': '0xed4490F946862acfaE644328DC9cf0Fe1b000507',
#   'balance': '895430840807797073'},
#  {'account': '0xDed789b66eB94c717937d9Cf1074FF8BCd512A8E',
#   'balance': '34258462726397121'},
#  {'account': '0x7FaA32b18C874b2eB4B42bC0d0924eFBBed49423',
#   'balance': '480840807838228625'},
#  {'account': '0x1dd89ebC254b30B5523FFe33740cC28aa6510EF2',
#   'balance': '33433093396229793'},
#  {'account': '0xe53e8F9113a455b039F6FA700D8FC9424e9F5f92',
#   'balance': '29052825740925241'},
#  {'account': '0x5A7198d8e4551A61B3323b268d9355e7A4A7898e',
#   'balance': '11296730733659987'},
#  {'account': '0xbc47bFE4887B82CCCF2B1aF40d1BF6a6E6708E89',
#   'balance': '10164644140225518'},
#  {'account': '0x44E2F285F26bF65b5396873dD25B8D82A63e5546',
#   'balance': '5472929869481912486'},
#  {'account': '0x3C795E4F750B15b61159E8f38dCA512256a021C7',
#   'balance': '109303591228350405'},
#  {'account': '0x908dBd31Ed8ac9ae70DB0228C0Ca0DF59aF8FB56',
#   'balance': '2704572053294356'},
#  {'account': '0xbEd7fC5a011cB6ac5a14FB86c1bA893B40ACF1e5',
#   'balance': '48729942393338506'},
#  {'account': '0xDEf1F95525716C9cd613BFEa3B543C8DdA5574E3',
#   'balance': '5602532297814690'},
#  {'account': '0x1412a974CF1debE85B9FdF5117846384A9FDB8c5',
#   'balance': '15320902016858688'},
#  {'account': '0x7afe1aB48Fcf8f00E759A84B0eE3e7Cc4aa9d060',
#   'balance': '16054797374567378'},
#  {'account': '0x6E9F31DfeE295B666fEB54754aE8fFaB20159096',
#   'balance': '10997854772583939'},
#  {'account': '0x3Efd8a2132456314FA4073586f23157F7f1C9d73',
#   'balance': '16029570454052366'},
#  {'account': '0x3DB6c3378a410be780091c49906Cc3119360885b',
#   'balance': '9177526992276290'},
#  {'account': '0xef25d4ab693675D4f726d02B3255F3a497870c94',
#   'balance': '11246555847652978'},
#  {'account': '0x1E34C6d1281f90Afa87107f5098036539d40E8C9',
#   'balance': '18374207878872428'},
#  {'account': '0xF7B2a7e7d1462905571dFfa7a21Fa6a4593A0b0F',
#   'balance': '8171542124557895'},
#  {'account': '0xb2FC08a70b5320ac647eeB5bceE458935b08125b',
#   'balance': '586630816054601234'},
#  ...]

# %%
sm_wealth = pd.DataFrame(eth_wealth2)
sm_wealth.head()
# Out:
#                                       account            balance
# 0  0x1BaA7E3DDA9480f2fff7a62cFB92B56c0B35456E   9227623336239750
# 1  0x298d0f26472e364Ea84090C80B09b187098F84b8   1313058536808346
# 2  0x8Fffb08a892B348C3df82695F55F866D85BCD358   4938400684681228
# 3  0x31A95aDAa9435f6381Ab41b38C6C8150Bcb845E9  10346809650713943
# 4  0xf517C1A78d0769B7BEdF26217e4FcAe4C727D0a0   8098745663244817

# %%
votes_wealth = pd.merge(sm_wealth, votes, left_on="account", right_on="voter")
votes_wealth['balance'] = votes_wealth['balance'].astype('float64')
votes_wealth.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2900 entries, 0 to 2899
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   account         2900 non-null   object
#  1   balance         2900 non-null   float64
#  2   id              2900 non-null   object
#  3   ipfs            2900 non-null   object
#  4   voter           2900 non-null   object
#  5   created         2900 non-null   int64
#  6   space           2900 non-null   object
#  7   proposal        2900 non-null   object
#  8   choice          2900 non-null   int64
#  9   metadata        2900 non-null   object
#  10  reason          2900 non-null   object
#  11  app             2900 non-null   object
#  12  vp              2900 non-null   int64
#  13  vp_by_strategy  2900 non-null   object
#  14  vp_state        2900 non-null   object
# dtypes: float64(1), int64(3), object(11)
# memory usage: 362.5+ KB

# %%
df_groups = votes_wealth.groupby('choice')

# %%
df_groups['balance'].describe()
# Out:
#          count          mean           std           min           25%  \
# choice
# 1       1630.0  1.644328e+17  1.477505e+18  0.000000e+00  7.338288e+15
# 2       1143.0  1.497961e+17  8.252119e+17  0.000000e+00  9.523568e+15
# 3        127.0  8.438756e+16  2.163363e+17  1.807249e+13  5.121654e+15
#
#                  50%           75%           max
# choice
# 1       1.952524e+16  7.824579e+16  5.288468e+19
# 2       2.558848e+16  1.033446e+17  2.472459e+19
# 3       1.246275e+16  5.639688e+16  1.800077e+18

# %%
stats = df_groups['balance'].agg(['mean', 'sem'])
stats['ci95_hi'] = (stats['mean'] + 1.96* stats['sem'])
stats['ci95_lo'] = (stats['mean'] - 1.96* stats['sem'])
stats
# Out:
#                 mean           sem       ci95_hi       ci95_lo
# choice
# 1       1.644328e+17  3.659613e+16  2.361612e+17  9.270437e+16
# 2       1.497961e+17  2.440857e+16  1.976369e+17  1.019553e+17
# 3       8.438756e+16  1.919675e+16  1.220132e+17  4.676194e+16

# %%
fig, axes = plt.subplots(ncols=3, nrows=1)

for c, ax in enumerate(axes.flatten()):
    c +=1
    x = votes_wealth[votes_wealth['choice'] == c]
    ax.boxplot(x['balance'])

    ax.set_title('Choice={}'.format(c))

plt.tight_layout()

# %% [markdown]
# #### Messages
#
# We get a better idea about the history of our DAO.

# %%
query = gq("snapshot_messages_of_space")
messages = await gql_all(query,
        field="messages", 
        # rest=True,
        # save="snapshot_followers_small.json",
        data_dir="data/",
        first=1000,
        vars={'space': DAO_ID }
    )
# Out:
# 1 1000
# 2 2000
# 3 3000
# 4 3539
# **I am done fetching!**

# %%
messages = pd.DataFrame(messages)
messages.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3539 entries, 0 to 3538
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   mci        3539 non-null   int64
#  1   id         3539 non-null   object
#  2   ipfs       3539 non-null   object
#  3   address    3539 non-null   object
#  4   version    3539 non-null   object
#  5   timestamp  3539 non-null   int64
#  6   space      3539 non-null   object
#  7   type       3539 non-null   object
#  8   sig        3539 non-null   object
#  9   receipt    3539 non-null   object
# dtypes: int64(2), object(8)
# memory usage: 276.6+ KB

# %%
messages.head()
# Out:
#        mci                                                 id  \
# 0  9127606  0xd7d321b42db92ad30d14d3326dedc334d0396b1acdad...
# 1  9125567  0x24f2e6dce95605c26729322cb80ebacab28431845cd2...
# 2  9123575  0x9decf88607c82f2f95857735d5bdbfb448840165ca0a...
# 3  9123394  0x46a597a6d5328b441403339901289b976c007d6a405c...
# 4  9118271  0xcc3bd913229aaa1d8f67f04fc726f0fda80db0f847a7...
#
#                                                 ipfs  \
# 0  bafkreibzmzihosvs2j2gxltfoij46zzulmlacjbmczc4f...
# 1  bafkreidege7fpv4u6i24lnxkrvtnq2gs3ihtxx6r2zgci...
# 2  bafkreievm6uvzrzo3qffph7fqpjvyvy4oxkdak5o2vcd7...
# 3  bafkreiaptrmcncyvlhsdhnerhycglao5kwzw5gfwb3dhc...
# 4  bafkreid6eyfvfdfd6txu3fbvdsolbylhp5dt362waajtk...
#
#                                       address version   timestamp  \
# 0  0xcC0ce82d2C580f78243ab48E18bf572B2A47902E   0.1.4  1664889143
# 1  0x6726aC7A0d3EF9b7b9ff60fc8fcd5F9324d4238F   0.1.4  1664880851
# 2  0x9424f29a7Fa532E21045bb7A67531F493852bb0E   0.1.4  1664867728
# 3  0x58729D55B934119D6DE2392E88044DAc3ebEb222   0.1.4  1664866526
# 4  0xE73526CA91E7513D2f7ed6973B0604E74Db1FB5c   0.1.4  1664821502
#
#              space      type  \
# 0  hashflowdao.eth    follow
# 1  hashflowdao.eth    follow
# 2  hashflowdao.eth    follow
# 3  hashflowdao.eth    follow
# 4  hashflowdao.eth  unfollow
#
#                                                  sig  \
# 0  0x4ff82298a7bd1814d5c064c428af7ee3cffea46a1fff...
# 1  0x16bcb9059f3a4737dadb4631406dd411fe9880b6f662...
# 2  0x8e29e087c2d03561b6fffb89f1882da8e8466883beab...
# 3  0x4c35f93019196cea04e0ae581e0e9f4485b615df1c1f...
# 4  0xec77ce6e887fabfee2fd9b527e66a21ed8df09903d10...
#
#                                              receipt
# 0  0x0cd02f019afdf96e94daaffe7e2ce5f608063e793313...
# 1  0xee396a079307fa0225b7d3359d766572ff2950f81517...
# 2  0xc1eeb6253b8b40f9831a7251314c745bc454176e8bee...
# 3  0xa43c334bd48dfde02462c1f56016b231ce4a70dc12f5...
# 4  0x3b6b92ab8bc0082ae1f20296138eea5b8761b0e1d13b...

# %%
messages['type'].value_counts()
# Out:
# vote                3164
# follow               312
# unfollow              45
# subscribe             12
# archive-proposal       5
# proposal               1
# Name: type, dtype: int64

# %% [markdown]
# The number of votes is larger than what we downloaded and the number of follows smaller. After inquiring with the Snapshot's staff on Discord:
#
# - admins might have deleted/closed/archived some proposals,
# - one should check the data of creation of a dato, as some features of the platform might have been added later.
