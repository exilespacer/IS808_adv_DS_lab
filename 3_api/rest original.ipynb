# %% [markdown]
# ## Snapshot and GraphQL

# %%
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# Snapshot Endpoints
#
# https://docs.snapshot.org/

# %%
ENDPOINT_DEMO = 'https://testnet.snapshot.org/graphql'

ENDPOINT_PRO = 'https://hub.snapshot.org/graphql'


ENDPOINT = ENDPOINT_PRO

# %% [markdown]
# We can make GraphQL queries with standard POST requests.

# %%
# https://datagy.io/python-requests-authentication/

def api(query, params=None):

    response = requests.post(ENDPOINT,
                            headers={                      
                                'accept': 'application/json'
                            },
                            params={
                                'query': query
                            })

    print(response)
    return response.json()['data']

# %%
query = """
query {
  space(id: "yam.eth") {
    id
    name
    about
    network
    symbol
    members
  }
}
"""

res = api(query)
# Out:
# <Response [200]>

# %%
res
# Out:
# {'space': {'id': 'yam.eth',
#   'name': 'Yam',
#   'about': 'Only delegated YAM may be used to vote on proposals. You can delegate to yourself or another address here: yam.finance/#/delegate',
#   'network': '1',
#   'symbol': 'YAM',
#   'members': ['0x683A78bA1f6b25E29fbBC9Cd1BFA29A51520De84',
#    '0x9Ebc8AD4011C7f559743Eb25705CCF5A9B58D0bc',
#    '0xC3edCBe0F93a6258c3933e86fFaA3bcF12F8D695',
#    '0xbdac5657eDd13F47C3DD924eAa36Cf1Ec49672cc',
#    '0xEC3281124d4c2FCA8A88e3076C1E7749CfEcb7F2']}}

# %%
query = """
query {
  spaces(
    first: 20,
    skip: 0,
    orderBy: "created",
    orderDirection: asc
  ) {
    id
    name
    about
    network
    symbol
    strategies {
      name
      params
    }
    admins
    members
    filters {
      minScore
      onlyMembers
    }
    plugins
  }
}
"""

res = api(query)
# Out:
# <Response [200]>

# %%
res
# Out:
# {'spaces': [{'id': 'bonustrack.eth',
#    'name': 'Hi',
#    'about': '',
#    'network': '1',
#    'symbol': 'TICKET',
#    'strategies': [{'name': 'ticket', 'params': {'symbol': 'TICKET'}}],
#    'admins': [],
#    'members': ['0x24A12Fa313F57aF541d447c594072A992c605DCf',
#     '0x8BBE4Ac64246d600BC2889ef5d83809D138F03DF',
#     '0xeF8305E140ac520225DAf050e2f71d5fBcC543e7',
#     '0x107174D70b33523E83711EA4C3F4229cdB8A7Cb1',
#     '0x0b21Dbc34A953a35dFA629ad31e1cEE3dE0433Fb',
#     '0x40FDAa1bff3BB87bC70955Be6657edBFdBeb122e',
#     '0xcc6A949DB9b26a7173648d50Cf7C55e800E6585B',
#     '0xC1C8ac723Fd9Db3db6E947dF42aaEdd28058A31D'],
#    'filters': {'minScore': 0, 'onlyMembers': False},
#    'plugins': {'safeSnap': {'address': '0xeF8305E140ac520225DAf050e2f71d5fBcC543e7'}}},
#   {'id': 'fabien.eth',
#    'name': 'Fabien',
#    'about': 'This is nothing more than a test space.',
#    'network': '1',
#    'symbol': 'POINT',
#    'strategies': [{'name': 'ticket',
#      'params': {'value': 100, 'symbol': 'POINT'}}],
#    'admins': ['0xeF8305E140ac520225DAf050e2f71d5fBcC543e7',
#     '0x4C7909d6F029b3a5798143C843F4f8e5341a3473'],
#    'members': ['0xeF8305E140ac520225DAf050e2f71d5fBcC543e7'],
#    'filters': {'minScore': 1, 'onlyMembers': False},
#    'plugins': {'safeSnap': {'safes': [{'network': '4',
#        'realityAddress': '0xF8Ca72b0d427F0b3e8984133C8A6860153b4f2D8'}]}}},
#   {'id': 'ichi.eth',
#    'name': 'ichi.farm',
#    'about': '',
#    'network': '1',
#    'symbol': 'ICHIPOWAH',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'ICHIPOWAH',
#       'address': '0x873902a3c0731EcC1F2075435FE035ACCeEd5459',
#       'decimals': 9}}],
#    'admins': [],
#    'members': ['0x873902a3c0731EcC1F2075435FE035ACCeEd5459'],
#    'filters': {'minScore': 0, 'onlyMembers': False},
#    'plugins': {}},
#   {'id': 'loyalfinance.eth',
#    'name': 'loyal.finance',
#    'about': '',
#    'network': '1',
#    'symbol': 'rLYL',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'RLYL',
#       'address': '0x0C9BbF4364F90db22B1B21b45177069a078842Aa',
#       'decimals': 18}}],
#    'admins': [],
#    'members': [],
#    'filters': {'minScore': 0, 'onlyMembers': False},
#    'plugins': {}},
#   {'id': 'damflux.eth',
#    'name': 'FLUX',
#    'about': '',
#    'network': '1',
#    'symbol': 'FLUX',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'FLUX',
#       'address': '0x469eDA64aEd3A3Ad6f868c44564291aA415cB1d9',
#       'decimals': 18}}],
#    'admins': [],
#    'members': [],
#    'filters': {'minScore': 0, 'onlyMembers': False},
#    'plugins': {}},
#   {'id': 'ufode.eth',
#    'name': 'UFO Finance',
#    'about': '',
#    'network': '1',
#    'symbol': 'UFO',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'DAI',
#       'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#       'decimals': 18}}],
#    'admins': [],
#    'members': [],
#    'filters': {'minScore': 0, 'onlyMembers': False},
#    'plugins': {}},
#   {'id': 'boringvote.eth',
#    'name': 'BoringDAO',
#    'about': '',
#    'network': '1',
#    'symbol': 'BoringDAO VS',
#    'strategies': [{'name': 'contract-call',
#      'params': {'symbol': 'BoringDAO VS',
#       'address': '0xdd018AD3D79bF8aA7C2E9726b566f7aeeF693618',
#       'decimals': 18,
#       'methodABI': {'name': 'balanceOf',
#        'type': 'function',
#        'inputs': [{'name': '_voter',
#          'type': 'address',
#          'internalType': 'address'}],
#        'outputs': [{'name': '', 'type': 'uint256', 'internalType': 'uint256'}],
#        'stateMutability': 'view'}}}],
#    'admins': [],
#    'members': [],
#    'filters': {'minScore': 0, 'onlyMembers': False},
#    'plugins': {}},
#   {'id': 'relayernetwork.eth',
#    'name': 'Relayer Network',
#    'about': '',
#    'network': '1',
#    'symbol': 'RLR',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'RLR',
#       'address': '0x0e3ef895c59e7db27214ab5bbf56347ce115a3f4',
#       'decimals': 18}},
#     {'name': 'erc20-balance-of-delegation',
#      'params': {'symbol': 'RLR',
#       'address': '0x0e3ef895c59e7db27214ab5bbf56347ce115a3f4',
#       'decimals': 18}}],
#    'admins': [],
#    'members': [],
#    'filters': {'minScore': 0, 'onlyMembers': False},
#    'plugins': {}},
#   {'id': 'prophetfinance.eth',
#    'name': 'prophet.finance',
#    'about': '',
#    'network': '1',
#    'symbol': 'PROPHET',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'PROPHET',
#       'address': '0x8d5db0c1f0681071cb38a382ae6704588d9da587',
#       'decimals': 9}}],
#    'admins': [],
#    'members': ['0xcA670BC7D254C2a4b050Dbb05aD8f3db57Fd43Cd',
#     '0xe2f071Fa6a421c6Bd7DF3635cC001c569182B950'],
#    'filters': {'minScore': 0, 'onlyMembers': False},
#    'plugins': {}},
#   {'id': 'liddao.eth',
#    'name': 'Lid Dao',
#    'about': '',
#    'network': '1',
#    'symbol': 'Lid Dao',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'LID-vr',
#       'address': '0xb271e47E8AbD99df2f6275793eF838B0Ee0866c9',
#       'decimals': 18}}],
#    'admins': [],
#    'members': ['0x4735581201F4cAD63CCa0716AB4ac7D6d9CFB0ed'],
#    'filters': {'minScore': 0, 'onlyMembers': False},
#    'plugins': {}},
#   {'id': 'idlefinance.eth',
#    'name': 'Idle DAO',
#    'about': 'Idle DAO off-chain polls for IDLE holders',
#    'network': '1',
#    'symbol': 'IDLE',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'IDLE',
#       'address': '0x875773784Af8135eA0ef43b5a374AaD105c5D39e',
#       'decimals': 18}},
#     {'name': 'erc20-balance-of',
#      'params': {'start': 11737307,
#       'symbol': 'LockedIDLE',
#       'address': '0xF241a0151841AE2E6ea750D50C5794b5EDC31D99',
#       'decimals': 18}},
#     {'name': 'uniswap',
#      'params': {'symbol': 'IDLE',
#       'address': '0x875773784Af8135eA0ef43b5a374AaD105c5D39e',
#       'decimals': 18}},
#     {'name': 'sushiswap',
#      'params': {'symbol': 'IDLE',
#       'address': '0x875773784Af8135eA0ef43b5a374AaD105c5D39e',
#       'decimals': 18}},
#     {'name': 'erc20-balance-of-delegation',
#      'params': {'symbol': 'IDLE',
#       'address': '0x875773784Af8135eA0ef43b5a374AaD105c5D39e',
#       'decimals': 18,
#       'delegationSpace': 'idlefinance.eth'}}],
#    'admins': ['0xe4E69ef860D3018B61A25134D60678be8628f780',
#     '0xb373F5f09d9875b94661776201165D01a7AE7bF7'],
#    'members': ['0xf27d7e8E96e891D77F42E1d88dA872A1cFaFe91a',
#     '0x4AF7cfbDbeF5ba845476652b79c0157D923E8207',
#     '0x2fa92128ecE3901395448bf62Dd5Ff6a35871540',
#     '0xe09E513301ba3717cBF50d9e67F85fAC249bb74d',
#     '0xeA173648F959790baea225cE3E75dF8A53a6BDE5',
#     '0xb373F5f09d9875b94661776201165D01a7AE7bF7',
#     '0x30723bb508E84706297EeF689C20096907023897',
#     '0xbD2D55b7F1693C4Fb337a89aCB12f657D5acFc82',
#     '0xDeBa9cd00120Ea0BE15955Cc3FA4b2d3E66Aa65d',
#     '0xfdA462548Ce04282f4B6D6619823a7C64Fdc0185'],
#    'filters': {'minScore': 100, 'onlyMembers': False},
#    'plugins': {}},
#   {'id': 'scradclub.eth',
#    'name': 'SCRAD Club',
#    'about': '',
#    'network': '1',
#    'symbol': 'SMT',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'SMT',
#       'address': '0xa6c5651f3f7f81bea6097a1a694bf819adbd1cfd',
#       'decimals': 0}}],
#    'admins': [],
#    'members': ['0x58E603d9824976F7a3940C6B408F0Ffa523a216C'],
#    'filters': {'minScore': 0, 'onlyMembers': False},
#    'plugins': {}},
#   {'id': 'pub-finance.eth',
#    'name': 'pub-finance',
#    'about': '',
#    'network': '1',
#    'symbol': 'PINT',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'PINT',
#       'address': '0xFECBa472B2540C5a2d3700b2C9E06F0aa7dC6462',
#       'decimals': 18}}],
#    'admins': [],
#    'members': [],
#    'filters': {'minScore': 50000, 'onlyMembers': False},
#    'plugins': {}},
#   {'id': 'saffronfinance.eth',
#    'name': 'saffron.finance',
#    'about': 'Welcome to Saffron, a peer-to-peer collateralization and risk exchange protocol. SFI holders decide which proposals are implemented on-chain',
#    'network': '1',
#    'symbol': 'SFI',
#    'strategies': [{'name': 'saffron-finance',
#      'params': {'symbol': 'SFIV1',
#       'contracts': [{'label': 'SFI',
#         'tokenAddress': '0xb753428af26e81097e7fd17f40c88aaa3e04902c',
#         'votingScheme': 'oneToOne'},
#        {'label': 'TEAM_HODL_TOKEN',
#         'tokenAddress': '0x4e5ee20900898054e998fd1862742c28c651bf5d',
#         'votingScheme': 'oneToOne'}],
#       'dexLpTypes': [{'name': 'uniswap',
#         'lpToken': '0xC76225124F3CaAb07f609b1D147a31de43926cd6'},
#        {'name': 'sushiswap',
#         'lpToken': '0x23a9292830Fc80dB7f563eDb28D2fe6fB47f8624'}],
#       'votingSchemes': [{'name': 'oneToOne',
#         'type': 'DirectBoostScheme',
#         'multiplier': 1},
#        {'name': 'staking', 'type': 'DirectBoostScheme', 'multiplier': 1.1},
#        {'name': 'uniswap', 'type': 'LPReservePairScheme', 'multiplier': 1.1},
#        {'name': 'sushiswap',
#         'type': 'LPReservePairScheme',
#         'multiplier': 1.1}]}},
#     {'name': 'saffron-finance-v2',
#      'params': {'symbol': 'SAFF_STAK_V2',
#       'decimals': 18,
#       'multiplier': 1.1,
#       'stakingPool': '0x4eB4C5911e931667fE1647428F38401aB1661763',
#       'singleAssets': ['0xb753428af26E81097e7fD17f40c88aaA3E04902c']}}],
#    'admins': ['0x9CfEC36a7b09c469DDf0D1558Eb92F7A88ED796b'],
#    'members': ['0x9CfEC36a7b09c469DDf0D1558Eb92F7A88ED796b',
#     '0xD90B866039E8820c2Cd082840fceeD81Cef691F8',
#     '0x44b6eaEA64a0f0a8828B32a9B9E103CD5eBfBBEb'],
#    'filters': {'minScore': 0.1, 'onlyMembers': False},
#    'plugins': {}},
#   {'id': 'sovi.eth',
#    'name': 'sovi.finance',
#    'about': '',
#    'network': '1',
#    'symbol': 'SOVI',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'DAI',
#       'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#       'decimals': 18}}],
#    'admins': [],
#    'members': ['0x560C2B75c7B4e077C71D66aE4E18b688D099963f',
#     '0x02e8e50913F7Fc1a22F48C1e7012cdc80B03d25a'],
#    'filters': {'minScore': 1, 'onlyMembers': True},
#    'plugins': {}},
#   {'id': 'monportefeuille.eth',
#    'name': 'Monportefeuille',
#    'about': '',
#    'network': '1',
#    'symbol': 'CIRCL',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'CIRCL',
#       'address': '0x63a2ccd492e316eefab5b3326db3c7b0a94c3726',
#       'decimals': 18}}],
#    'admins': [],
#    'members': ['0xa921789802E13243C6827D37526Ce632eF4A138b'],
#    'filters': {'minScore': 250, 'onlyMembers': True},
#    'plugins': {}},
#   {'id': 'flowcommunity.eth',
#    'name': 'Flow Protocol',
#    'about': '',
#    'network': '1',
#    'symbol': 'FLOW',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'FLOW',
#       'address': '0xC6e64729931f60D2c8Bc70A27D66D9E0c28D1BF9',
#       'decimals': 18}}],
#    'admins': [],
#    'members': [],
#    'filters': {'minScore': 51, 'onlyMembers': False},
#    'plugins': {}},
#   {'id': 'tradersquare.eth',
#    'name': 'Trader Square',
#    'about': '',
#    'network': '1',
#    'symbol': 'TRS',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'TRS',
#       'address': '0x1Ef4d930097D30689B16945Aa8286C62Ce7f75dF',
#       'decimals': 4}}],
#    'admins': [],
#    'members': ['0xf4945a878d7B464cAA4d383B3988a652661897d2',
#     '0xe2d088Ee9872dFd340A6B3fb5d0fD6B245CBe34a',
#     '0x890F598d391f4bA5A2d903301eC78B7E12C935FC'],
#    'filters': {'minScore': 0, 'onlyMembers': True},
#    'plugins': {}},
#   {'id': 'xionetwork.eth',
#    'name': '(old) Blockzero Labs',
#    'about': '',
#    'network': '1',
#    'symbol': 'XIO',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'XIO',
#       'address': '0x0f7F961648aE6Db43C75663aC7E5414Eb79b5704',
#       'decimals': 18}},
#     {'name': 'uniswap',
#      'params': {'symbol': 'XIO',
#       'address': '0x0f7F961648aE6Db43C75663aC7E5414Eb79b5704',
#       'decimals': 18}}],
#    'admins': [],
#    'members': ['0x11231f7Dc863F36A6516Eb4EF052f195000e0000',
#     '0xA0018Abd370A8B5CA89452f0711B653786F6264E',
#     '0xb0faa146515792276465F084f7c23E52F3B40839',
#     '0xA8A68CDe3aF5a932BE6a29a7E4975D1975f3E3AC',
#     '0x4BF4e3a59add035c479CDE89d98103Cb65DCa941',
#     '0xE73C98667C82bb76E58c0d9B065B6A0C9ea2d088'],
#    'filters': {'minScore': 0, 'onlyMembers': True},
#    'plugins': {}},
#   {'id': 'minkfinance.eth',
#    'name': 'Mink Finance',
#    'about': '',
#    'network': '1',
#    'symbol': 'MINK',
#    'strategies': [{'name': 'erc20-balance-of',
#      'params': {'symbol': 'MINK',
#       'address': '0x1D47F2A94d5a6d59D2A37eF47CA7f71b661654c8',
#       'decimals': 18}}],
#    'admins': [],
#    'members': ['0x9650F4feDd1e6ce63621479A4bf5F4d743E6F958'],
#    'filters': {'minScore': 0, 'onlyMembers': False},
#    'plugins': {}}]}

# %% [markdown]
# What if want to fetch all spaces? It's a bit cumbersome with standard POST requests, but we can use the [gql](https://pypi.org/project/gql/) client.

# %% [markdown]
# #### GQL Client

# %%
# !pip install gql
# !pip install aiohttp 
from gql import gql, Client
from gql.transport.aiohttp import AIOHTTPTransport

# %%
transport = AIOHTTPTransport(url=ENDPOINT)
client = Client(
    transport=transport
    #fetch_schema_from_transport=True
)

# %% [markdown]
# Let's test a simple query.
# First, we need build it, when we execute it.
#
# _Note:_ gql will throw an error if the query is malformed.

# %%
space_query = gql(
"""
query {
space(id: "yam.eth") {
    id
    name
    about
    network
    symbol
    members
    }
}
""")

# %%
## Error in Jupyter-like environments.
result = client.execute(space_query)
print(result)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-14-9dc131824f44> in <module>
#       1 ## Error in Jupyter-like environments.
# ----> 2 result = client.execute(space_query)
#       3 print(result)
#
# /opt/anaconda3/lib/python3.7/site-packages/gql/client.py in execute(self, document, variable_values, operation_name, serialize_variables, parse_result, get_execution_result, **kwargs)
#     382
#     383             assert not loop.is_running(), (
# --> 384                 "Cannot run client.execute(query) if an asyncio loop is running."
#     385                 " Use 'await client.execute_async(query)' instead."
#     386             )
#
# AssertionError: Cannot run client.execute(query) if an asyncio loop is running. Use 'await client.execute_async(query)' instead.

# %%
result = await client.execute_async(space_query)
print(result)
# Out:
# {'space': {'id': 'yam.eth', 'name': 'Yam', 'about': 'Only delegated YAM may be used to vote on proposals. You can delegate to yourself or another address here: yam.finance/#/delegate', 'network': '1', 'symbol': 'YAM', 'members': ['0x683A78bA1f6b25E29fbBC9Cd1BFA29A51520De84', '0x9Ebc8AD4011C7f559743Eb25705CCF5A9B58D0bc', '0xC3edCBe0F93a6258c3933e86fFaA3bcF12F8D695', '0xbdac5657eDd13F47C3DD924eAa36Cf1Ec49672cc', '0xEC3281124d4c2FCA8A88e3076C1E7749CfEcb7F2']}}

# %% [markdown]
# #### GraphQL Variables
#
# Now we want to fetch _all_ spaces.
#
# We need to use a special feature of GraphQL, that is the ability to pass **variables** into queries.
#
# Variables are identified by the dollar sign `$` and must indicate their type (e.g., `Int`).
#
# If a variable is mandatory, it is followed by an exclamation mark.

# %%
spaces_query = gql("""
  query ($first: Int!, $skip: Int!) {
    spaces(
      first: $first,
      skip: $skip,
      orderBy: "created",
      orderDirection: asc
    ) 
    {
      id
      name
      about
      network
      symbol
      strategies {
        name
        params
      }
      admins
      members
      filters {
        minScore
        onlyMembers
      }
      plugins
    }
  }
""")

# %%
## spaces_tmp is a temp variable we can use to store partial computations
## in case an error (e.g., a timeout) occurs
spaces_tmp = []

# %%
## Fetch'em all!
spaces = spaces_tmp
first = 1000
skip = len(spaces)
fetch = True
while fetch:
    vars = {"first": first, "skip": skip}
    res = await client.execute_async(spaces_query, variable_values=vars)
    # print(type(res))
    # print(res)
    
    if not res['spaces']:
        print('**I am done fetching!**')
        fetch = False
    else:
        spaces.extend(res['spaces'])
        print(len(spaces))
        skip += first# fetch = False
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10956
# **I am done fetching!**

# %%
len(spaces)
# Out:
# 10956

# %% [markdown]
# Let's put everything in a Pandas data frame.

# %%
df = pd.DataFrame(spaces)
df.info()
df['id'] = df['id'].astype('string')
df['name'] = df['name'].astype('string')
df['about'] = df['about'].astype('string')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10956 entries, 0 to 10955
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          10956 non-null  object
#  1   name        10956 non-null  object
#  2   about       10956 non-null  object
#  3   network     10956 non-null  object
#  4   symbol      10956 non-null  object
#  5   strategies  10956 non-null  object
#  6   admins      10956 non-null  object
#  7   members     10956 non-null  object
#  8   filters     10956 non-null  object
#  9   plugins     10956 non-null  object
# dtypes: object(10)
# memory usage: 856.1+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10956 entries, 0 to 10955
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          10956 non-null  string
#  1   name        10956 non-null  string
#  2   about       10956 non-null  string
#  3   network     10956 non-null  object
#  4   symbol      10956 non-null  object
#  5   strategies  10956 non-null  object
#  6   admins      10956 non-null  object
#  7   members     10956 non-null  object
#  8   filters     10956 non-null  object
#  9   plugins     10956 non-null  object
# dtypes: object(7), string(3)
# memory usage: 856.1+ KB

# %%
df.to_json("data/daos_snapshot.json", orient="records")

## Visually explore the saved file.
# Is it a mess? Prettify it with VS Code auto-formatter. 
# Don't you remember the shorcut? Check our python_warmup lecture.

# %%
df.head()
# Out:
#                  id           name                                    about  \
# 0    bonustrack.eth             Hi
# 1        fabien.eth         Fabien  This is nothing more than a test space.
# 2          ichi.eth      ichi.farm
# 3  loyalfinance.eth  loyal.finance
# 4       damflux.eth           FLUX
#
#   network     symbol                                         strategies  \
# 0       1     TICKET  [{'name': 'ticket', 'params': {'symbol': 'TICK...
# 1       1      POINT  [{'name': 'ticket', 'params': {'value': 100, '...
# 2       1  ICHIPOWAH  [{'name': 'erc20-balance-of', 'params': {'symb...
# 3       1       rLYL  [{'name': 'erc20-balance-of', 'params': {'symb...
# 4       1       FLUX  [{'name': 'erc20-balance-of', 'params': {'symb...
#
#                                               admins  \
# 0                                                 []
# 1  [0xeF8305E140ac520225DAf050e2f71d5fBcC543e7, 0...
# 2                                                 []
# 3                                                 []
# 4                                                 []
#
#                                              members  \
# 0  [0x24A12Fa313F57aF541d447c594072A992c605DCf, 0...
# 1       [0xeF8305E140ac520225DAf050e2f71d5fBcC543e7]
# 2       [0x873902a3c0731EcC1F2075435FE035ACCeEd5459]
# 3                                                 []
# 4                                                 []
#
#                                  filters  \
# 0  {'minScore': 0, 'onlyMembers': False}
# 1  {'minScore': 1, 'onlyMembers': False}
# 2  {'minScore': 0, 'onlyMembers': False}
# 3  {'minScore': 0, 'onlyMembers': False}
# 4  {'minScore': 0, 'onlyMembers': False}
#
#                                              plugins
# 0  {'safeSnap': {'address': '0xeF8305E140ac520225...
# 1  {'safeSnap': {'safes': [{'network': '4', 'real...
# 2                                                 {}
# 3                                                 {}
# 4                                                 {}

# %% [markdown]
# Now let's create a function to make our life easier.
#
# The function `gql_all` will fetch all paginated responses from an endpoint until it returns an empty response.
#
# _Notice:_ the _async_ keyword and the _try/except_ statement

# %%
async def gql_all(query, field, first=1000, skip=0, initial_list=None, 
                  counter = True):

    out = []
    
    if initial_list:
        out = initial_list
        skip = len(out)

    fetch = True
    try:
        while fetch:
            vars = {"first": first, "skip": skip}
            res = await client.execute_async(query, variable_values=vars)
            # print(type(res))
            # print(res)
            
            if not res[field]:
                print('**I am done fetching!**')
                fetch = False
            else:
                out.extend(res[field])
                skip += first# fetch = False
                if counter: print(len(out))
    except:
        print("**An error occurred, exiting early.**")
    
    return out

# %%
res = await gql_all(spaces_query, "spaces")
# Out:
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000
# 10956
# **I am done fetching!**

# %%
res
# Out:
# [{'id': 'bonustrack.eth',
#   'name': 'Hi',
#   'about': '',
#   'network': '1',
#   'symbol': 'TICKET',
#   'strategies': [{'name': 'ticket', 'params': {'symbol': 'TICKET'}}],
#   'admins': [],
#   'members': ['0x24A12Fa313F57aF541d447c594072A992c605DCf',
#    '0x8BBE4Ac64246d600BC2889ef5d83809D138F03DF',
#    '0xeF8305E140ac520225DAf050e2f71d5fBcC543e7',
#    '0x107174D70b33523E83711EA4C3F4229cdB8A7Cb1',
#    '0x0b21Dbc34A953a35dFA629ad31e1cEE3dE0433Fb',
#    '0x40FDAa1bff3BB87bC70955Be6657edBFdBeb122e',
#    '0xcc6A949DB9b26a7173648d50Cf7C55e800E6585B',
#    '0xC1C8ac723Fd9Db3db6E947dF42aaEdd28058A31D'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {'safeSnap': {'address': '0xeF8305E140ac520225DAf050e2f71d5fBcC543e7'}}},
#  {'id': 'fabien.eth',
#   'name': 'Fabien',
#   'about': 'This is nothing more than a test space.',
#   'network': '1',
#   'symbol': 'POINT',
#   'strategies': [{'name': 'ticket',
#     'params': {'value': 100, 'symbol': 'POINT'}}],
#   'admins': ['0xeF8305E140ac520225DAf050e2f71d5fBcC543e7',
#    '0x4C7909d6F029b3a5798143C843F4f8e5341a3473'],
#   'members': ['0xeF8305E140ac520225DAf050e2f71d5fBcC543e7'],
#   'filters': {'minScore': 1, 'onlyMembers': False},
#   'plugins': {'safeSnap': {'safes': [{'network': '4',
#       'realityAddress': '0xF8Ca72b0d427F0b3e8984133C8A6860153b4f2D8'}]}}},
#  {'id': 'ichi.eth',
#   'name': 'ichi.farm',
#   'about': '',
#   'network': '1',
#   'symbol': 'ICHIPOWAH',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'ICHIPOWAH',
#      'address': '0x873902a3c0731EcC1F2075435FE035ACCeEd5459',
#      'decimals': 9}}],
#   'admins': [],
#   'members': ['0x873902a3c0731EcC1F2075435FE035ACCeEd5459'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'loyalfinance.eth',
#   'name': 'loyal.finance',
#   'about': '',
#   'network': '1',
#   'symbol': 'rLYL',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'RLYL',
#      'address': '0x0C9BbF4364F90db22B1B21b45177069a078842Aa',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'damflux.eth',
#   'name': 'FLUX',
#   'about': '',
#   'network': '1',
#   'symbol': 'FLUX',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'FLUX',
#      'address': '0x469eDA64aEd3A3Ad6f868c44564291aA415cB1d9',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'ufode.eth',
#   'name': 'UFO Finance',
#   'about': '',
#   'network': '1',
#   'symbol': 'UFO',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'boringvote.eth',
#   'name': 'BoringDAO',
#   'about': '',
#   'network': '1',
#   'symbol': 'BoringDAO VS',
#   'strategies': [{'name': 'contract-call',
#     'params': {'symbol': 'BoringDAO VS',
#      'address': '0xdd018AD3D79bF8aA7C2E9726b566f7aeeF693618',
#      'decimals': 18,
#      'methodABI': {'name': 'balanceOf',
#       'type': 'function',
#       'inputs': [{'name': '_voter',
#         'type': 'address',
#         'internalType': 'address'}],
#       'outputs': [{'name': '', 'type': 'uint256', 'internalType': 'uint256'}],
#       'stateMutability': 'view'}}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'relayernetwork.eth',
#   'name': 'Relayer Network',
#   'about': '',
#   'network': '1',
#   'symbol': 'RLR',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'RLR',
#      'address': '0x0e3ef895c59e7db27214ab5bbf56347ce115a3f4',
#      'decimals': 18}},
#    {'name': 'erc20-balance-of-delegation',
#     'params': {'symbol': 'RLR',
#      'address': '0x0e3ef895c59e7db27214ab5bbf56347ce115a3f4',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'prophetfinance.eth',
#   'name': 'prophet.finance',
#   'about': '',
#   'network': '1',
#   'symbol': 'PROPHET',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'PROPHET',
#      'address': '0x8d5db0c1f0681071cb38a382ae6704588d9da587',
#      'decimals': 9}}],
#   'admins': [],
#   'members': ['0xcA670BC7D254C2a4b050Dbb05aD8f3db57Fd43Cd',
#    '0xe2f071Fa6a421c6Bd7DF3635cC001c569182B950'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'liddao.eth',
#   'name': 'Lid Dao',
#   'about': '',
#   'network': '1',
#   'symbol': 'Lid Dao',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'LID-vr',
#      'address': '0xb271e47E8AbD99df2f6275793eF838B0Ee0866c9',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x4735581201F4cAD63CCa0716AB4ac7D6d9CFB0ed'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'idlefinance.eth',
#   'name': 'Idle DAO',
#   'about': 'Idle DAO off-chain polls for IDLE holders',
#   'network': '1',
#   'symbol': 'IDLE',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'IDLE',
#      'address': '0x875773784Af8135eA0ef43b5a374AaD105c5D39e',
#      'decimals': 18}},
#    {'name': 'erc20-balance-of',
#     'params': {'start': 11737307,
#      'symbol': 'LockedIDLE',
#      'address': '0xF241a0151841AE2E6ea750D50C5794b5EDC31D99',
#      'decimals': 18}},
#    {'name': 'uniswap',
#     'params': {'symbol': 'IDLE',
#      'address': '0x875773784Af8135eA0ef43b5a374AaD105c5D39e',
#      'decimals': 18}},
#    {'name': 'sushiswap',
#     'params': {'symbol': 'IDLE',
#      'address': '0x875773784Af8135eA0ef43b5a374AaD105c5D39e',
#      'decimals': 18}},
#    {'name': 'erc20-balance-of-delegation',
#     'params': {'symbol': 'IDLE',
#      'address': '0x875773784Af8135eA0ef43b5a374AaD105c5D39e',
#      'decimals': 18,
#      'delegationSpace': 'idlefinance.eth'}}],
#   'admins': ['0xe4E69ef860D3018B61A25134D60678be8628f780',
#    '0xb373F5f09d9875b94661776201165D01a7AE7bF7'],
#   'members': ['0xf27d7e8E96e891D77F42E1d88dA872A1cFaFe91a',
#    '0x4AF7cfbDbeF5ba845476652b79c0157D923E8207',
#    '0x2fa92128ecE3901395448bf62Dd5Ff6a35871540',
#    '0xe09E513301ba3717cBF50d9e67F85fAC249bb74d',
#    '0xeA173648F959790baea225cE3E75dF8A53a6BDE5',
#    '0xb373F5f09d9875b94661776201165D01a7AE7bF7',
#    '0x30723bb508E84706297EeF689C20096907023897',
#    '0xbD2D55b7F1693C4Fb337a89aCB12f657D5acFc82',
#    '0xDeBa9cd00120Ea0BE15955Cc3FA4b2d3E66Aa65d',
#    '0xfdA462548Ce04282f4B6D6619823a7C64Fdc0185'],
#   'filters': {'minScore': 100, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'scradclub.eth',
#   'name': 'SCRAD Club',
#   'about': '',
#   'network': '1',
#   'symbol': 'SMT',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'SMT',
#      'address': '0xa6c5651f3f7f81bea6097a1a694bf819adbd1cfd',
#      'decimals': 0}}],
#   'admins': [],
#   'members': ['0x58E603d9824976F7a3940C6B408F0Ffa523a216C'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'pub-finance.eth',
#   'name': 'pub-finance',
#   'about': '',
#   'network': '1',
#   'symbol': 'PINT',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'PINT',
#      'address': '0xFECBa472B2540C5a2d3700b2C9E06F0aa7dC6462',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 50000, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'saffronfinance.eth',
#   'name': 'saffron.finance',
#   'about': 'Welcome to Saffron, a peer-to-peer collateralization and risk exchange protocol. SFI holders decide which proposals are implemented on-chain',
#   'network': '1',
#   'symbol': 'SFI',
#   'strategies': [{'name': 'saffron-finance',
#     'params': {'symbol': 'SFIV1',
#      'contracts': [{'label': 'SFI',
#        'tokenAddress': '0xb753428af26e81097e7fd17f40c88aaa3e04902c',
#        'votingScheme': 'oneToOne'},
#       {'label': 'TEAM_HODL_TOKEN',
#        'tokenAddress': '0x4e5ee20900898054e998fd1862742c28c651bf5d',
#        'votingScheme': 'oneToOne'}],
#      'dexLpTypes': [{'name': 'uniswap',
#        'lpToken': '0xC76225124F3CaAb07f609b1D147a31de43926cd6'},
#       {'name': 'sushiswap',
#        'lpToken': '0x23a9292830Fc80dB7f563eDb28D2fe6fB47f8624'}],
#      'votingSchemes': [{'name': 'oneToOne',
#        'type': 'DirectBoostScheme',
#        'multiplier': 1},
#       {'name': 'staking', 'type': 'DirectBoostScheme', 'multiplier': 1.1},
#       {'name': 'uniswap', 'type': 'LPReservePairScheme', 'multiplier': 1.1},
#       {'name': 'sushiswap',
#        'type': 'LPReservePairScheme',
#        'multiplier': 1.1}]}},
#    {'name': 'saffron-finance-v2',
#     'params': {'symbol': 'SAFF_STAK_V2',
#      'decimals': 18,
#      'multiplier': 1.1,
#      'stakingPool': '0x4eB4C5911e931667fE1647428F38401aB1661763',
#      'singleAssets': ['0xb753428af26E81097e7fD17f40c88aaA3E04902c']}}],
#   'admins': ['0x9CfEC36a7b09c469DDf0D1558Eb92F7A88ED796b'],
#   'members': ['0x9CfEC36a7b09c469DDf0D1558Eb92F7A88ED796b',
#    '0xD90B866039E8820c2Cd082840fceeD81Cef691F8',
#    '0x44b6eaEA64a0f0a8828B32a9B9E103CD5eBfBBEb'],
#   'filters': {'minScore': 0.1, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'sovi.eth',
#   'name': 'sovi.finance',
#   'about': '',
#   'network': '1',
#   'symbol': 'SOVI',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x560C2B75c7B4e077C71D66aE4E18b688D099963f',
#    '0x02e8e50913F7Fc1a22F48C1e7012cdc80B03d25a'],
#   'filters': {'minScore': 1, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'monportefeuille.eth',
#   'name': 'Monportefeuille',
#   'about': '',
#   'network': '1',
#   'symbol': 'CIRCL',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'CIRCL',
#      'address': '0x63a2ccd492e316eefab5b3326db3c7b0a94c3726',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0xa921789802E13243C6827D37526Ce632eF4A138b'],
#   'filters': {'minScore': 250, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'flowcommunity.eth',
#   'name': 'Flow Protocol',
#   'about': '',
#   'network': '1',
#   'symbol': 'FLOW',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'FLOW',
#      'address': '0xC6e64729931f60D2c8Bc70A27D66D9E0c28D1BF9',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 51, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'tradersquare.eth',
#   'name': 'Trader Square',
#   'about': '',
#   'network': '1',
#   'symbol': 'TRS',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'TRS',
#      'address': '0x1Ef4d930097D30689B16945Aa8286C62Ce7f75dF',
#      'decimals': 4}}],
#   'admins': [],
#   'members': ['0xf4945a878d7B464cAA4d383B3988a652661897d2',
#    '0xe2d088Ee9872dFd340A6B3fb5d0fD6B245CBe34a',
#    '0x890F598d391f4bA5A2d903301eC78B7E12C935FC'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'xionetwork.eth',
#   'name': '(old) Blockzero Labs',
#   'about': '',
#   'network': '1',
#   'symbol': 'XIO',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'XIO',
#      'address': '0x0f7F961648aE6Db43C75663aC7E5414Eb79b5704',
#      'decimals': 18}},
#    {'name': 'uniswap',
#     'params': {'symbol': 'XIO',
#      'address': '0x0f7F961648aE6Db43C75663aC7E5414Eb79b5704',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x11231f7Dc863F36A6516Eb4EF052f195000e0000',
#    '0xA0018Abd370A8B5CA89452f0711B653786F6264E',
#    '0xb0faa146515792276465F084f7c23E52F3B40839',
#    '0xA8A68CDe3aF5a932BE6a29a7E4975D1975f3E3AC',
#    '0x4BF4e3a59add035c479CDE89d98103Cb65DCa941',
#    '0xE73C98667C82bb76E58c0d9B065B6A0C9ea2d088'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'minkfinance.eth',
#   'name': 'Mink Finance',
#   'about': '',
#   'network': '1',
#   'symbol': 'MINK',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'MINK',
#      'address': '0x1D47F2A94d5a6d59D2A37eF47CA7f71b661654c8',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x9650F4feDd1e6ce63621479A4bf5F4d743E6F958'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'mutualdao.eth',
#   'name': 'MutualDAO',
#   'about': '',
#   'network': '1',
#   'symbol': 'MDS',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'MDS',
#      'address': '0x66186008C1050627F979d464eABb258860563dbE',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x00f57c080d7746b607708699bc9c3af289a0b56a'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'esd.eth',
#   'name': 'Empty Set',
#   'about': 'A decentralized, censorship resistant, stablecoin built for DeFi',
#   'network': '1',
#   'symbol': 'ESS',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'ESS',
#      'address': '0x24aE124c4CC33D6791F8E8B63520ed7107ac8b3e',
#      'decimals': 18}},
#    {'name': 'delegation',
#     'params': {'symbol': 'ESS (delegated)',
#      'strategies': [{'name': 'erc20-balance-of',
#        'params': {'address': '0x24aE124c4CC33D6791F8E8B63520ed7107ac8b3e',
#         'decimals': 18}}]}}],
#   'admins': [],
#   'members': ['0xB0B2b405c9D09d129E9F9b18c9DD218c532f2b2A',
#    '0x0FeBbB3f91fae9BDC2f86B82c1b61a1dF6c6a5e8',
#    '0x264297e93B09430a81a31368F243EDe8500A5E6d',
#    '0x7ed9F10b5299b44D28F2AEBf8D057919698cB94A',
#    '0xC85170886A7F34e1365E2aA04486ae8F1106F783',
#    '0xDbFcA4a2807F4EF3efdDc10F3EaDc84714D8c333',
#    '0x37Ed74A0dA66c0392C4c5901c3b3B97675871FE1'],
#   'filters': {'minScore': 100000, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'vote.southchain.eth',
#   'name': 'SouthChain Digital Asset Network',
#   'about': '',
#   'network': '1',
#   'symbol': 'SCT',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'SCT',
#      'address': '0x98f2e50eECA2352b60E1Dad37f93Dc9113a07BE9',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x51A33a5bBa82f8EBd0fE2192A25CA2E60B9Dc32f',
#    '0x54c787bA416570B72B5Da1457a7bE0932261f9b2',
#    '0x6Bc5d7C5cb2371A1923499F7a38717261Dadb559',
#    '0x2C9754cc6E982530c7fC41CA1edA622d780Cf49d'],
#   'filters': {'minScore': 10000, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'flushlol.eth',
#   'name': 'FLUSH',
#   'about': '',
#   'network': '1',
#   'symbol': 'PAPER',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'PAPER',
#      'address': '0xdDce093888C8Dc636677Cd29BC6C68D35cFDAC33',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0xcd9B0611bAD3c052215968bA5CBD7A0A51549BA6'],
#   'filters': {'minScore': 10, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'xethfinance.eth',
#   'name': 'xETH Finance',
#   'about': '',
#   'network': '1',
#   'symbol': 'xETH-G',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'xETH-G',
#      'address': '0x3863ea7577fc91bfbaeae6a6a3e403524afcf787',
#      'decimals': 18}},
#    {'name': 'staked-uniswap',
#     'params': {'symbol': 'xETH-G',
#      'decimals': 18,
#      'tokenAddress': '0x3863EA7577fc91bFBaEAE6A6a3E403524aFcf787',
#      'stakingAddress': '0x022e6461e01af241a81b2e6a661111efa852e976',
#      'uniswapAddress': '0x6ff249432df165f209782995dc27c9c53bd11ee1'}},
#    {'name': 'contract-call',
#     'params': {'symbol': 'xETH-G',
#      'address': '0x304D4F1abB117aaB97C6AC34b97fE14348A3Be10',
#      'decimals': 18,
#      'methodABI': {'name': 'balanceOf',
#       'type': 'function',
#       'inputs': [{'name': 'voter',
#         'type': 'address',
#         'internalType': 'address'}],
#       'outputs': [{'name': '', 'type': 'uint256', 'internalType': 'uint256'}],
#       'stateMutability': 'view'}}}],
#   'admins': [],
#   'members': ['0x95df7d90fc5822Ef1140Fb9aB37A9fF2a94356A2'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'dodobird.eth',
#   'name': 'DODO',
#   'about': 'DODO is a decentralized exchange platform powered by the Proactive Market Maker (PMM) algorithm.',
#   'network': '1',
#   'symbol': 'DODO',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DODO',
#      'address': '0x43Dfc4159D86F3A37A5A4B3D4580b888ad7d4DDd',
#      'decimals': 18}},
#    {'name': 'erc20-balance-of-coeff',
#     'params': {'coeff': 100,
#      'symbol': 'vDODO',
#      'address': '0xc4436fBAE6eBa5d95bf7d53Ae515F8A707Bd402A',
#      'decimals': 18}},
#    {'name': 'multichain',
#     'params': {'symbol': 'BSC DODO',
#      'strategies': [{'name': 'erc20-balance-of',
#        'params': {'address': '0x67ee3Cb086F8a16f34beE3ca72FAD36F7Db929e2',
#         'decimals': 18},
#        'network': '56'}]}},
#    {'name': 'multichain',
#     'params': {'symbol': 'Arbitrum DODO',
#      'strategies': [{'name': 'erc20-balance-of',
#        'params': {'address': '0x69Eb4FA4a2fbd498C257C57Ea8b7655a2559A581',
#         'decimals': 18},
#        'network': '42161'}]}},
#    {'name': 'multichain',
#     'params': {'symbol': 'Polygon DODO',
#      'strategies': [{'name': 'erc20-balance-of',
#        'params': {'address': '0xe4bf2864ebec7b7fdf6eeca9bacae7cdfdaffe78',
#         'decimals': 18},
#        'network': '137'}]}}],
#   'admins': ['0xd088dBF014335d679fac2b7c6359018f8ed952BB',
#    '0x0fBC222aDF84bEE9169022b28ebc3D32b5C60756',
#    '0xC1068213b81c7A18E88063e998519d5EBB01efE2'],
#   'members': ['0xd088dBF014335d679fac2b7c6359018f8ed952BB'],
#   'filters': {'minScore': 100000, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'archerdao.eth',
#   'name': 'Archer DAO',
#   'about': '',
#   'network': '1',
#   'symbol': 'ARCH',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'AVP',
#      'address': '0x000100bB517E0c003200502A822083000a3B005d',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x8d775aeA4533253327FE70be28F6a56166ddD951',
#    '0x848Df9eFee9Fe8b473Ad456CFd46364461B5BC75',
#    '0x4530B100BF6400268E22fE64d7548fFaafA8dC39'],
#   'filters': {'minScore': 20000, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'bbra.eth',
#   'name': 'BooBanker Research Association',
#   'about': '',
#   'network': '1',
#   'symbol': 'BBRA',
#   'strategies': [{'name': 'contract-call',
#     'params': {'symbol': 'BBRA',
#      'address': '0x19e5680201231B5Ef3038063Ff801C1b50770Ee5',
#      'decimals': 18,
#      'methodABI': {'name': 'balanceOf',
#       'type': 'function',
#       'inputs': [{'name': '_user',
#         'type': 'address',
#         'internalType': 'address'}],
#       'outputs': [{'name': '', 'type': 'uint256', 'internalType': 'uint256'}],
#       'stateMutability': 'view'}}}],
#   'admins': [],
#   'members': ['0x02480f3Fc4c53885f6b5d2eC723025C8ce0DE264',
#    '0xD5b790E299c7a46407c16E2Ec94B893046aB478E'],
#   'filters': {'minScore': 1, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'truegov.eth',
#   'name': 'TrueFi-Test',
#   'about': '',
#   'network': '1',
#   'symbol': 'TRU',
#   'strategies': [{'name': 'contract-call',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0xf6E2Da7D82ee49f76CE652bc0BeB546Cbe0Ea521'],
#   'filters': {'minScore': 1500, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'keep2r.eth',
#   'name': 'Keep2r',
#   'about': '',
#   'network': '1',
#   'symbol': 'KP2R',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'KP2R',
#      'address': '0x9BdE098Be22658d057C3F1F185e3Fd4653E2fbD1',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x69ba033E6622e76f10C733A38aB8a9A6a6C1Ce4B',
#    '0x5E47b8155E4D66d5A88437D471e80daEb4Df9498',
#    '0xB2b4076a36b8993094cBfdb72512820B8BeDb6Ce',
#    '0xb058daD825A8E84cB453949bEFc4f7e77CaAa65E'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'meter-eth.eth',
#   'name': 'Meter Ethereum eMTRG',
#   'about': '',
#   'network': '1',
#   'symbol': 'eMTRG',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'eMTRG',
#      'address': '0xBd2949F67DcdC549c6Ebe98696449Fa79D988A9F',
#      'decimals': 18}},
#    {'name': 'uniswap',
#     'params': {'symbol': 'eMTRG LPT',
#      'address': '0xBd2949F67DcdC549c6Ebe98696449Fa79D988A9F',
#      'decimals': 18}},
#    {'name': 'balancer',
#     'params': {'symbol': 'eMTRG BPT',
#      'address': '0xBd2949F67DcdC549c6Ebe98696449Fa79D988A9F',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x0aB5ddA6f096E127AF74d4b64A101ac6C43FA128',
#    '0x78e6f3af2bf71afa209c6e81b161c6a41d2da79d',
#    '0xa755Cff7308Ac068c55EB141fbFDE822ee6FFcdd',
#    '0xf6B5FD8e2CAC43987DE603ce7942E09e2DC8A2C9'],
#   'filters': {'minScore': 100, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'meter-mainnet.eth',
#   'name': 'Meter Governance MTRG',
#   'about': '',
#   'network': '82',
#   'symbol': 'MTRG',
#   'strategies': [{'name': 'contract-call',
#     'params': {'symbol': 'MTRG',
#      'address': '0x5729cb3716a315d0bde3b5e489163bf8b9659436',
#      'decimals': 18,
#      'methodABI': {'name': 'balanceOfBoundMtrg',
#       'type': 'function',
#       'inputs': [{'name': 'account',
#         'type': 'address',
#         'internalType': 'address'}],
#       'outputs': [{'name': '', 'type': 'uint256', 'internalType': 'uint256'}],
#       'stateMutability': 'view'}}},
#    {'name': 'erc20-balance-of',
#     'params': {'symbol': 'MTRG',
#      'address': '0x228ebBeE999c6a7ad74A6130E81b12f9Fe237Ba3',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x0aB5ddA6f096E127AF74d4b64A101ac6C43FA128',
#    '0x78e6f3af2bf71afa209c6e81b161c6a41d2da79d',
#    '0xa755Cff7308Ac068c55EB141fbFDE822ee6FFcdd',
#    '0xf6B5FD8e2CAC43987DE603ce7942E09e2DC8A2C9',
#    '0x0F8684F6dC76617D6831B4546381eb6CFB1C559F'],
#   'filters': {'minScore': 100, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'communitytoken.eth',
#   'name': 'Community Token',
#   'about': '',
#   'network': '1',
#   'symbol': 'COM',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'COM',
#      'address': '0x1b4052d98fb1888c2bf3b8d3b930e0aff8a910df',
#      'decimals': 18}},
#    {'name': 'contract-call',
#     'params': {'symbol': 'COM',
#      'address': '0xbB687EC3e1EfD71c58164147899DFEa54c9dAb6e',
#      'decimals': 18,
#      'methodABI': {'name': 'balanceOf',
#       'type': 'function',
#       'inputs': [{'name': 'voter',
#         'type': 'address',
#         'internalType': 'address'}],
#       'outputs': [{'name': '', 'type': 'uint256', 'internalType': 'uint256'}],
#       'stateMutability': 'view'}}}],
#   'admins': [],
#   'members': ['0x95df7d90fc5822Ef1140Fb9aB37A9fF2a94356A2'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'ceproject.eth',
#   'name': 'CEProject',
#   'about': '',
#   'network': '1',
#   'symbol': 'CEP',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'BDC',
#      'address': '0xa6e24154944bec5106ed416a6df1fb241ccb523b',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'dfking.eth',
#   'name': 'Defiking',
#   'about': '',
#   'network': '1',
#   'symbol': 'DFK',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'swarmnetwork.eth',
#   'name': 'Swarm Network',
#   'about': '',
#   'network': '1',
#   'symbol': 'SWM',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'SWM',
#      'address': '0x3505f494c3f0fed0b594e01fa41dd3967645ca39',
#      'decimals': 18}},
#    {'name': 'masterchef-pool-balance',
#     'params': {'pid': '0',
#      'symbol': 'SWM',
#      'chefAddress': '0xE13c0Ec78D283eb8Cca72Edd018a9c13AD0E002a'}},
#    {'name': 'masterchef-pool-balance',
#     'params': {'pid': '1',
#      'symbol': 'SWM',
#      'chefAddress': '0xE13c0Ec78D283eb8Cca72Edd018a9c13AD0E002a',
#      'uniPairAddress': '0xe0b1433e0174b47e8879ee387f1069a0dbf94137'}}],
#   'admins': [],
#   'members': ['0x102D67E6d2BcdC5f66C079d4a383d3cefA5023b0',
#    '0xd56c6E89DA9F6cEab903878b98B1D91CfE1024D9'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'gokai.eth',
#   'name': 'Gokai',
#   'about': '',
#   'network': '1',
#   'symbol': 'GKI',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x71dFf12E24Db711b99a64a8A1d904cd256A49e58',
#    '0x41646Fb881Acd56bad144B343A3525B6907Bc86b'],
#   'filters': {'minScore': 10000, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'midas-defi.eth',
#   'name': 'Midas',
#   'about': '',
#   'network': '1',
#   'symbol': 'MDS',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'MDS',
#      'address': '0x0290B327A8583bD6FA63c130B732a808864e55Fc',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x4150f70235FA3d017AA67b1eeaC377f46BD76953'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'btfinance.eth',
#   'name': 'BT.Finance',
#   'about': '',
#   'network': '1',
#   'symbol': 'BT',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'BT',
#      'address': '0x85E129b851d07D942e743f9444D637f57d3E3767',
#      'decimals': 9}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': '0xEaDC218Ac4cB7895a5A56e6484646b48f841C45a.eth',
#   'name': 'odanonchoose',
#   'about': '',
#   'network': '1',
#   'symbol': 'odc',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'moltenfinance.eth',
#   'name': 'MOLTEN',
#   'about': '',
#   'network': '1',
#   'symbol': 'MOL',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'MOL',
#      'address': '0x1443e7c1cce72662545d94779120c59251447e91',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x3E8D2bCc6503E684eE0FFaaA89d30bE6ce91dD14'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'decentralgames.eth',
#   'name': 'Decentral Games',
#   'about': 'Decentral Games builds games that give players economic freedom through aligned incentives, self-custody and delegation of yield-bearing metaverse assets. ',
#   'network': '1',
#   'symbol': 'xDG',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'xDG',
#      'address': '0x4f81c790581b240a5c948afd173620ecc8c71c8d',
#      'decimals': 18}},
#    {'name': 'erc20-balance-of',
#     'params': {'symbol': 'xDG',
#      'address': '0xc6480da81151b2277761024599e8db2ad4c388c8',
#      'decimals': 18}},
#    {'name': 'erc20-balance-of-delegation',
#     'params': {'symbol': 'xDG',
#      'address': '0x4f81c790581b240a5c948afd173620ecc8c71c8d',
#      'decimals': 18,
#      'delegationSpace': 'decentralgames.eth'}},
#    {'name': 'erc20-balance-of-delegation',
#     'params': {'symbol': 'xDG',
#      'address': '0xc6480da81151b2277761024599e8db2ad4c388c8',
#      'decimals': 18,
#      'delegationSpace': 'decentralgames.eth'}}],
#   'admins': ['0x7146cae915f1Cd90871ecc69999BEfFdcaf38ff9'],
#   'members': ['0x7e5DCA041b0E91Af20142aE96081EEc9D73d2af9',
#    '0xE2be94B59a3A4Aef2F66Eb0dD73079da00315BF0',
#    '0x5E42f33749A9CbBE7AfA732191BB4C282a3866C2',
#    '0xb3Ab3a2f58a7d91Fe3Dcf9ABAd53C0dD1603B847'],
#   'filters': {'minScore': 100000, 'onlyMembers': False},
#   'plugins': {'poap': {}}},
#  {'id': 'metapoolgov.eth',
#   'name': 'MetaFinance',
#   'about': '',
#   'network': '56',
#   'symbol': 'MFI',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'MFI',
#      'address': '0x808f1350dff684C099F4837A01D863fC61A86BC6',
#      'decimals': 18}}],
#   'admins': ['0xd57DA064AE651Ade95f5827B39A81298cF8cf1E4'],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'nftgoddessart.eth',
#   'name': 'nftgoddess.art',
#   'about': '',
#   'network': '1',
#   'symbol': 'GDS',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'GDS',
#      'address': '0xdB78f97B26757330bEDC2b4d9729c3E4C4560736',
#      'decimals': 18}},
#    {'name': 'staked-uniswap',
#     'params': {'symbol': 'GDS',
#      'decimals': 18,
#      'tokenAddress': '0xdB78f97B26757330bEDC2b4d9729c3E4C4560736',
#      'stakingAddress': '0x29d7D9C1025eaC6A572ce51e351D59c80C71B57F',
#      'uniswapAddress': '0x0a234e34b9ce8e2013b18abdd136d3fd9d094117'}},
#    {'name': 'erc20-balance-of',
#     'params': {'symbol': 'SC',
#      'address': '0x556890075123744AF24D38954bB320aE2Dd00c88',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x8DB6A3FE0f238ed9f9E440fbeD33d6C25E06D8a5',
#    '0x49c7B67C2aB965dc74f17e5E7FdFE9783a832181'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'coopnetwork.eth',
#   'name': 'thecoopnetwork',
#   'about': '',
#   'network': '1',
#   'symbol': 'Coop',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'badgerdao.eth',
#   'name': 'BadgerDAO',
#   'about': '',
#   'network': '1',
#   'symbol': 'BADGER',
#   'strategies': [{'name': 'pagination',
#     'params': {'symbol': 'vsBADGER',
#      'strategy': {'name': 'erc20-balance-of',
#       'params': {'address': '0x49fa0D0619BdeD9aAc4106974E34CeB516bdeAeF',
#        'decimals': 18}}}},
#    {'name': 'delegation',
#     'params': {'symbol': 'vsBADGER',
#      'strategies': [{'name': 'erc20-balance-of',
#        'params': {'symbol': 'vsBADGER', 'address': '', 'decimals': 18}}]}},
#    {'name': 'multichain',
#     'params': {'symbol': 'BADGER',
#      'strategies': [{'name': 'erc20-balance-of',
#        'params': {'address': '0x1fcbe5937b0cc2adf69772d228fa4205acf4d9b2',
#         'decimals': 18},
#        'network': '137'},
#       {'name': 'erc20-balance-of',
#        'params': {'address': '0x47752Ff9d07EC7803694860566a83356A9eb5f51',
#         'decimals': 18},
#        'network': '42161'},
#       {'name': 'erc20-balance-of',
#        'params': {'address': '0x753fbc5800a8C8e3Fb6DC6415810d627A387Dfc9',
#         'decimals': 18},
#        'network': '250'}]}}],
#   'admins': ['0xf3Fc0aAE46D4917c022cd0abF1435493C9Ddf8cC'],
#   'members': ['0x6b3eF8E2446136bCD885Ced8686e6D785B3482c8',
#    '0xD1e5bE16a4f1EfE5ad21cC0F0c73FB8Ea8D1edCe',
#    '0x592F75a830Fd400C4f308388FDd6FEad5351e20a',
#    '0xFcdF725929D73CE97e358a0ca0904451Cb34108E',
#    '0x29C3Bf1254e499Bb29Fa7560d3E9522a46eDF5B1',
#    '0xf3Fc0aAE46D4917c022cd0abF1435493C9Ddf8cC'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'yam.eth',
#   'name': 'Yam',
#   'about': 'Only delegated YAM may be used to vote on proposals. You can delegate to yourself or another address here: yam.finance/#/delegate',
#   'network': '1',
#   'symbol': 'YAM',
#   'strategies': [{'name': 'contract-call',
#     'params': {'symbol': 'YAM LP',
#      'address': '0xc32f9b0292965c5dd4a0ea1abfcc1f5a36d66986',
#      'decimals': 24,
#      'methodABI': {'name': 'getCurrentVotes',
#       'type': 'function',
#       'inputs': [{'name': 'owner',
#         'type': 'address',
#         'internalType': 'address'}],
#       'outputs': [{'name': '', 'type': 'uint256', 'internalType': 'uint256'}],
#       'payable': False,
#       'constant': False,
#       'stateMutability': 'nonpayable'}}}],
#   'admins': ['0x9Ebc8AD4011C7f559743Eb25705CCF5A9B58D0bc'],
#   'members': ['0x683A78bA1f6b25E29fbBC9Cd1BFA29A51520De84',
#    '0x9Ebc8AD4011C7f559743Eb25705CCF5A9B58D0bc',
#    '0xC3edCBe0F93a6258c3933e86fFaA3bcF12F8D695',
#    '0xbdac5657eDd13F47C3DD924eAa36Cf1Ec49672cc',
#    '0xEC3281124d4c2FCA8A88e3076C1E7749CfEcb7F2'],
#   'filters': {'minScore': 100, 'onlyMembers': False},
#   'plugins': {'quorum': {'total': 200000, 'strategy': 'static'}}},
#  {'id': 'gov.cap.eth',
#   'name': 'Cap',
#   'about': '',
#   'network': '1',
#   'symbol': 'CAP',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}},
#    {'name': 'contract-call',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0xbCe17D1c44B39F7ccD4F4f9f69941B83c9F4f92f'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'honeyfinance.eth',
#   'name': 'Honey Finance',
#   'about': '',
#   'network': '1',
#   'symbol': 'HONEY',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'HONEY',
#      'address': '0x37C9EB4CeF7571f27136145C82c37a01F2a8Aa16',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x179047339A1c38F8A7820D89B401fD32179158a0'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'aavegotchi.eth',
#   'name': 'Aavegotchi',
#   'about': '',
#   'network': '137',
#   'symbol': 'GHST',
#   'strategies': [{'name': 'pagination',
#     'params': {'limit': 200,
#      'symbol': 'GHST',
#      'strategy': {'name': 'aavegotchi',
#       'params': {'decimals': 18,
#        'tokenAddress': '0x385Eeac5cB85A38A9a07A70c73e0a3271CfB54A7',
#        'stakingAddress': '0xA02d547512Bb90002807499F05495Fe9C4C3943f',
#        'ghstUsdcAddress': '0x096c5ccb33cfc5732bcd1f3195c13dbefc4c82f4',
#        'ghstWethAddress': '0xccb9d2100037f1253e6c1682adf7dc9944498aff',
#        'ghstQuickAddress': '0x8b1fd78ad67c7da09b682c5392b65ca7caa101b9'}}}},
#    {'name': 'pagination',
#     'params': {'limit': 500,
#      'symbol': 'AGIP',
#      'strategy': {'name': 'aavegotchi-agip',
#       'params': {'tokenAddress': '0x86935f11c86623dec8a25696e1c19a8659cbf95d'}}}},
#    {'name': 'pagination',
#     'params': {'limit': 500,
#      'symbol': 'GHST',
#      'strategy': {'name': 'erc20-balance-of',
#       'params': {'address': '0x385Eeac5cB85A38A9a07A70c73e0a3271CfB54A7',
#        'decimals': 18}}}},
#    {'name': 'pagination',
#     'params': {'symbol': 'AGIP17',
#      'strategy': {'name': 'aavegotchi-agip-17',
#       'params': {'symbol': 'REALM'}}}}],
#   'admins': ['0x027Ffd3c119567e85998f4E6B9c3d83D5702660c',
#    '0x7E4724C60718A9F87CE51bcF8812Bf90D0b7B9Db',
#    '0xa3efAaDEc9b2533d546139a79A21d661dd3F08ea'],
#   'members': ['0x027Ffd3c119567e85998f4E6B9c3d83D5702660c',
#    '0x5e31c357d03e9528E9BF95bD16e5c1aB3f7D37D0',
#    '0x7E4724C60718A9F87CE51bcF8812Bf90D0b7B9Db'],
#   'filters': {'minScore': 1, 'onlyMembers': False},
#   'plugins': {'poap': {}, 'quorum': {'total': 9000000, 'strategy': 'static'}}},
#  {'id': 'firestack.eth',
#   'name': 'Firestack',
#   'about': '',
#   'network': '108',
#   'symbol': 'FRSK',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'FRSK',
#      'address': '0x2a7a59c82812a4b70Dedf76ef4F3b7451A212a3f',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x9650F4feDd1e6ce63621479A4bf5F4d743E6F958',
#    '0x583d2a5621366BD20877908357DC0924DEB1Da91'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'wse.eth',
#   'name': 'WhiteSwap',
#   'about': '',
#   'network': '1',
#   'symbol': 'WSE',
#   'strategies': [{'name': 'contract-call',
#     'params': {'symbol': 'WSE',
#      'address': '0x77b8ae2E83c7d044d159878445841E2A9777Af38',
#      'decimals': 18,
#      'methodABI': {'name': 'getCurrentVotes',
#       'type': 'function',
#       'inputs': [{'name': 'account',
#         'type': 'address',
#         'internalType': 'address'}],
#       'outputs': [{'name': '', 'type': 'uint96', 'internalType': 'uint96'}],
#       'stateMutability': 'view'}}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 1, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'baovotes.eth',
#   'name': 'baovotes.eth',
#   'about': '',
#   'network': '1',
#   'symbol': 'BAO',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'BAO',
#      'address': '0xAed713175343D3AA83689F85Ab9E7B800a297992',
#      'decimals': 18}}],
#   'admins': ['0x3bC3c8aF8CFe3dFC9bA1A57c7C3b653e3f6d6951',
#    '0x18d5D444467Fa53a78e72cB98375F57efDAfF0F1'],
#   'members': ['0x3bC3c8aF8CFe3dFC9bA1A57c7C3b653e3f6d6951',
#    '0x18d5D444467Fa53a78e72cB98375F57efDAfF0F1',
#    '0x27d882B686b00faF2A5849E41E84073541e62B90',
#    '0x2f75E925C38f83785A7D0630f65Aed8C65C1454f',
#    '0x8f4A7b7AeaA5c0E01b7b3c0e966D8E62e7b3cBf6',
#    '0x8f5d46FCADEcA93356B70F40858219bB1FBf6088',
#    '0xab0C9BC6bcBaad9391C530f33f9294DEc38ae189',
#    '0xf1674FE69b2920b4de51E909cbf060dd78724CD8'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'yfdfi.eth',
#   'name': 'DFI.GOV',
#   'about': '',
#   'network': '1',
#   'symbol': 'YFD',
#   'strategies': [{'name': 'uniswap',
#     'params': {'symbol': 'YFD',
#      'address': '0x4F4F0Ef7978737ce928BFF395529161b44e27ad9',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x96706EB471F875a9a41442f358d3B34ba02F868b'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'unitprotocol.eth',
#   'name': 'Unit protocol',
#   'about': '',
#   'network': '1',
#   'symbol': 'COL',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'COL',
#      'address': '0xc76fb75950536d98fa62ea968e1d6b45ffea2a55',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x40A6e795ba54E12B21264C416fE2918a537637f2'],
#   'filters': {'minScore': 100000000, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'thescientificblock.eth',
#   'name': 'thescientificblock',
#   'about': '',
#   'network': '1',
#   'symbol': 'tsb',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'unidexapp.eth',
#   'name': 'UniDex',
#   'about': '',
#   'network': '250',
#   'symbol': 'UNIDX',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'UNIDX',
#      'address': '0x2130d2a1e51112d349ccf78d2a1ee65843ba36e0',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x2E5d207a4C0F7e7C52F6622DCC6EB44bC0fE1A13'],
#   'filters': {'minScore': 50, 'onlyMembers': False},
#   'plugins': {'charts': {'total_votes_per_day': {'enabled': True},
#     'voting_power_per_day': {'enabled': True},
#     'voting_power_per_address': {'enabled': True}}}},
#  {'id': 'ubxt.eth',
#   'name': 'UpBots',
#   'about': '',
#   'network': '1',
#   'symbol': 'UBXT',
#   'strategies': [{'name': 'multichain',
#     'params': {'graphs': {'1': 'https://api.thegraph.com/subgraphs/name/apyvision/block-info',
#       '56': 'https://api.thegraph.com/subgraphs/name/apyvision/block-info'},
#      'symbol': 'UBXT',
#      'strategies': [{'name': 'erc20-balance-of',
#        'params': {'address': '0x8564653879a18c560e7c0ea0e084c516c62f5653',
#         'decimals': 18},
#        'network': '1'},
#       {'name': 'erc20-balance-of',
#        'params': {'address': '0xbbeb90cfb6fafa1f69aa130b7341089abeef5811',
#         'decimals': 18},
#        'network': '56'}]}}],
#   'admins': ['0x2B6b2701d7F7b65BA2E1ec2d2dAa17d46B85A4fe',
#    '0x7D4Bf7054F5cfD1f15c4E7D680656f0faF840898',
#    '0x37adC63949857080d3b5A28bb6D5ca2e335e907E',
#    '0x567c96c040e8Ff5B938A3E86F9258d362D55F8D5'],
#   'members': ['0x7D4Bf7054F5cfD1f15c4E7D680656f0faF840898',
#    '0x2B6b2701d7F7b65BA2E1ec2d2dAa17d46B85A4fe',
#    '0x37adC63949857080d3b5A28bb6D5ca2e335e907E',
#    '0x567c96c040e8Ff5B938A3E86F9258d362D55F8D5'],
#   'filters': {'minScore': 5000000, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'hollaex.eth',
#   'name': 'HollaEx',
#   'about': '',
#   'network': '1',
#   'symbol': 'XHT',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'XHT',
#      'address': '0xD3c625F54dec647DB8780dBBe0E880eF21BA4329',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x8C4e039921905e0CDF9a18b3E3D857922719b209'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'noderunners.eth',
#   'name': 'Node Runners',
#   'about': '',
#   'network': '1',
#   'symbol': 'NDR',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'NDR',
#      'address': '0x739763a258640919981F9bA610AE65492455bE53',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'xdaistake.eth',
#   'name': 'xDai Chain (Gnosis Chain)',
#   'about': 'The xDai chain is a stable payments blockchain designed for fast and inexpensive transactions. ',
#   'network': '1',
#   'symbol': 'STAKE',
#   'strategies': [{'name': 'multichain',
#     'params': {'graphs': {'100': 'https://api.thegraph.com/subgraphs/name/1hive/xdai-blocks'},
#      'symbol': 'STAKE',
#      'strategies': [{'name': 'honeyswap',
#        'params': {'address': '0xb7D311E2Eb55F2f68a9440da38e7989210b9A05e',
#         'useStakedBalances': 'true'},
#        'network': '100'},
#       {'name': 'agave',
#        'params': {'lpToken': '0xf7a28097fDf8c323Da826A9D98617a266A73c0Ef',
#         'underlyingToken': '0xb7D311E2Eb55F2f68a9440da38e7989210b9A05e'},
#        'network': '100'},
#       {'name': 'erc20-balance-of',
#        'params': {'address': '0x0Ae055097C6d159879521C384F1D2123D1f195e6',
#         'decimals': 18},
#        'network': '1'},
#       {'name': 'erc20-balance-of',
#        'params': {'address': '0xb7D311E2Eb55F2f68a9440da38e7989210b9A05e',
#         'decimals': 18},
#        'network': '100'},
#       {'name': 'uniswap-v3',
#        'params': {'poolAddress': '0x7B24f3f2c6fc51CA67C91BCDfEB07Bc75249Fd1d',
#         'tokenReserve': 0},
#        'network': '1'},
#       {'name': 'uniswap',
#        'params': {'address': '0x0Ae055097C6d159879521C384F1D2123D1f195e6',
#         'decimals': 18},
#        'network': '1'},
#       {'name': 'sushiswap',
#        'params': {'address': '0x0Ae055097C6d159879521C384F1D2123D1f195e6',
#         'useStakedBalances': 'true'},
#        'network': '1'},
#       {'name': 'sushiswap',
#        'params': {'address': '0xb7D311E2Eb55F2f68a9440da38e7989210b9A05e',
#         'useStakedBalances': 'true'},
#        'network': '100'},
#       {'name': 'xdai-easy-staking',
#        'params': {'address': '0x0Ae055097C6d159879521C384F1D2123D1f195e6',
#         'decimals': 18},
#        'network': '1'},
#       {'name': 'xdai-posdao-staking', 'network': '100'}],
#      'startBlocks': {'1': 0, '100': 0}}},
#    {'name': 'delegation',
#     'params': {'symbol': 'STAKE (delegated)',
#      'strategies': [{'name': 'multichain',
#        'params': {'graphs': {'100': 'https://api.thegraph.com/subgraphs/name/1hive/xdai-blocks'},
#         'symbol': 'STAKE',
#         'strategies': [{'name': 'honeyswap',
#           'params': {'address': '0xb7D311E2Eb55F2f68a9440da38e7989210b9A05e',
#            'useStakedBalances': 'true'},
#           'network': '100'},
#          {'name': 'agave',
#           'params': {'lpToken': '0xf7a28097fDf8c323Da826A9D98617a266A73c0Ef',
#            'underlyingToken': '0xb7D311E2Eb55F2f68a9440da38e7989210b9A05e'},
#           'network': '100'},
#          {'name': 'erc20-balance-of',
#           'params': {'address': '0x0Ae055097C6d159879521C384F1D2123D1f195e6',
#            'decimals': 18},
#           'network': '1'},
#          {'name': 'erc20-balance-of',
#           'params': {'address': '0xb7D311E2Eb55F2f68a9440da38e7989210b9A05e',
#            'decimals': 18},
#           'network': '100'},
#          {'name': 'uniswap-v3',
#           'params': {'poolAddress': '0x7B24f3f2c6fc51CA67C91BCDfEB07Bc75249Fd1d',
#            'tokenReserve': 0},
#           'network': '1'},
#          {'name': 'uniswap',
#           'params': {'address': '0x0Ae055097C6d159879521C384F1D2123D1f195e6',
#            'decimals': 18},
#           'network': '1'},
#          {'name': 'sushiswap',
#           'params': {'address': '0x0Ae055097C6d159879521C384F1D2123D1f195e6',
#            'useStakedBalances': 'true'},
#           'network': '1'},
#          {'name': 'sushiswap',
#           'params': {'address': '0xb7D311E2Eb55F2f68a9440da38e7989210b9A05e',
#            'useStakedBalances': 'true'},
#           'network': '100'},
#          {'name': 'xdai-easy-staking',
#           'params': {'address': '0x0Ae055097C6d159879521C384F1D2123D1f195e6',
#            'decimals': 18},
#           'network': '1'},
#          {'name': 'xdai-posdao-staking', 'network': '100'}],
#         'startBlocks': {'1': 0, '100': 0}}}]}}],
#   'admins': [],
#   'members': ['0x50c87176BcD227aB083A6B4Cf2038b0D5081fFe5',
#    '0xA84944735B66e957Fe385567dcc85975022Fe68A',
#    '0x4dc7a5aB35447A88697F9B97eE1f4b997FEE0b7C'],
#   'filters': {'minScore': 1000, 'onlyMembers': True},
#   'plugins': {'poap': {}}},
#  {'id': 'compgov.eth',
#   'name': 'Compound Governance',
#   'about': '',
#   'network': '1',
#   'symbol': 'COMP',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'COMP',
#      'address': '0xc00e94cb662c3520282e6f5717214004a7f26888',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'earndeficoin.eth',
#   'name': 'EarnDefiCoin',
#   'about': '',
#   'network': '1',
#   'symbol': 'EDC',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'EDC',
#      'address': '0xAE66bEa480f7a6C91F07C58f2AEe185883558fb8',
#      'decimals': 18}}],
#   'admins': [],
#   'members': ['0x0530b049EebbB433De580f6358150574C7FB0346',
#    '0xc26ffc302c76ddc00c9fce8cbb3dbdb86209e13c'],
#   'filters': {'minScore': 50000, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'multiplierfinance.eth',
#   'name': 'Multiplier Finance MXX',
#   'about': '',
#   'network': '1',
#   'symbol': 'MXX',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'MXX',
#      'address': '0x8a6f3bf52a26a21531514e23016eeae8ba7e7018',
#      'decimals': 8}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 50000, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'wearedesign.eth',
#   'name': 'Design',
#   'about': '',
#   'network': '1',
#   'symbol': 'DSGN',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DSGN',
#      'address': '0x537a9095b78517597b5f2058edcd6e1978095909',
#      'decimals': 4}}],
#   'admins': [],
#   'members': ['0xf9b2F966C3CD7d39066a8534809135Cc945A22A5'],
#   'filters': {'minScore': 23000, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'tranche.eth',
#   'name': 'Tranche Finance',
#   'about': 'Tranche is a decentralized protocol for managing DeFi risk and maximizing returns.',
#   'network': '1',
#   'symbol': 'SLICE',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'SLICE',
#      'address': '0x0aee8703d34dd9ae107386d3eff22ae75dd616d1',
#      'decimals': 18}},
#    {'name': 'uniswap',
#     'params': {'symbol': 'Uniswap LP',
#      'address': '0x0aee8703d34dd9ae107386d3eff22ae75dd616d1',
#      'decimals': 18}},
#    {'name': 'tranche-staking',
#     'params': {'symbol': 'Staked SLICE',
#      'address': '0x5CE49F584257606426498bfd16d770C50bB20254',
#      'decimals': 18,
#      'tokenAddress': '0x0aee8703d34dd9ae107386d3eff22ae75dd616d1'}},
#    {'name': 'tranche-staking-lp',
#     'params': {'symbol': 'SLICE/DAI LP',
#      'address': '0xBc2834e142bBBa3704D6855c63ca99CfC5b0E929',
#      'decimals': 18,
#      'tokenAddress': '0x0aee8703d34dd9ae107386d3eff22ae75dd616d1',
#      'lpTokenAddress': '0x896eebeb02f81445f5a88ff7884af8d937294ee8'}},
#    {'name': 'tranche-staking-lp',
#     'params': {'symbol': 'SLICE/ETH LP',
#      'address': '0x05db908E095662745595Ee42C9C90aaDC5D51c98',
#      'decimals': 18,
#      'tokenAddress': '0x0aee8703d34dd9ae107386d3eff22ae75dd616d1',
#      'lpTokenAddress': '0xa21ECe44Cc5dAc03E3805362bd3f68F22a49Ea1e'}},
#    {'name': 'tranche-staking-slice',
#     'params': {'symbol': 'SLICE',
#      'address': '0xab4235a9acf00a45557e90f7db127f3b293ca45a',
#      'decimals': 18}}],
#   'admins': ['0x5aD3330AeBDd74D7Dda641D37273Ac1835EE9330',
#    '0x55eE305d2d3039E82853C438a8c6AE47afB743A4'],
#   'members': ['0x5aD3330AeBDd74D7Dda641D37273Ac1835EE9330',
#    '0x55eE305d2d3039E82853C438a8c6AE47afB743A4'],
#   'filters': {'minScore': 5000, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'trinityprotocol.eth',
#   'name': 'Trinity',
#   'about': '',
#   'network': '1',
#   'symbol': 'TRI',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'TRI',
#      'address': '0xc299004a310303d1c0005cb14c70ccc02863924d',
#      'decimals': 9}}],
#   'admins': [],
#   'members': ['0x73D9d147eDeB7d6E31D2326B7D942b16CBc79ffD'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'yfi3money.eth',
#   'name': 'yfi3money',
#   'about': '',
#   'network': '1',
#   'symbol': 'yfi3',
#   'strategies': [{'name': 'erc20-balance-of',
# ...
#      'address': '0xaA2C0cf54cB418eB24E7e09053B82C875C68bb88',
#      'decimals': 18}},
#    {'name': 'erc20-balance-of',
#     'params': {'symbol': 'TESU1',
#      'address': '0x61f885867DC34222854890b53b4eFE03B03c3E89',
#      'decimals': 18}},
#    {'name': 'erc20-with-balance',
#     'params': {'symbol': 'SOON',
#      'address': '0xaA2C0cf54cB418eB24E7e09053B82C875C68bb88',
#      'decimals': 18}}],
#   'admins': ['0x960Dbe5457C7d4dCAD9041D61A7b12B96D6BD1D7'],
#   'members': ['0x960Dbe5457C7d4dCAD9041D61A7b12B96D6BD1D7',
#    '0x60A1827cC0B8b7c112B39f2E8A4D01d10E51C3fc'],
#   'filters': {'minScore': 5, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'awsl.eth',
#   'name': 'Web3首选投研',
#   'about': '媒体+VC＝操控NFT价格；',
#   'network': '1',
#   'symbol': 'rice',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'rice',
#      'address': '0xbd9908b0cdd50386f92efcc8e1d71766c2782df0',
#      'decimals': 18}}],
#   'admins': ['0x131a858718ed52f79f5204cbc7daa6af03c694dd'],
#   'members': ['0x131a858718ed52f79f5204cbc7daa6af03c694dd'],
#   'filters': {'minScore': 100, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'quadraticvoting.eth',
#   'name': 'VOL Test',
#   'about': '',
#   'network': '1',
#   'symbol': 'VOL',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'VOL',
#      'address': '0x5166E09628b696285E3A151e84FB977736a83575',
#      'decimals': 18}},
#    {'name': 'contract-call',
#     'params': {'symbol': 'sVOL',
#      'address': '0xcf9FAD8BC125EbB96e27318fF9159108Dbf688e8',
#      'decimals': 18,
#      'methodABI': {'name': 'totalPower',
#       'type': 'function',
#       'inputs': [{'name': '_beneficiary',
#         'type': 'address',
#         'internalType': 'address'}],
#       'outputs': [{'name': 'total',
#         'type': 'uint256',
#         'internalType': 'uint256'}],
#       'stateMutability': 'view'}}}],
#   'admins': ['0x85f32c1326cb11fc460312d6e4fFC9D6c93C7E94',
#    '0x000000aaee6a496aaf7b7452518781786313400f',
#    '0x794f58Bd8257ccd02E86D80375e6bF5BbD14758f'],
#   'members': ['0x85f32c1326cb11fc460312d6e4fFC9D6c93C7E94',
#    '0x794f58Bd8257ccd02E86D80375e6bF5BbD14758f',
#    '0x000000aaee6a496aaf7b7452518781786313400f'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'stormxio.eth',
#   'name': 'StormX',
#   'about': '',
#   'network': '1',
#   'symbol': 'ATH',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'ATH',
#      'address': '0x2F9411088cEF82Fd9fB904Eb8092f28eB485C8F6',
#      'decimals': 18}}],
#   'admins': ['0x93b06Fd660042F6651feC7BdF6b2E0B6Bba6660F',
#    '0xb67eFA83B4F7e5bBE367E2a410AD3899d019D847'],
#   'members': ['0xb67eFA83B4F7e5bBE367E2a410AD3899d019D847',
#    '0x93b06Fd660042F6651feC7BdF6b2E0B6Bba6660F',
#    '0x2436dBe34D41f032138180A8353dB518f16C4D3e'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'zenft.eth',
#   'name': 'ZENFT',
#   'about': '',
#   'network': '1',
#   'symbol': 'BNSI/SPIRIT',
#   'strategies': [{'name': 'erc721',
#     'params': {'symbol': 'SPIRIT',
#      'address': '0x38eeF32ae1978bD4240605F5d3f98A4427fdC845'}},
#    {'name': 'erc721',
#     'params': {'symbol': 'BNSI',
#      'address': '0xeC9C519D49856Fd2f8133A0741B4dbE002cE211b'}}],
#   'admins': ['0x8F2b195992046C364de1eEe5bD7a1060be2d82fA'],
#   'members': ['0x8F2b195992046C364de1eEe5bD7a1060be2d82fA'],
#   'filters': {'minScore': 1, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'ampled.eth',
#   'name': 'Ampled',
#   'about': 'Direct support for all musicians. Collectively owned, community supported.',
#   'network': '1',
#   'symbol': 'Ampled',
#   'strategies': [{'name': 'erc20-with-balance',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}},
#    {'name': 'balance-of-with-min',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}}],
#   'admins': ['0xFB4974917850D9D82D812DD49221EB0B4C2F240e',
#    '0x9E5457E23d6e59b5F40cA6d99082049C5421F4f0'],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'rcubedao.xyz',
#   'name': 'RetroDEFI - RCUBE DAO',
#   'about': 'RCUBE DAO is a User-Governed ecosystem aimed to hand the RetroDEFI community the voting power for the future steps of the platform',
#   'network': '56',
#   'symbol': 'RCUBE',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'RCUBE',
#      'address': '0xa6e53f07bd410df069e20ced725bdc9135146fe9',
#      'decimals': 18}},
#    {'name': 'contract-call',
#     'params': {'symbol': 'RCUBE',
#      'address': '0xa6e53f07bd410df069e20ced725bdc9135146fe9',
#      'decimals': 18}}],
#   'admins': ['0xB5c8f28AB36Cee8481a720D2D9561832e790782C'],
#   'members': [],
#   'filters': {'minScore': 1000, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'yotta21.eth',
#   'name': 'Yotta21',
#   'about': 'Only delegated DYTT may be used to vote on proposals. You can delegate to yourself or another address here: vote.yotta21.co',
#   'network': '4',
#   'symbol': 'DYTT',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DYTT',
#      'address': '0x739a64cb87c37d9f17568c337490768e5f34c1c3',
#      'decimals': 18}}],
#   'admins': ['0xFcaA55E72357c12adfd8168AeA71E353d2233Aa6'],
#   'members': ['0xFc3408640D0c34F2d6C0cb68cd5082eDd3df8FCb'],
#   'filters': {'minScore': 1, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'researchhub.eth',
#   'name': 'ResearchHub',
#   'about': '',
#   'network': '1',
#   'symbol': 'RSC',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'RSC',
#      'address': '0xd101dcc414f310268c37eeb4cd376ccfa507f571',
#      'decimals': 18}}],
#   'admins': ['0xAfDb8502c2D012C3E9306445f012b4a2D30De860'],
#   'members': ['0xAfDb8502c2D012C3E9306445f012b4a2D30De860',
#    '0x29E46015cCFe13cfe8dC96D75760a6290dF311Ee',
#    '0x1eB8F260d5e0311F396E076aE2CB4EEbfb17a3E7'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'alicehe.eth',
#   'name': 'alicehe',
#   'about': '',
#   'network': '1',
#   'symbol': 'ETH',
#   'strategies': [{'name': 'uniswap',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}},
#    {'name': 'erc20-balance-of',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'flux01.eth',
#   'name': 'Flux',
#   'about': 'Flux Protocol - A multi-chain lending and borrowing  platform',
#   'network': '1',
#   'symbol': 'FLUX',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'FLUX',
#      'address': '0x7645DdfEecedA57e41f92679c4aCd83c56A81D14',
#      'decimals': 18}}],
#   'admins': ['0xE7B6721fC8C9b313C2422200D2B05c9aB2F1A665',
#    '0x8A30b9440C13bCeFCEf04BAd5B98087Cc353Fc00'],
#   'members': ['0xE7B6721fC8C9b313C2422200D2B05c9aB2F1A665',
#    '0x8A30b9440C13bCeFCEf04BAd5B98087Cc353Fc00'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'flux-bsc.eth',
#   'name': 'Flux-BSC DAO',
#   'about': '',
#   'network': '56',
#   'symbol': 'ZO',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'ZO',
#      'address': '0x3b808Db06074E1bAe5dFE0D970dc7B891EE26Cac',
#      'decimals': 18}},
#    {'name': 'erc20-balance-of',
#     'params': {'symbol': 'ZO-30 day3',
#      'address': '0x709abe32ace78dfba971c6f4a109642749d01be7',
#      'decimals': 18}}],
#   'admins': ['0xE7B6721fC8C9b313C2422200D2B05c9aB2F1A665',
#    '0x8A30b9440C13bCeFCEf04BAd5B98087Cc353Fc00',
#    '0x73AC875785523bf7D9C20D26393EC67607d2D923',
#    '0xD888B6a490F524d97374E2844c356b4B6b58954A'],
#   'members': ['0xE7B6721fC8C9b313C2422200D2B05c9aB2F1A665',
#    '0x8A30b9440C13bCeFCEf04BAd5B98087Cc353Fc00',
#    '0x73AC875785523bf7D9C20D26393EC67607d2D923',
#    '0xD888B6a490F524d97374E2844c356b4B6b58954A'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'flux-heco.eth',
#   'name': 'Flux-Heco DAO',
#   'about': '',
#   'network': '128',
#   'symbol': 'hFLUX',
#   'strategies': [{'name': 'erc20-balance-of-coeff',
#     'params': {'coeff': 0.2,
#      'symbol': 'hFLUX',
#      'address': '0xd10852DF03Ea8b8Af0CC0B09cAc3f7dbB15e0433',
#      'decimals': 18}},
#    {'name': 'erc20-balance-of-coeff',
#     'params': {'coeff': 3,
#      'symbol': 'FLUX3days',
#      'address': '0x122E253B5D7544F09a67Ff72702f59a82baC868E',
#      'decimals': 18}},
#    {'name': 'erc20-balance-of-coeff',
#     'params': {'coeff': 7,
#      'symbol': 'FLUX7days',
#      'address': '0x9198E353FE12786eA04152D51280D5BDB1A3DCe2',
#      'decimals': 18}},
#    {'name': 'erc20-balance-of-coeff',
#     'params': {'coeff': 30,
#      'symbol': 'FLUX30days',
#      'address': '0xd0815947F6816Fc8565b9B68AfcA99E249C72ea6',
#      'decimals': 18}}],
#   'admins': ['0xE7B6721fC8C9b313C2422200D2B05c9aB2F1A665',
#    '0x8A30b9440C13bCeFCEf04BAd5B98087Cc353Fc00',
#    '0x73AC875785523bf7D9C20D26393EC67607d2D923'],
#   'members': ['0xE7B6721fC8C9b313C2422200D2B05c9aB2F1A665',
#    '0x8A30b9440C13bCeFCEf04BAd5B98087Cc353Fc00',
#    '0x73AC875785523bf7D9C20D26393EC67607d2D923'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'flux-oec.eth',
#   'name': 'Flux-OEC DAO',
#   'about': '',
#   'network': '66',
#   'symbol': 'FLUXK',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'FLUXK',
#      'address': '0xd0C6821aba4FCC65e8f1542589e64BAe9dE11228',
#      'decimals': 18}}],
#   'admins': ['0xE7B6721fC8C9b313C2422200D2B05c9aB2F1A665',
#    '0x8A30b9440C13bCeFCEf04BAd5B98087Cc353Fc00',
#    '0x73AC875785523bf7D9C20D26393EC67607d2D923'],
#   'members': ['0xE7B6721fC8C9b313C2422200D2B05c9aB2F1A665',
#    '0x8A30b9440C13bCeFCEf04BAd5B98087Cc353Fc00'],
#   'filters': {'minScore': 0, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'unlock-protocol.eth',
#   'name': 'Unlock Protocol',
#   'about': 'Unlock is a protocol for memberships',
#   'network': '1',
#   'symbol': 'UDT',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'UDT',
#      'address': '0x90de74265a416e1393a450752175aed98fe11517',
#      'decimals': 18}}],
#   'admins': ['0x4Ce2DD8373ECe0d7baAA16E559A5817CC875b16a'],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'rcubedao.eth',
#   'name': 'RETRO DEFI ',
#   'about': "RETRO DEFI is a User-Governed Ecosystem | Yield Farming | Gaming | NFT's",
#   'network': '56',
#   'symbol': 'RCUBE',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'RCUBE',
#      'address': '0xa6e53f07bd410df069e20ced725bdc9135146fe9',
#      'decimals': 18}},
#    {'name': 'contract-call',
#     'params': {'symbol': 'RCUBE',
#      'address': '0xa6e53f07bd410df069e20ced725bdc9135146fe9',
#      'decimals': 18}}],
#   'admins': ['0xB5c8f28AB36Cee8481a720D2D9561832e790782C'],
#   'members': [],
#   'filters': {'minScore': 2500, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'metta.eth',
#   'name': 'Mettā Creative',
#   'about': 'To allow participation of MTTA token holders in the governance of Mettā Creative DAO ',
#   'network': '1',
#   'symbol': 'mtta',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'MTTA',
#      'address': '0x0Df6b23127cfd1C931000cbB452a0D75A716c3cd',
#      'decimals': 2}}],
#   'admins': ['0xD2f793D5f65449e6992e0c9c52A7334b62e5ec6c'],
#   'members': ['0x713A60bc9FB6D8527ACF956dc92b11f253b0512d',
#    '0xDE31A8E636E1222E736ff0Fe7e4e95aCb0018C6E',
#    '0xbD8C79740Bf625F5054E86a2CE4e73879382f923'],
#   'filters': {'minScore': 100, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'icebrk.eth',
#   'name': 'Icebreak-R',
#   'about': 'ICEBRK token is the governance and utility token for the IceBreak-R Network, a social media driven NFT-marketplace and DeFi ecosystem.',
#   'network': '250',
#   'symbol': 'ICEBRK',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'ICEBRK',
#      'address': '0xc6E3f3083a15468350976369898381Eec5cfE10f',
#      'decimals': 9}},
#    {'name': 'erc20-balance-of',
#     'params': {'symbol': 'ICEDOGE',
#      'address': '0xF007fb98c537aaf892dfb04e794dFEbbE9aDCfc6',
#      'decimals': 9}}],
#   'admins': ['0x30bc20753b325C7F7B3e55daEB464C348C5e8096',
#    '0x721700d0DC44058B8Dc855840464489210Ca1457'],
#   'members': ['0x721700d0DC44058B8Dc855840464489210Ca1457',
#    '0x30bc20753b325C7F7B3e55daEB464C348C5e8096',
#    '0xBA189a4F264f5A434B5DCD49Df5aB150DD0e54Ae',
#    '0xa587a1694ec8b2e7dcb1cf3ed3ac3f8b4953f938',
#    '0x0bb354811980410fd515a5d5f0fbd484dbbc93d5',
#    '0xffdcab633846a6f90a1084a914f988f2c4e3e3da'],
#   'filters': {'minScore': 2000, 'onlyMembers': True},
#   'plugins': {}},
#  {'id': 'marbleclash.eth',
#   'name': 'MarbleClash',
#   'about': 'The first game based on MarbleCards',
#   'network': '1',
#   'symbol': 'MBC',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'MBC',
#      'address': '0x8888889213DD4dA823EbDD1e235b09590633C150',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'apestreet.eth',
#   'name': 'Ape Street',
#   'about': 'Decentralizing the Financial World',
#   'network': '1',
#   'symbol': 'APE',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'frenchienetwork.eth',
#   'name': 'Frenchie Network',
#   'about': '',
#   'network': '56',
#   'symbol': 'FREN',
#   'strategies': [{'name': 'erc20-with-balance',
#     'params': {'symbol': 'FREN',
#      'address': '0x13958e1eb63dfb8540eaf6ed7dcbbc1a60fd52af',
#      'decimals': 18}},
#    {'name': 'erc20-balance-of',
#     'params': {'symbol': 'FREN',
#      'address': '0x13958e1eb63dfb8540eaf6ed7dcbbc1a60fd52af',
#      'decimals': 18}}],
#   'admins': ['0x6ED8CD17EE5453E17eb731a6B2004aF53eA1f26a'],
#   'members': ['0x6ED8CD17EE5453E17eb731a6B2004aF53eA1f26a'],
#   'filters': {'minScore': 1000000000, 'onlyMembers': False},
#   'plugins': {'quorum': {'total': 50000000000, 'strategy': 'static'}}},
#  {'id': 'mintlaab.eth',
#   'name': 'Mintlaab',
#   'about': '',
#   'network': '1',
#   'symbol': 'DAI',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'ETH',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}}],
#   'admins': ['0x1700c12BC9F2D6963B71d3022301A8d326796865',
#    '0xD710B4cbF1A4E510F6c6e9245c5Cb65c4eB3Dc02'],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'longdrinkfinance.eth',
#   'name': 'Longdrink Finance',
#   'about': 'Longdrink Finance is the leading index protocol on BSC',
#   'network': '56',
#   'symbol': 'LONG',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'vLong',
#      'address': '0x6F49e0311419eDc6879F8d3d60E49f1eDb7A257E',
#      'decimals': 18}}],
#   'admins': ['0x33756a0A837Ec2babee7244bb6D5793FD7306818',
#    '0xd9811FF259869e9bC23d77EEBAc7C3f01DB68D33'],
#   'members': ['0x33756a0A837Ec2babee7244bb6D5793FD7306818',
#    '0xd9811FF259869e9bC23d77EEBAc7C3f01DB68D33'],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'chimpyswap.eth',
#   'name': 'ChimpySwap',
#   'about': 'ChimpySwap is a decentralized exchange on Binance Smart Chain',
#   'network': '56',
#   'symbol': 'CHIMPY',
#   'strategies': [{'name': 'pancake',
#     'params': {'symbol': 'DAI',
#      'address': '0x6B175474E89094C44Da98b954EedeAC495271d0F',
#      'decimals': 18}}],
#   'admins': ['0x4C9093bF32814BD705bA5A7FecF799ce74C0C85f'],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  {'id': 'ldt.eth',
#   'name': 'LENDOO',
#   'about': 'lendoo is a lend protocol. website: https://lendoo.finance',
#   'network': '70',
#   'symbol': 'GLDT',
#   'strategies': [{'name': 'erc20-balance-of',
#     'params': {'symbol': 'GLDT',
#      'address': '0xB856F232f1Eb62bd9E301287631A168b9A5C68dE',
#      'decimals': 18}}],
#   'admins': [],
#   'members': [],
#   'filters': {'minScore': 0, 'onlyMembers': False},
#   'plugins': {}},
#  ...]
